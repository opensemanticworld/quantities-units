# %% [markdown]
# # 1. Unit Prefix
#
# [Unit prefix](https://wiki-dev.open-semantic-lab.org/wiki/Category:OSW99e0f46a40ca4129a420b4bb89c4cc45)
#
# State: functional but can be optimized for higher data quality by adding ontology references to property exact_ontology_match. Logic that proves the exact match required.

# %% [markdown]
# ## Required OSL Schemas

# %%
from osw.core import OSW
import osw
from osw.auth import CredentialManager
from osw.wtsite import WtSite
from osw.express import OswExpress
import osw.model.entity as model


required_schemas = [
    "Category:OSW99e0f46a40ca4129a420b4bb89c4cc45",  # Unit prefix
    "Category:OSWd2520fa016844e01af0097a85bb25b25",  # Unit of Measure
]


def update_local_osw(osw_obj):
    print("fetch schemas")
    osw_obj.fetch_schema(
        OSW.FetchSchemaParam(
            schema_title=required_schemas,
            mode="replace",
        )
    )


if __name__ == "__main__":
    # Authentication
    osw_obj = OswExpress(
        domain="wiki-dev.open-semantic-lab.org",  # cred_filepath=pwd_file_path
    )
    update_local_osw(osw_obj)
# Out:
# fetch schemas
# Fetch Category:OSW99e0f46a40ca4129a420b4bb89c4cc45
# Fetch Category:OSWd02741381aaa4709ae0753a0edc341ce
# Fetch Category:OSWcbb09a36336740c6a2cd62db9bf647ec
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47

# %%
from pprint import pprint


title = "Item:OSW9aae9552adf34f139f6766876a8d7c59"  # kilo


kilo_u = osw_obj.load_entity(title)


print("kilo json:\n")


pprint(kilo_u.json(exclude_none=True))


print("kilo pydantic:\n")


pprint(kilo_u)


# Constructor example of Prefix unit


prefix_unit_example = model.UnitPrefix(
    uuid="574e9f21-e175-4937-847e-93c2ae9bf185",
    name="dummy_kilo",
    label=[{"text": "kilo (unit prefix)", "lang": "en"}],
    description=[],
    type=["Category:OSW99e0f46a40ca4129a420b4bb89c4cc45"],  # Unit prefix
    symbol="k",
    factor=1000.0,
)

pprint(prefix_unit_example)

# Upload Prefixed unit example
# osw_obj.store_entity(prefix_unit_example)

# Delete Prefixed unit example
# osw_obj.delete_entity(prefix_unit_example)
# Out:
# kilo json:
#
# ('{"type": ["Category:OSW99e0f46a40ca4129a420b4bb89c4cc45"], "uuid": '
#  '"9aae9552-adf3-4f13-9f67-66876a8d7c59", "name": "kilo", "label": [{"text": '
#  '"kilo (unit prefix)", "lang": "en"}], "description": [], "meta": '
#  '{"wiki_page": {"title": "OSW9aae9552adf34f139f6766876a8d7c59", "namespace": '
#  '"Item"}}, "symbol": "k", "factor": 1000.0}')
# kilo pydantic:
#
# UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('9aae9552-adf3-4f13-9f67-66876a8d7c59'), exact_ontology_match=None, close_ontology_match=None, rdf_type=None, iri=None, name='kilo', label=[Label(text='kilo (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=Meta(wiki_page=WikiPage(title='OSW9aae9552adf34f139f6766876a8d7c59', namespace='Item'), change_id=None), entry_access=None, symbol='k', factor=1000.0)
# UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('574e9f21-e175-4937-847e-93c2ae9bf185'), exact_ontology_match=None, close_ontology_match=None, rdf_type=None, iri=None, name='dummy_kilo', label=[Label(text='kilo (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='k', factor=1000.0)

# %% [markdown]
# ## Fetch SI Digital Framework API Prefixes

# %%
# TODO: Implement sparql_wrapper for .ttl file as endpoint


# from utils import sparql_wrapper

# # SI Prefixes
# sparql_sidf_prefixes = sparql_wrapper.Sparql(
#     endpoint="https://si-digital-framework.org/SI/query",
#     src_filepath="../ontology/sidf/sparql/prefixes.sparql",
#     tgt_filepath="../ontology/sidf/data/prefixes.json",
#     debug=False,
# )
# sidf_prefixes = sparql_sidf_prefixes.execQuery()
# # sparql_sidf_prefixes.writeJsonFile(data=om2_qk)
# pprint(sidf_prefixes)

# %%
# Use REST API to fetch data
import requests

sidf_api_host = "https://si-digital-framework.org"
sidf_prefixes_endpoint = "/SI/prefixes"
sidf_prefixes_url = sidf_api_host + sidf_prefixes_endpoint

sidf_prefixes_res_en = requests.get(
    url=sidf_prefixes_url,
    params={"lang": "en"},
)

# Compare the results and print the differences
from deepdiff import DeepDiff

diff = DeepDiff(sidf_prefixes_res_en.json(), sidf_prefixes_res_de.json())
print("difference in prefixes en vs. de:\n", diff)
pprint(sidf_prefixes_res_en.json())

# Example of DeepDiff
# a = {"a": 1, "b": 2}
# b = {"a": 1, "b": 3}

# diff = DeepDiff(a, b)
# print(diff)
# Out:
# difference in prefixes en vs. de:
#  {}
# [{'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm2022res3e',
#   'label': 'quecto',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/quecto',
#   'prefixId': 'quecto',
#   'scalingFactor': 1e-30,
#   'scalingFactorStr': '1e-30',
#   'symbol': 'q'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm2022res3e',
#   'label': 'ronto',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/ronto',
#   'prefixId': 'ronto',
#   'scalingFactor': 1e-27,
#   'scalingFactorStr': '1e-27',
#   'symbol': 'r'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1991res4e',
#   'label': 'yocto',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/yocto',
#   'prefixId': 'yocto',
#   'scalingFactor': 1e-24,
#   'scalingFactorStr': '1e-24',
#   'symbol': 'y'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1991res4e',
#   'label': 'zepto',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/zepto',
#   'prefixId': 'zepto',
#   'scalingFactor': 1e-21,
#   'scalingFactorStr': '1e-21',
#   'symbol': 'z'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1964res8e',
#   'label': 'atto',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/atto',
#   'prefixId': 'atto',
#   'scalingFactor': 1e-18,
#   'scalingFactorStr': '1e-18',
#   'symbol': 'a'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1964res8e',
#   'label': 'femto',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/femto',
#   'prefixId': 'femto',
#   'scalingFactor': 1e-15,
#   'scalingFactorStr': '1e-15',
#   'symbol': 'f'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'pico',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/pico',
#   'prefixId': 'pico',
#   'scalingFactor': 1e-12,
#   'scalingFactorStr': '1e-12',
#   'symbol': 'p'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'nano',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/nano',
#   'prefixId': 'nano',
#   'scalingFactor': 1e-09,
#   'scalingFactorStr': '1e-09',
#   'symbol': 'n'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'micro',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/micro',
#   'prefixId': 'micro',
#   'scalingFactor': 1e-06,
#   'scalingFactorStr': '1e-06',
#   'symbol': 'µ'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#decimal',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'milli',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/milli',
#   'prefixId': 'milli',
#   'scalingFactor': 0.001,
#   'scalingFactorStr': '1e-03',
#   'symbol': 'm'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#decimal',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'centi',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/centi',
#   'prefixId': 'centi',
#   'scalingFactor': 0.01,
#   'scalingFactorStr': '1e-02',
#   'symbol': 'c'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#decimal',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'deci',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/deci',
#   'prefixId': 'deci',
#   'scalingFactor': 0.1,
#   'scalingFactorStr': '1e-01',
#   'symbol': 'd'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#integer',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'deca',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/deca',
#   'prefixId': 'deca',
#   'scalingFactor': 10.0,
#   'scalingFactorStr': '1e+01',
#   'symbol': 'da'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#integer',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'hecto',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/hecto',
#   'prefixId': 'hecto',
#   'scalingFactor': 100.0,
#   'scalingFactorStr': '1e+02',
#   'symbol': 'h'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#integer',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'kilo',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/kilo',
#   'prefixId': 'kilo',
#   'scalingFactor': 1000.0,
#   'scalingFactorStr': '1e+03',
#   'symbol': 'k'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#integer',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'mega',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/mega',
#   'prefixId': 'mega',
#   'scalingFactor': 1000000.0,
#   'scalingFactorStr': '1e+06',
#   'symbol': 'M'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#integer',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'giga',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/giga',
#   'prefixId': 'giga',
#   'scalingFactor': 1000000000.0,
#   'scalingFactorStr': '1e+09',
#   'symbol': 'G'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#integer',
#   'doi': 'https://doi.org/10.59161/cgpm1960res12e',
#   'label': 'tera',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/tera',
#   'prefixId': 'tera',
#   'scalingFactor': 1000000000000.0,
#   'scalingFactorStr': '1e+12',
#   'symbol': 'T'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#integer',
#   'doi': 'https://doi.org/10.59161/cgpm1975res10e',
#   'label': 'peta',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/peta',
#   'prefixId': 'peta',
#   'scalingFactor': 1000000000000000.0,
#   'scalingFactorStr': '1e+15',
#   'symbol': 'P'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1975res10e',
#   'label': 'exa',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/exa',
#   'prefixId': 'exa',
#   'scalingFactor': 1e+18,
#   'scalingFactorStr': '1e+18',
#   'symbol': 'E'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1991res4e',
#   'label': 'zetta',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/zetta',
#   'prefixId': 'zetta',
#   'scalingFactor': 1e+21,
#   'scalingFactorStr': '1e+21',
#   'symbol': 'Z'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm1991res4e',
#   'label': 'yotta',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/yotta',
#   'prefixId': 'yotta',
#   'scalingFactor': 1e+24,
#   'scalingFactorStr': '1e+24',
#   'symbol': 'Y'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm2022res3e',
#   'label': 'ronna',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/ronna',
#   'prefixId': 'ronna',
#   'scalingFactor': 1e+27,
#   'scalingFactorStr': '1e+27',
#   'symbol': 'R'},
#  {'dataType': 'http://www.w3.org/2001/XMLSchema#float',
#   'doi': 'https://doi.org/10.59161/cgpm2022res3e',
#   'label': 'quetta',
#   'pid': 'https://si-digital-framework.org/SI/prefixes/quetta',
#   'prefixId': 'quetta',
#   'scalingFactor': 1e+30,
#   'scalingFactorStr': '1e+30',
#   'symbol': 'Q'}]

# %% [markdown]
# ## Map Attributes from fetched data to OSL Instances of UnitPrefix

# %%
# Deterministic UUID by URL
import uuid

prefix_name = "kilo"
print(
    uuid.uuid5(
        namespace=uuid.NAMESPACE_URL,
        name=f"https://si-digital-framework.org/SI/prefixes/{prefix_name}",
    )
)
# Out:
# 4b380554-7fd8-5820-83af-f8562ba4b4c5

# %%
# DEPRECATED: single prefix upload
import uuid

# For each prefix, create a UnitPrefix object and upload it to OSW
for prefix in sidf_prefixes_res_en.json():
    # Instantiate Prefixed unit 
    prefix_unit = model.UnitPrefix(
        uuid=uuid.uuid5(
          namespace=uuid.NAMESPACE_URL, 
          name=prefix["pid"]
        ),  
        name=prefix["label"],
        exact_ontology_match=[prefix["pid"]],
        label=[{"text": f"{prefix["label"]} (unit prefix)", "lang": "en"}],
        description=[],
        type=["Category:OSW99e0f46a40ca4129a420b4bb89c4cc45"],  # Unit prefix
        symbol=prefix["symbol"],
        factor=prefix["scalingFactor"],
    )
    
    # Upload Prefixed unit
    osw_obj.store_entity(prefix_unit)
    
    # Delete Prefixed unit
    # osw_obj.delete_entity(prefix_unit)
# Out:
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWacf92a3a0e8d5980b4827fe8a60bea1a'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW9011d0bfe7d95515a9d02e245c203768'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWc8823e0b49b9580b96a5cd136482522b'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW1ec25b8880285b038e10bf20520072f0'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWa569fd62d673576f8150159be578c72d'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWaa15a848c6445a7087c7293dd18a7244'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW5f8f94601be05a078108b2be4d74e461'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWb6a5fd00b91058d1909514095f84fe6f'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW59f1ae99ce85577d995c76e442b46e74'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWbca49386a57457c1a1b250da355d94fe'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW0be842b1433b5b4aa5625264c188d622'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW2b7aeb54b7395e99b3d5c20b77de4b15'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWfa81836c0a3951e8ac1f4c6d0fba3e25'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW4b3805547fd8582083aff8562ba4b4c5'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWed7019528a135715a25263d19a2d5bef'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW62e04cd0df5c5ad4b76d5632fa7b47a0'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW8c95fb553826551fb7c0294a7c0ada41'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW8f99dd9018ab5f848ada364a751a65db'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW6536aa1754db57d7a75f42389720cb23'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW15a58e45166256828641ebf46f034d4c'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSWd03cdff87efa5392b2a53097e36f4ae4'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW780ec81283de5d9cbd88f4b23ff93735'.
# Entities to be uploaded have been sorted according to their type.
# Now uploading entities of class type 'Category:OSW99e0f46a40ca4129a420b4bb89c4cc45' (UnitPrefix). No class specific overwrite setting found. Using fallback option 'keep existing' for all entities of this class.
# (1/1) Entity stored at 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW6ddac2f976055ffcb416c1da8dec445f'.

# %%
# Optimized version

unit_prefixes = [
    model.UnitPrefix(
        uuid=uuid.uuid5(
            namespace=uuid.NAMESPACE_URL,
            name=prefix["pid"]
        ),
        name=prefix["label"],
        exact_ontology_match=[prefix["pid"]],
        label=[{"text": f"{prefix["label"]} (unit prefix)", "lang": "en"}],
        description=[],
        type=["Category:OSW99e0f46a40ca4129a420b4bb89c4cc45"],  # Unit prefix
        symbol=prefix["symbol"],
        factor=prefix["scalingFactor"],
    )
    for prefix in sidf_prefixes_res_en.json()
]
print(f"Length of prefixid units: {len(unit_prefixes)}\nunit_prefixes:\n")
pprint(unit_prefixes)

# Upload all Prefixed units in a single call
osw_obj.store_entity(unit_prefixes)
# Out:
# Length of prefixid units: 24
# prefix_units:
#
# [UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('acf92a3a-0e8d-5980-b482-7fe8a60bea1a'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/quecto'], close_ontology_match=None, rdf_type=None, iri=None, name='quecto', label=[Label(text='quecto (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='q', factor=1e-30),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('9011d0bf-e7d9-5515-a9d0-2e245c203768'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/ronto'], close_ontology_match=None, rdf_type=None, iri=None, name='ronto', label=[Label(text='ronto (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='r', factor=1e-27),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('c8823e0b-49b9-580b-96a5-cd136482522b'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/yocto'], close_ontology_match=None, rdf_type=None, iri=None, name='yocto', label=[Label(text='yocto (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='y', factor=1e-24),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('1ec25b88-8028-5b03-8e10-bf20520072f0'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/zepto'], close_ontology_match=None, rdf_type=None, iri=None, name='zepto', label=[Label(text='zepto (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='z', factor=1e-21),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('a569fd62-d673-576f-8150-159be578c72d'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/atto'], close_ontology_match=None, rdf_type=None, iri=None, name='atto', label=[Label(text='atto (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='a', factor=1e-18),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('aa15a848-c644-5a70-87c7-293dd18a7244'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/femto'], close_ontology_match=None, rdf_type=None, iri=None, name='femto', label=[Label(text='femto (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='f', factor=1e-15),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('5f8f9460-1be0-5a07-8108-b2be4d74e461'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/pico'], close_ontology_match=None, rdf_type=None, iri=None, name='pico', label=[Label(text='pico (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='p', factor=1e-12),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('b6a5fd00-b910-58d1-9095-14095f84fe6f'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/nano'], close_ontology_match=None, rdf_type=None, iri=None, name='nano', label=[Label(text='nano (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='n', factor=1e-09),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('59f1ae99-ce85-577d-995c-76e442b46e74'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/micro'], close_ontology_match=None, rdf_type=None, iri=None, name='micro', label=[Label(text='micro (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='µ', factor=1e-06),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('6d63c0f4-ea7b-56b2-80d1-a6d363ec48c6'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/milli'], close_ontology_match=None, rdf_type=None, iri=None, name='milli', label=[Label(text='milli (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='m', factor=0.001),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('bca49386-a574-57c1-a1b2-50da355d94fe'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/centi'], close_ontology_match=None, rdf_type=None, iri=None, name='centi', label=[Label(text='centi (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='c', factor=0.01),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('0be842b1-433b-5b4a-a562-5264c188d622'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/deci'], close_ontology_match=None, rdf_type=None, iri=None, name='deci', label=[Label(text='deci (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='d', factor=0.1),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('2b7aeb54-b739-5e99-b3d5-c20b77de4b15'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/deca'], close_ontology_match=None, rdf_type=None, iri=None, name='deca', label=[Label(text='deca (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='da', factor=10.0),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('fa81836c-0a39-51e8-ac1f-4c6d0fba3e25'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/hecto'], close_ontology_match=None, rdf_type=None, iri=None, name='hecto', label=[Label(text='hecto (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='h', factor=100.0),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('4b380554-7fd8-5820-83af-f8562ba4b4c5'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/kilo'], close_ontology_match=None, rdf_type=None, iri=None, name='kilo', label=[Label(text='kilo (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='k', factor=1000.0),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('ed701952-8a13-5715-a252-63d19a2d5bef'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/mega'], close_ontology_match=None, rdf_type=None, iri=None, name='mega', label=[Label(text='mega (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='M', factor=1000000.0),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('62e04cd0-df5c-5ad4-b76d-5632fa7b47a0'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/giga'], close_ontology_match=None, rdf_type=None, iri=None, name='giga', label=[Label(text='giga (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='G', factor=1000000000.0),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('8c95fb55-3826-551f-b7c0-294a7c0ada41'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/tera'], close_ontology_match=None, rdf_type=None, iri=None, name='tera', label=[Label(text='tera (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='T', factor=1000000000000.0),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('8f99dd90-18ab-5f84-8ada-364a751a65db'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/peta'], close_ontology_match=None, rdf_type=None, iri=None, name='peta', label=[Label(text='peta (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='P', factor=1000000000000000.0),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('6536aa17-54db-57d7-a75f-42389720cb23'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/exa'], close_ontology_match=None, rdf_type=None, iri=None, name='exa', label=[Label(text='exa (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='E', factor=1e+18),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('15a58e45-1662-5682-8641-ebf46f034d4c'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/zetta'], close_ontology_match=None, rdf_type=None, iri=None, name='zetta', label=[Label(text='zetta (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='Z', factor=1e+21),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('d03cdff8-7efa-5392-b2a5-3097e36f4ae4'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/yotta'], close_ontology_match=None, rdf_type=None, iri=None, name='yotta', label=[Label(text='yotta (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='Y', factor=1e+24),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('780ec812-83de-5d9c-bd88-f4b23ff93735'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/ronna'], close_ontology_match=None, rdf_type=None, iri=None, name='ronna', label=[Label(text='ronna (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='R', factor=1e+27),
#  UnitPrefix(type=['Category:OSW99e0f46a40ca4129a420b4bb89c4cc45'], uuid=UUID('6ddac2f9-7605-5ffc-b416-c1da8dec445f'), exact_ontology_match=['https://si-digital-framework.org/SI/prefixes/quetta'], close_ontology_match=None, rdf_type=None, iri=None, name='quetta', label=[Label(text='quetta (unit prefix)', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, symbol='Q', factor=1e+30)]
