# %% [markdown]
# # 2. Units

# %% [markdown]
# ## Fetch prefixes name list

# %%
import requests
from pprint import pprint
import json
import uuid

sidf_prefixes_res_de = requests.get(
    url="https://si-digital-framework.org/SI/prefixes",
    params={"lang": "de"},
)

# Convert result to dict
sidf_prefixes_de = sidf_prefixes_res_de.json()
print(sidf_prefixes_de)
prefix_name_list = [item["label"] for item in sidf_prefixes_de]
print(prefix_name_list)
# Out:
# [{'label': 'quecto', 'symbol': 'q', 'scalingFactor': 1e-30, 'prefixId': 'quecto', 'scalingFactorStr': '1e-30', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/quecto'}, {'label': 'ronto', 'symbol': 'r', 'scalingFactor': 1e-27, 'prefixId': 'ronto', 'scalingFactorStr': '1e-27', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/ronto'}, {'label': 'yocto', 'symbol': 'y', 'scalingFactor': 1e-24, 'prefixId': 'yocto', 'scalingFactorStr': '1e-24', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/yocto'}, {'label': 'zepto', 'symbol': 'z', 'scalingFactor': 1e-21, 'prefixId': 'zepto', 'scalingFactorStr': '1e-21', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/zepto'}, {'label': 'atto', 'symbol': 'a', 'scalingFactor': 1e-18, 'prefixId': 'atto', 'scalingFactorStr': '1e-18', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/atto'}, {'label': 'femto', 'symbol': 'f', 'scalingFactor': 1e-15, 'prefixId': 'femto', 'scalingFactorStr': '1e-15', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/femto'}, {'label': 'pico', 'symbol': 'p', 'scalingFactor': 1e-12, 'prefixId': 'pico', 'scalingFactorStr': '1e-12', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/pico'}, {'label': 'nano', 'symbol': 'n', 'scalingFactor': 1e-09, 'prefixId': 'nano', 'scalingFactorStr': '1e-09', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/nano'}, {'label': 'micro', 'symbol': 'µ', 'scalingFactor': 1e-06, 'prefixId': 'micro', 'scalingFactorStr': '1e-06', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/micro'}, {'label': 'milli', 'symbol': 'm', 'scalingFactor': 0.001, 'prefixId': 'milli', 'scalingFactorStr': '1e-03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/milli'}, {'label': 'centi', 'symbol': 'c', 'scalingFactor': 0.01, 'prefixId': 'centi', 'scalingFactorStr': '1e-02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/centi'}, {'label': 'deci', 'symbol': 'd', 'scalingFactor': 0.1, 'prefixId': 'deci', 'scalingFactorStr': '1e-01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/deci'}, {'label': 'deca', 'symbol': 'da', 'scalingFactor': 10.0, 'prefixId': 'deca', 'scalingFactorStr': '1e+01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/deca'}, {'label': 'hecto', 'symbol': 'h', 'scalingFactor': 100.0, 'prefixId': 'hecto', 'scalingFactorStr': '1e+02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/hecto'}, {'label': 'kilo', 'symbol': 'k', 'scalingFactor': 1000.0, 'prefixId': 'kilo', 'scalingFactorStr': '1e+03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http ...
# ['quecto', 'ronto', 'yocto', 'zepto', 'atto', 'femto', 'pico', 'nano', 'micro', 'milli', 'centi', 'deci', 'deca', 'hecto', 'kilo', 'mega', 'giga', 'tera', 'peta', 'exa', 'zetta', 'yotta', 'ronna', 'quetta']

# %% [markdown]
# ## Fetch all quantities (SI) from Qudt with its units

# %%
from utils import sparql_wrapper
from pprint import pprint

sparql_qudt_qk = sparql_wrapper.Sparql(
    endpoint="https://www.qudt.org/fuseki/qudt/sparql",
    src_filepath="../ontology/qudt/sparql/quantitykind.sparql",
    tgt_filepath="../ontology/qudt/data/quantitykind.json",
    debug=False,
)
qudt_qk = sparql_qudt_qk.execQuery()
sparql_qudt_qk.writeJsonFile(data=qudt_qk)
print("num of quantitykind: ", len(qudt_qk["results"]["bindings"]))
pprint(qudt_qk)
# Out:
# Reading SPARQL Query from c:\Users\raeder\Desktop\dev\Gitlab\osw\apps\python-lvl2\quantities-units\src\quantities-units\utils\../ontology/qudt/sparql/quantitykind.sparql
# Writing JSON data to c:\Users\raeder\Desktop\dev\Gitlab\osw\apps\python-lvl2\quantities-units\src\quantities-units\utils\../ontology/qudt/data/quantitykind.json
# num of quantitykind:  329
# {'head': {'vars': ['quantity',
#                    'dimension',
#                    'labels',
#                    'descriptions',
#                    'plainTextDescriptions',
#                    'applicableUnits',
#                    'ucumCodes']},
#  'results': {'bindings': [{'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J, '
#                                                         'http://qudt.org/vocab/unit/MegaEV, '
#                                                         'http://qudt.org/vocab/unit/EV, '
#                                                         'http://qudt.org/vocab/unit/GigaEV, '
#                                                         'http://qudt.org/vocab/unit/AttoJ, '
#                                                         'http://qudt.org/vocab/unit/ExaJ, '
#                                                         'http://qudt.org/vocab/unit/FemtoJ, '
#                                                         'http://qudt.org/vocab/unit/GigaJ, '
#                                                         'http://qudt.org/vocab/unit/GigaW-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloEV, '
#                                                         'http://qudt.org/vocab/unit/KiloJ, '
#                                                         'http://qudt.org/vocab/unit/KiloV-A-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloW-HR, '
#                                                         'http://qudt.org/vocab/unit/MegaJ, '
#                                                         'http://qudt.org/vocab/unit/MegaV-A-HR, '
#                                                         'http://qudt.org/vocab/unit/MegaW-HR, '
#                                                         'http://qudt.org/vocab/unit/MilliJ, '
#                                                         'http://qudt.org/vocab/unit/PetaJ, '
#                                                         'http://qudt.org/vocab/unit/TeraJ, '
#                                                         'http://qudt.org/vocab/unit/TeraW-HR, '
#                                                         'http://qudt.org/vocab/unit/V-A-HR, '
#                                                         'http://qudt.org/vocab/unit/W-HR, '
#                                                         'http://qudt.org/vocab/unit/W-SEC'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'Energy is the quantity '
#                                                      'characterizing the '
#                                                      'ability of a system to '
#                                                      'do work.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L2I0M1H0T-2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Energie@de, energy@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'Energy is the '
#                                                               'quantity '
#                                                               'characterizing '
#                                                               'the ability of '
#                                                               'a system to do '
#                                                               'work.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Energy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J, MeV, eV, GeV, aJ, EJ, '
#                                                   'fJ, GJ, GW.h, keV, kJ, '
#                                                   'kV.A.h, kW.h, MJ, MV.A.h, '
#                                                   'MW.h, mJ, PJ, TJ, TW/h, '
#                                                   'V.A.h, W.h, W.s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/CentiM2-PER-V-SEC, '
#                                                         'http://qudt.org/vocab/unit/M2-PER-V-SEC'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Mobility" characterizes '
#                                                      'how quickly a particle '
#                                                      'can move through a metal '
#                                                      'or semiconductor, when '
#                                                      'pulled by an electric '
#                                                      'field. The average drift '
#                                                      'speed imparted to a '
#                                                      'charged particle in a '
#                                                      'medium by an electric '
#                                                      'field, divided by the '
#                                                      'electric field '
#                                                      'strength.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E1L0I0M-1H0T2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Beweglichkeit@de, mobility@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': '"Mobility" '
#                                                               'characterizes '
#                                                               'how quickly a '
#                                                               'particle can '
#                                                               'move through a '
#                                                               'metal or '
#                                                               'semiconductor, '
#                                                               'when pulled by '
#                                                               'an electric '
#                                                               'field. The '
#                                                               'average drift '
#                                                               'speed imparted '
#                                                               'to a charged '
#                                                               'particle in a '
#                                                               'medium by an '
#                                                               'electric field, '
#                                                               'divided by the '
#                                                               'electric field '
#                                                               'strength.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Mobility'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'cm2.V-1.s-1, cm2/(V.s), '
#                                                   'm2.V-1.s-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/KiloGM-PER-M3'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Mass Concentration of '
#                                                      'Water Vapour" is one of '
#                                                      'a number of '
#                                                      '$\\textit{Concentration}$ '
#                                                      'quantities defined by '
#                                                      'ISO 80000.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-3I0M1H0T0D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Mass Concentration of Water '
#                                                'Vapour@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'Mass '
#                                                               'Concentration '
#                                                               'of Water is one '
#                                                               'of a number of '
#                                                               'Concentration '
#                                                               'quantities '
#                                                               'defined by ISO '
#                                                               '80000.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MassConcentrationOfWaterVapour'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'kg.m-3, kg/m3'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/A-PER-DEG_C'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Electric Current per '
#                                                      'Unit Temperature" is '
#                                                      'used to express how a '
#                                                      'current is subject to '
#                                                      'temperature. Originally '
#                                                      "used in Wien's Law to "
#                                                      'describe phenomena '
#                                                      'related to filaments. '
#                                                      'One use today is to '
#                                                      'express how a current '
#                                                      'generator derates with '
#                                                      'temperature.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E1L0I0M0H-1T0D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Electric Current per '
#                                                'Temperature@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': '"Electric '
#                                                               'Current per '
#                                                               'Temperature" is '
#                                                               'used to express '
#                                                               'how a current '
#                                                               'is subject to '
#                                                               'temperature. '
#                                                               'Originally used '
#                                                               "in Wien's Law "
#                                                               'to describe '
#                                                               'phenomena '
#                                                               'related to '
#                                                               'filaments. One '
#                                                               'use today is to '
#                                                               'express how a '
#                                                               'current '
#                                                               'generator '
#                                                               'derates with '
#                                                               'temperature.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ElectricCurrentPerTemperature'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'A.Cel-1, A/Cel'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/KiloGM-PER-M-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloGM-PER-M-SEC, '
#                                                         'http://qudt.org/vocab/unit/MilliPA-SEC, '
#                                                         'http://qudt.org/vocab/unit/PA-SEC'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'A measure of the '
#                                                      'molecular frictional '
#                                                      'resistance of a fluid as '
#                                                      'calculated using '
#                                                      "Newton's law."},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M1H0T-1D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'dynamic viscosity@en, '
#                                                'dynamische Viskosität@de'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'A measure of '
#                                                               'the molecular '
#                                                               'frictional '
#                                                               'resistance of a '
#                                                               'fluid as '
#                                                               'calculated '
#                                                               "using Newton's "
#                                                               'law.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/DynamicViscosity'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'kg.m-1.h-1, kg.m-1.s-1, '
#                                                   'mPa.s, Pa.s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M2-PER-SEC'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'The "Diffusion '
#                                                      'Coefficient" is '},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L2I0M0H0T-1D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Diffusionskoeffizient@de, '
#                                                'diffusion coefficient@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'The "Diffusion '
#                                                               'Coefficient" '
#                                                               'is '},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/NeutronDiffusionCoefficient'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2.s-1, m2/s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/V-PER-M'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'The space surrounding an '
#                                                      'electric charge or in '
#                                                      'the presence of a '
#                                                      'time-varying magnetic '
#                                                      'field has a property '
#                                                      'called an electric '
#                                                      'field. This electric '
#                                                      'field exerts a force on '
#                                                      'other electrically '
#                                                      'charged objects. In the '
#                                                      'idealized case, the '
#                                                      'force exerted between '
#                                                      'two point charges is '
#                                                      'inversely proportional '
#                                                      'to the square of the '
#                                                      'distance between them. '
#                                                      "(Coulomb's Law)."},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E-1L1I0M1H0T-3D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Electric Field@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'The space '
#                                                               'surrounding an '
#                                                               'electric charge '
#                                                               'or in the '
#                                                               'presence of a '
#                                                               'time-varying '
#                                                               'magnetic field '
#                                                               'has a property '
#                                                               'called an '
#                                                               'electric field. '
#                                                               'This electric '
#                                                               'field exerts a '
#                                                               'force on other '
#                                                               'electrically '
#                                                               'charged '
#                                                               'objects. In the '
#                                                               'idealized case, '
#                                                               'the force '
#                                                               'exerted between '
#                                                               'two point '
#                                                               'charges is '
#                                                               'inversely '
#                                                               'proportional to '
#                                                               'the square of '
#                                                               'the distance '
#                                                               'between them. '
#                                                               "(Coulomb's "
#                                                               'Law).'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ElectricField'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'V.m-1, V/m'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/CentiM3-PER-GM, '
#                                                         'http://qudt.org/vocab/unit/DeciL-PER-GM, '
#                                                         'http://qudt.org/vocab/unit/L-PER-KiloGM, '
#                                                         'http://qudt.org/vocab/unit/M3-PER-KiloGM, '
#                                                         'http://qudt.org/vocab/unit/MilliL-PER-GM, '
#                                                         'http://qudt.org/vocab/unit/MilliL-PER-KiloGM, '
#                                                         'http://qudt.org/vocab/unit/MilliM3-PER-GM, '
#                                                         'http://qudt.org/vocab/unit/MilliM3-PER-KiloGM'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Specific Volume" '
#                                                      '($\\nu$) is the volume '
#                                                      'occupied by a unit of '
#                                                      'mass of a material. It '
#                                                      'is equal to the inverse '
#                                                      'of density.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L3I0M-1H0T0D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Specific Volume@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/SpecificVolume'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'cm3.g-1, cm3/g, dL.g-1, '
#                                                   'dL/g, L.kg-1, L/kg, '
#                                                   'm3.kg-1, m3/kg, mL.g-1, '
#                                                   'mL/g, mL.kg-1, mL/kg, '
#                                                   'mm3.g-1, mm3/g, mm3.kg-1, '
#                                                   'mm3/kg'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/HectoPA-PER-K, '
#                                                         'http://qudt.org/vocab/unit/KiloPA-PER-K, '
#                                                         'http://qudt.org/vocab/unit/MegaPA-PER-K, '
#                                                         'http://qudt.org/vocab/unit/PA-PER-K'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M1H-1T-2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Pressure Coefficient@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/PressureCoefficient'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'hPa.K-1, kPa.K-1, MPa.K-1, '
#                                                   'Pa.K-1, Pa/K'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M1H-1T-3D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Surface Coefficient of Heat '
#                                                'Transfer@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/SurfaceCoefficientOfHeatTransfer'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'W.m-2.K-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/C3-M-PER-J2'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E3L-3I0M-2H0T7D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Cubic Electric Dipole Moment '
#                                                'per Square Energy@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ElectricDipoleMoment_CubicPerEnergy_Squared'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'C3.m.J-2, C3.m/J2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/C-PER-KiloGM-SEC'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Exposure Rate" '
#                                                      'expresses the rate of '
#                                                      'charge production per '
#                                                      'unit mass of air and is '
#                                                      'commonly expressed in '
#                                                      'roentgens per hour (R/h) '
#                                                      'or milliroentgens per '
#                                                      'hour (mR/h).'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E1L0I0M-1H0T0D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Exposure Rate@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': '"Exposure Rate" '
#                                                               'expresses the '
#                                                               'rate of charge '
#                                                               'production per '
#                                                               'unit mass of '
#                                                               'air and is '
#                                                               'commonly '
#                                                               'expressed in '
#                                                               'roentgens per '
#                                                               'hour (R/h) or '
#                                                               'milliroentgens '
#                                                               'per hour '
#                                                               '(mR/h).'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ExposureRate'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'C.kg-1.s-1, C/(kg.s)'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/GigaJ-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/J-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/MilliJ-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/ERG-PER-CentiM2, '
#                                                         'http://qudt.org/vocab/unit/J-PER-CentiM2, '
#                                                         'http://qudt.org/vocab/unit/KiloGM-PER-SEC2, '
#                                                         'http://qudt.org/vocab/unit/KiloW-HR-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/MegaJ-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/N-M-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/W-HR-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/W-SEC-PER-M2'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'Energy per unit area is '
#                                                      'a measure of the energy '
#                                                      'either impinging upon or '
#                                                      'generated from a given '
#                                                      'unit of area. This can '
#                                                      'be a measure of the '
#                                                      '"toughness" of a '
#                                                      'material, being the '
#                                                      'amount of energy that '
#                                                      'needs to be applied per '
#                                                      'unit area of a crack to '
#                                                      'cause it to fracture. '
#                                                      'This is a constant for a '
#                                                      'given material..'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M1H0T-2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Energy per Area@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'Energy per unit '
#                                                               'area is a '
#                                                               'measure of the '
#                                                               'energy either '
#                                                               'impinging upon '
#                                                               'or generated '
#                                                               'from a given '
#                                                               'unit of area. '
#                                                               'This can be a '
#                                                               'measure of the '
#                                                               '"toughness" of '
#                                                               'a material, '
#                                                               'being the '
#                                                               'amount of '
#                                                               'energy that '
#                                                               'needs to be '
#                                                               'applied per '
#                                                               'unit area of a '
#                                                               'crack to cause '
#                                                               'it to fracture. '
#                                                               'This is a '
#                                                               'constant for a '
#                                                               'given '
#                                                               'material..'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/EnergyPerArea'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'GJ.m-2, GJ/m2, J.m-2, J/m2, '
#                                                   'mJ.m-2, mJ/m2, erg.cm-2, '
#                                                   'J.cm-2, kg.s-2, kg/s2, '
#                                                   'kW.h.m-2, MJ.m-2, N.m.m-2, '
#                                                   'W.h.m-2, W.s.m-2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-KiloV-A-HR'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-2I0M-1H0T2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Inverse Energy@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/InverseEnergy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'kV-1.A-1.h-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J-PER-MOL-K'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'The "Standard Molar '
#                                                      'Entropy" is the entropy '
#                                                      'content of one mole of '
#                                                      'substance, under '
#                                                      'standard conditions (not '
#                                                      'standard temperature and '
#                                                      'pressure STP).'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A-1E0L2I0M1H-1T-2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Molar Entropy@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'The "Standard '
#                                                               'Molar Entropy" '
#                                                               'is the entropy '
#                                                               'content of one '
#                                                               'mole of '
#                                                               'substance, '
#                                                               'under standard '
#                                                               'conditions (not '
#                                                               'standard '
#                                                               'temperature and '
#                                                               'pressure STP).'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MolarEntropy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J.mol-1.K-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J-PER-MOL, '
#                                                         'http://qudt.org/vocab/unit/KiloJ-PER-MOL'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Molar Energy" is the '
#                                                      'total energy contained '
#                                                      'by a thermodynamic '
#                                                      'system. The unit is '
#                                                      '$$J/mol$$, also '
#                                                      'expressed as '
#                                                      '$$joule/mole$$,  or '
#                                                      '$$joules per mole$$. '
#                                                      'This unit is commonly '
#                                                      'used in the SI unit '
#                                                      'system. The quantity has '
#                                                      'the dimension of $$M '
#                                                      '\\cdot L^2 \\cdot  '
#                                                      'T^{-2} \\cdot N^{-1}$$ '
#                                                      'where $$M$$ is mass, '
#                                                      '$$L$$ is length, $$T$$ '
#                                                      'is time, and $$N$$ is '
#                                                      'amount of substance.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A-1E0L2I0M1H0T-2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Molar Energy@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MolarEnergy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J.mol-1, J/mol, kJ.mol-1, '
#                                                   'kJ/mol'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/OHM'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Impedance" is the '
#                                                      'measure of the '
#                                                      'opposition that a '
#                                                      'circuit presents to the '
#                                                      'passage of a current '
#                                                      'when a voltage is '
#                                                      'applied. In quantitative '
#                                                      'terms, it is the complex '
#                                                      'ratio of the voltage to '
#                                                      'the current in an '
#                                                      'alternating current (AC) '
#                                                      'circuit. Impedance '
#                                                      'extends the concept of '
#                                                      'resistance to AC '
#                                                      'circuits, and possesses '
#                                                      'both magnitude and '
#                                                      'phase, unlike '
#                                                      'resistance, which has '
#                                                      'only magnitude. When a '
#                                                      'circuit is driven with '
#                                                      'direct current (DC), '
#                                                      'there is no distinction '
#                                                      'between impedance and '
#                                                      'resistance; the latter '
#                                                      'can be thought of as '
#                                                      'impedance with zero '
#                                                      'phase angle.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E-2L2I0M1H0T-3D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Impedance@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': '"Impedance" is '
#                                                               'the measure of '
#                                                               'the opposition '
#                                                               'that a circuit '
#                                                               'presents to the '
#                                                               'passage of a '
#                                                               'current when a '
#                                                               'voltage is '
#                                                               'applied. In '
#                                                               'quantitative '
#                                                               'terms, it is '
#                                                               'the complex '
#                                                               'ratio of the '
#                                                               'voltage to the '
#                                                               'current in an '
#                                                               'alternating '
#                                                               'current (AC) '
#                                                               'circuit. '
#                                                               'Impedance '
#                                                               'extends the '
#                                                               'concept of '
#                                                               'resistance to '
#                                                               'AC circuits, '
#                                                               'and possesses '
#                                                               'both magnitude '
#                                                               'and phase, '
#                                                               'unlike '
#                                                               'resistance, '
#                                                               'which has only '
#                                                               'magnitude. When '
#                                                               'a circuit is '
#                                                               'driven with '
#                                                               'direct current '
#                                                               '(DC), there is '
#                                                               'no distinction '
#                                                               'between '
#                                                               'impedance and '
#                                                               'resistance; the '
#                                                               'latter can be '
#                                                               'thought of as '
#                                                               'impedance with '
#                                                               'zero phase '
#                                                               'angle.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Impedance'},
#                            'ucumCodes': {'type': 'literal', 'value': 'Ohm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/SEC'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'Duration of one cycle of '
#                                                      'a periodic phenomenon.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H0T1D0'},
#                            'labels': {'type': 'literal', 'value': 'Period@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'Duration of one '
#                                                               'cycle of a '
#                                                               'periodic '
#                                                               'phenomenon.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Period'},
#                            'ucumCodes': {'type': 'literal', 'value': 's'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/DeciS-PER-M, '
#                                                         'http://qudt.org/vocab/unit/KiloS-PER-M, '
#                                                         'http://qudt.org/vocab/unit/MegaS-PER-M, '
#                                                         'http://qudt.org/vocab/unit/MicroS-PER-CentiM, '
#                                                         'http://qudt.org/vocab/unit/MicroS-PER-M, '
#                                                         'http://qudt.org/vocab/unit/MilliS-PER-CentiM, '
# ...
#                                                               'low '
#                                                               'permeability. '
#                                                               'The '
#                                                               'permeability of '
#                                                               'a medium is '
#                                                               'related to the '
#                                                               'porosity, but '
#                                                               'also to the '
#                                                               'shapes of the '
#                                                               'pores in the '
#                                                               'medium and '
#                                                               'their level of '
#                                                               'connectedness.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/HydraulicPermeability'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2, cm2, dm2, um2, mm2, '
#                                                   'nm2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/KiloGM-PER-GigaJ, '
#                                                         'http://qudt.org/vocab/unit/KiloGM-PER-J'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'Mass per Energy ($m/E$) '
#                                                      'is a physical quantity '
#                                                      'that bridges mass and '
#                                                      'energy. The SI unit is '
#                                                      '$kg/J$ or equivalently '
#                                                      '$s^2/m^2$.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-2I0M0H0T2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Mass per Energy@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'Mass per Energy '
#                                                               'is a physical '
#                                                               'quantity that '
#                                                               'can be used to '
#                                                               'relate the '
#                                                               'energy of a '
#                                                               'system to its '
#                                                               'mass.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MassPerEnergy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'kg.GJ-1, kg.J-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M2-K-PER-W'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '$\\textit{Thermal '
#                                                      'Insulance}$ is the '
#                                                      'reduction of heat '
#                                                      'transfer (the transfer '
#                                                      'of thermal energy '
#                                                      'between objects of '
#                                                      'differing temperature) '
#                                                      'between objects in '
#                                                      'thermal contact or in '
#                                                      'range of radiative '
#                                                      'influence. In building '
#                                                      'technology, this '
#                                                      'quantity is often called '
#                                                      '$\\textit{Thermal '
#                                                      'Resistance}$, with the '
#                                                      'symbol $R$.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M-1H1T3D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Thermal Insulance@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ThermalInsulance'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2.K.W-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-M3, '
#                                                         'http://qudt.org/vocab/unit/PER-CentiM3, '
#                                                         'http://qudt.org/vocab/unit/PER-L, '
#                                                         'http://qudt.org/vocab/unit/PER-MilliL, '
#                                                         'http://qudt.org/vocab/unit/PER-MilliM3'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-3I0M0H0T0D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Inverse Volume@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/InverseVolume'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/m3, m-3, cm-3, /L, L-1, '
#                                                   '/mL, mL-1, /mm3, mm-3'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-T-M'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Length Per Unit '
#                                                      'Magnetic Flux" is the '
#                                                      'the resistance of a '
#                                                      'material to the '
#                                                      'establishment of a '
#                                                      'magnetic field in it. It '
#                                                      'is the reciprocal of '
#                                                      '$\\textit{Magnetic '
#                                                      'Permeability}$, the '
#                                                      'inverse of the measure '
#                                                      'of the ability of a '
#                                                      'material to support the '
#                                                      'formation of a magnetic '
#                                                      'field within itself.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E1L-1I0M-1H0T2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Magnetic Reluctivity@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': 'Length Per Unit '
#                                                               'Magnetic Flux '
#                                                               'is the the '
#                                                               'resistance of a '
#                                                               'material to the '
#                                                               'establishment '
#                                                               'of a magnetic '
#                                                               'field in it. It '
#                                                               'is the '
#                                                               'reciprocal of '
#                                                               'Magnetic '
#                                                               'Permeability, '
#                                                               'the inverse of '
#                                                               'the measure of '
#                                                               'the ability of '
#                                                               'a material to '
#                                                               'support the '
#                                                               'formation of a '
#                                                               'magnetic field '
#                                                               'within itself.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MagneticReluctivity'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'T-1.m-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/V-SEC-PER-M'},
#                            'descriptions': {'type': 'literal',
#                                             'value': '"Scalar Magnetic '
#                                                      'Potential" is the scalar '
#                                                      'potential of an '
#                                                      'irrotational magnetic '
#                                                      'field strength. The '
#                                                      'negative of the gradient '
#                                                      'of the scalar magnetic '
#                                                      'potential is the '
#                                                      'irrotational magnetic '
#                                                      'field strength. The '
#                                                      'magnetic scalar '
#                                                      'potential is not unique '
#                                                      'since any constant '
#                                                      'scalar field can be '
#                                                      'added to it without '
#                                                      'changing its gradient.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E-1L1I0M1H0T-2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Scalar Magnetic Potential@en'},
#                            'plainTextDescriptions': {'type': 'literal',
#                                                      'value': '"Scalar '
#                                                               'Magnetic '
#                                                               'Potential" is '
#                                                               'the scalar '
#                                                               'potential of an '
#                                                               'irrotational '
#                                                               'magnetic field '
#                                                               'strength. The '
#                                                               'negative of the '
#                                                               'gradient of the '
#                                                               'scalar magnetic '
#                                                               'potential is '
#                                                               'the '
#                                                               'irrotational '
#                                                               'magnetic field '
#                                                               'strength. The '
#                                                               'magnetic scalar '
#                                                               'potential is '
#                                                               'not unique '
#                                                               'since any '
#                                                               'constant scalar '
#                                                               'field can be '
#                                                               'added to it '
#                                                               'without '
#                                                               'changing its '
#                                                               'gradient.'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ScalarMagneticPotential'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'V.s.m-1, V.s/m'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J-PER-K'},
#                            'descriptions': {'type': 'literal',
#                                             'value': 'When a small amount of '
#                                                      'heat $dQ$ is received by '
#                                                      'a system whose '
#                                                      'thermodynamic '
#                                                      'temperature is $T$, the '
#                                                      'entropy of the system '
#                                                      'increases by $dQ/T$, '
#                                                      'provided that no '
#                                                      'irreversible change '
#                                                      'takes place in the '
#                                                      'system.'},
#                            'dimension': {'type': 'uri',
#                                          'value': 'http://qudt.org/vocab/dimensionvector/A0E0L2I0M1H-1T-2D0'},
#                            'labels': {'type': 'literal',
#                                       'value': 'Entropie@de, entropy@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Entropy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J.K-1'}}]}}

# %% [markdown]
# ## Split applicableUnits into prefixedUnits and nonPrefixedUnits

# %%
from utils import sparql_wrapper
from pprint import pprint
import json
import requests

quant_kind_list = json.load(open("ontology/qudt/data/quantitykind.json", "r"))[
    "results"
]["bindings"]

pprint(quant_kind_list[5]["applicableUnits"])


def get_prefix_list():

    sidf_prefixes_res_de = requests.get(
        url="https://si-digital-framework.org/SI/prefixes",
        params={"lang": "de"},
    )

    # Convert result to dict
    sidf_prefixes_de = sidf_prefixes_res_de.json()
    print(sidf_prefixes_de)
    prefix_name_list = [item["label"] for item in sidf_prefixes_de]
    print(prefix_name_list)
    return prefix_name_list


prefix_name_list = get_prefix_list()


def get_unit_prefix(unit_str):
    for prefix in prefix_name_list:
        if prefix in unit_str.lower():
            return prefix
    return None


def split_prefixed_applicable_units(applicable_units_str, debug=False):
    non_prefixed_units = []
    prefixed_units = []
    for unit_str in applicable_units_str.split(", "):

        if debug:
            print(unit_str)
            print(get_unit_prefix(unit_str))
        if get_unit_prefix(unit_str) == None:
            if debug:
                print("no prefix: ", unit_str)
            non_prefixed_units.append(unit_str)
        else:
            if debug:
                print(
                    "prefix: ",
                    get_unit_prefix(unit_str),
                    "found in ",
                    unit_str,
                )
            prefixed_units.append(unit_str)
    return non_prefixed_units, prefixed_units


all_prefixed_units = []
all_non_prefixed_units = []
for quant_kind in quant_kind_list:
    non_prefixed, prefixed = split_prefixed_applicable_units(
        quant_kind["applicableUnits"]["value"]
    )
    all_prefixed_units = all_prefixed_units + prefixed
    all_non_prefixed_units = all_non_prefixed_units + non_prefixed

all_prefixed_units = list(set(all_prefixed_units))
all_non_prefixed_units = list(set(all_non_prefixed_units))

print(len(all_prefixed_units))
print(len(all_non_prefixed_units))


import re


def remove_kilo(uri=None, debug=False):
    pattern = re.compile(r"kilo", re.IGNORECASE)
    if debug:
        print(pattern.sub("", uri))
    return pattern.sub("", uri)


unit_str = "http://qudt.org/vocab/unit/KiloGM-PER-M3"

a = remove_kilo(unit_str, debug=False)


def remove_kilo_list(uri_list, debug=False):
    _list = [remove_kilo(uri, debug) for uri in uri_list]
    if debug:
        print(_list)
    return _list


kilo_list = [
    "http://qudt.org/vocab/unit/KiloGM-PER-M3",
    "http://qudt.org/vocab/unit/CentiMOL-PER-KiloGM",
]

b = remove_kilo_list(kilo_list, debug=True)
# Out:
# {'type': 'literal', 'value': 'http://qudt.org/vocab/unit/M2-PER-SEC'}
# [{'label': 'quecto', 'symbol': 'q', 'scalingFactor': 1e-30, 'prefixId': 'quecto', 'scalingFactorStr': '1e-30', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/quecto'}, {'label': 'ronto', 'symbol': 'r', 'scalingFactor': 1e-27, 'prefixId': 'ronto', 'scalingFactorStr': '1e-27', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/ronto'}, {'label': 'yocto', 'symbol': 'y', 'scalingFactor': 1e-24, 'prefixId': 'yocto', 'scalingFactorStr': '1e-24', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/yocto'}, {'label': 'zepto', 'symbol': 'z', 'scalingFactor': 1e-21, 'prefixId': 'zepto', 'scalingFactorStr': '1e-21', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/zepto'}, {'label': 'atto', 'symbol': 'a', 'scalingFactor': 1e-18, 'prefixId': 'atto', 'scalingFactorStr': '1e-18', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/atto'}, {'label': 'femto', 'symbol': 'f', 'scalingFactor': 1e-15, 'prefixId': 'femto', 'scalingFactorStr': '1e-15', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/femto'}, {'label': 'pico', 'symbol': 'p', 'scalingFactor': 1e-12, 'prefixId': 'pico', 'scalingFactorStr': '1e-12', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/pico'}, {'label': 'nano', 'symbol': 'n', 'scalingFactor': 1e-09, 'prefixId': 'nano', 'scalingFactorStr': '1e-09', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/nano'}, {'label': 'micro', 'symbol': 'µ', 'scalingFactor': 1e-06, 'prefixId': 'micro', 'scalingFactorStr': '1e-06', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/micro'}, {'label': 'milli', 'symbol': 'm', 'scalingFactor': 0.001, 'prefixId': 'milli', 'scalingFactorStr': '1e-03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/milli'}, {'label': 'centi', 'symbol': 'c', 'scalingFactor': 0.01, 'prefixId': 'centi', 'scalingFactorStr': '1e-02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/centi'}, {'label': 'deci', 'symbol': 'd', 'scalingFactor': 0.1, 'prefixId': 'deci', 'scalingFactorStr': '1e-01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/deci'}, {'label': 'deca', 'symbol': 'da', 'scalingFactor': 10.0, 'prefixId': 'deca', 'scalingFactorStr': '1e+01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/deca'}, {'label': 'hecto', 'symbol': 'h', 'scalingFactor': 100.0, 'prefixId': 'hecto', 'scalingFactorStr': '1e+02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/hecto'}, {'label': 'kilo', 'symbol': 'k', 'scalingFactor': 1000.0, 'prefixId': 'kilo', 'scalingFactorStr': '1e+03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http ...
# ['quecto', 'ronto', 'yocto', 'zepto', 'atto', 'femto', 'pico', 'nano', 'micro', 'milli', 'centi', 'deci', 'deca', 'hecto', 'kilo', 'mega', 'giga', 'tera', 'peta', 'exa', 'zetta', 'yotta', 'ronna', 'quetta']
# 544
# 333
# http://qudt.org/vocab/unit/GM-PER-M3
# http://qudt.org/vocab/unit/CentiMOL-PER-GM
# ['http://qudt.org/vocab/unit/GM-PER-M3', 'http://qudt.org/vocab/unit/CentiMOL-PER-GM']

# %%
# Functions to extract the path of a given URL
def get_path(url):
    return url.split("/")[-1]


# def get_path_list(url_list):
#     return [get_path(url) for url in url_list]

# def get_iri_without_path(iri):
#     return iri.split("/")[:-1]


def get_main_string(unit_str, prefix_name_list):
    for prefix in prefix_name_list:
        capitalized_prefix = prefix.capitalize()
        if capitalized_prefix in unit_str:
            return unit_str.replace(capitalized_prefix, "")
    return unit_str


def merge_prefixed_and_non_prefixed_units(
    all_non_prefixed_units, all_prefixed_units, prefix_name_list
):
    unit_dict = {}
    for non_prefixed_unit in all_non_prefixed_units:
        prefixed_units = []
        # Match the non prefixed unit with all the prefixed units
        for prefixed_unit in all_prefixed_units:
            if get_path(non_prefixed_unit) == get_main_string(
                get_path(prefixed_unit), prefix_name_list
            ):
                prefixed_units.append(prefixed_unit)
        unit_dict[non_prefixed_unit] = {"prefixed_units": prefixed_units}

    return unit_dict


unit_dict = merge_prefixed_and_non_prefixed_units(
    all_non_prefixed_units, all_prefixed_units, prefix_name_list
)
pprint(unit_dict)
# Out:
# {'http://qudt.org/vocab/unit/A': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaA',
#                                                      'http://qudt.org/vocab/unit/MilliA',
#                                                      'http://qudt.org/vocab/unit/PicoA',
#                                                      'http://qudt.org/vocab/unit/KiloA',
#                                                      'http://qudt.org/vocab/unit/MicroA']},
#  'http://qudt.org/vocab/unit/A-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloA-HR',
#                                                         'http://qudt.org/vocab/unit/MilliA-HR']},
#  'http://qudt.org/vocab/unit/A-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-M2-PER-J-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-DEG_C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloA-PER-M',
#                                                            'http://qudt.org/vocab/unit/A-PER-MilliM',
#                                                            'http://qudt.org/vocab/unit/A-PER-CentiM',
#                                                            'http://qudt.org/vocab/unit/MilliA-PER-MilliM']},
#  'http://qudt.org/vocab/unit/A-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaA-PER-M2',
#                                                             'http://qudt.org/vocab/unit/A-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/KiloA-PER-M2',
#                                                             'http://qudt.org/vocab/unit/A-PER-MilliM2']},
#  'http://qudt.org/vocab/unit/A-PER-M2-K2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/ARE': {'prefixed_units': ['http://qudt.org/vocab/unit/DecaARE']},
#  'http://qudt.org/vocab/unit/AU': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/B': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciB']},
#  'http://qudt.org/vocab/unit/BQ-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroBQ-PER-L',
#                                                             'http://qudt.org/vocab/unit/MilliBQ-PER-L',
#                                                             'http://qudt.org/vocab/unit/NanoBQ-PER-L']},
#  'http://qudt.org/vocab/unit/BQ-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/BQ-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C': {'prefixed_units': ['http://qudt.org/vocab/unit/ZettaC',
#                                                      'http://qudt.org/vocab/unit/ZeptoC',
#                                                      'http://qudt.org/vocab/unit/DeciC',
#                                                      'http://qudt.org/vocab/unit/PicoC',
#                                                      'http://qudt.org/vocab/unit/MilliC',
#                                                      'http://qudt.org/vocab/unit/MicroC',
#                                                      'http://qudt.org/vocab/unit/TeraC',
#                                                      'http://qudt.org/vocab/unit/FemtoC',
#                                                      'http://qudt.org/vocab/unit/DecaC',
#                                                      'http://qudt.org/vocab/unit/NanoC',
#                                                      'http://qudt.org/vocab/unit/MegaC',
#                                                      'http://qudt.org/vocab/unit/AttoC',
#                                                      'http://qudt.org/vocab/unit/CentiC',
#                                                      'http://qudt.org/vocab/unit/KiloC',
#                                                      'http://qudt.org/vocab/unit/HectoC',
#                                                      'http://qudt.org/vocab/unit/YoctoC',
#                                                      'http://qudt.org/vocab/unit/YottaC',
#                                                      'http://qudt.org/vocab/unit/ExaC',
#                                                      'http://qudt.org/vocab/unit/GigaC',
#                                                      'http://qudt.org/vocab/unit/PetaC']},
#  'http://qudt.org/vocab/unit/C-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-M2-PER-V': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliC-PER-M2',
#                                                             'http://qudt.org/vocab/unit/C-PER-MilliM2',
#                                                             'http://qudt.org/vocab/unit/KiloC-PER-M2',
#                                                             'http://qudt.org/vocab/unit/C-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/MegaC-PER-M2',
#                                                             'http://qudt.org/vocab/unit/MicroC-PER-M2']},
#  'http://qudt.org/vocab/unit/C-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/GigaC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/C-PER-CentiM3',
#                                                             'http://qudt.org/vocab/unit/MilliC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/MegaC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/MicroC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/C-PER-MilliM3']},
#  'http://qudt.org/vocab/unit/C-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C2-M2-PER-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C3-M-PER-J2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C4-M4-PER-J3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CD-PER-LM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CD-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CFU': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliDEG_C']},
#  'http://qudt.org/vocab/unit/DEG_C-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-WK': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C2-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/EV': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaEV',
#                                                       'http://qudt.org/vocab/unit/KiloEV',
#                                                       'http://qudt.org/vocab/unit/GigaEV']},
#  'http://qudt.org/vocab/unit/EV-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/EV-PER-T': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/EV-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/ElementaryCharge': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/FARAD': {'prefixed_units': ['http://qudt.org/vocab/unit/NanoFARAD',
#                                                          'http://qudt.org/vocab/unit/AttoFARAD',
#                                                          'http://qudt.org/vocab/unit/PicoFARAD',
#                                                          'http://qudt.org/vocab/unit/MilliFARAD',
#                                                          'http://qudt.org/vocab/unit/MicroFARAD']},
#  'http://qudt.org/vocab/unit/FARAD-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/FARAD-PER-KiloM',
#                                                                'http://qudt.org/vocab/unit/PicoFARAD-PER-M',
#                                                                'http://qudt.org/vocab/unit/NanoFARAD-PER-M',
#                                                                'http://qudt.org/vocab/unit/MicroFARAD-PER-M']},
#  'http://qudt.org/vocab/unit/GM': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroGM',
#                                                       'http://qudt.org/vocab/unit/CentiGM',
#                                                       'http://qudt.org/vocab/unit/NanoGM',
#                                                       'http://qudt.org/vocab/unit/DeciGM',
#                                                       'http://qudt.org/vocab/unit/KiloGM',
#                                                       'http://qudt.org/vocab/unit/MegaGM',
#                                                       'http://qudt.org/vocab/unit/DecaGM',
#                                                       'http://qudt.org/vocab/unit/HectoGM',
#                                                       'http://qudt.org/vocab/unit/MilliGM',
#                                                       'http://qudt.org/vocab/unit/PicoGM']},
#  'http://qudt.org/vocab/unit/GM-PER-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/NanoGM-PER-DAY',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-DAY',
#                                                               'http://qudt.org/vocab/unit/MilliGM-PER-DAY']},
#  'http://qudt.org/vocab/unit/GM-PER-DEG_C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/GM-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/GM-PER-KiloGM',
#                                                              'http://qudt.org/vocab/unit/MicroGM-PER-GM',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-KiloGM',
#                                                              'http://qudt.org/vocab/unit/MilliGM-PER-GM',
#                                                              'http://qudt.org/vocab/unit/PicoGM-PER-GM']},
#  'http://qudt.org/vocab/unit/GM-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-HR',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-HR']},
#  'http://qudt.org/vocab/unit/GM-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/GM-PER-DeciL',
#                                                             'http://qudt.org/vocab/unit/GM-PER-MilliL',
#                                                             'http://qudt.org/vocab/unit/FemtoGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/MilliGM-PER-MilliL',
#                                                             'http://qudt.org/vocab/unit/MilliGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/PicoGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/KiloGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/MicroGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/NanoGM-PER-L']},
#  'http://qudt.org/vocab/unit/GM-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-M',
#                                                             'http://qudt.org/vocab/unit/GM-PER-KiloM',
#                                                             'http://qudt.org/vocab/unit/GM-PER-MilliM',
#                                                             'http://qudt.org/vocab/unit/KiloGM-PER-M']},
#  'http://qudt.org/vocab/unit/GM-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-M2',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-KiloM2',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-M2',
#                                                              'http://qudt.org/vocab/unit/GM-PER-CentiM2']},
#  'http://qudt.org/vocab/unit/GM-PER-M2-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroGM-PER-M2-DAY',
#                                                                  'http://qudt.org/vocab/unit/MilliGM-PER-M2-DAY']},
#  'http://qudt.org/vocab/unit/GM-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/GM-PER-CentiM3',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/GM-PER-DeciM3',
#                                                              'http://qudt.org/vocab/unit/MilliGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/NanoGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/MicroGM-PER-M3']},
#  'http://qudt.org/vocab/unit/GM-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-MIN',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-MIN']},
#  'http://qudt.org/vocab/unit/GM-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloGM-PER-MOL',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-KiloMOL']},
#  'http://qudt.org/vocab/unit/GM-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-SEC',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-SEC']},
#  'http://qudt.org/vocab/unit/GON': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/GRAIN-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/GRAY-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/H': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliH',
#                                                      'http://qudt.org/vocab/unit/MicroH',
#                                                      'http://qudt.org/vocab/unit/NanoH',
#                                                      'http://qudt.org/vocab/unit/PicoH']},
#  'http://qudt.org/vocab/unit/H-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroH-PER-M',
#                                                            'http://qudt.org/vocab/unit/NanoH-PER-M']},
#  'http://qudt.org/vocab/unit/H-PER-OHM': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroH-PER-OHM',
#                                                              'http://qudt.org/vocab/unit/MilliH-PER-OHM',
#                                                              'http://qudt.org/vocab/unit/H-PER-KiloOHM']},
#  'http://qudt.org/vocab/unit/HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/HZ-M': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaHZ-M',
#                                                         'http://qudt.org/vocab/unit/MegaHZ-M']},
#  'http://qudt.org/vocab/unit/HZ-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaHZ-PER-K']},
#  'http://qudt.org/vocab/unit/HZ-PER-T': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaHZ-PER-T']},
#  'http://qudt.org/vocab/unit/HZ-PER-V': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloJ',
#                                                      'http://qudt.org/vocab/unit/MegaJ',
#                                                      'http://qudt.org/vocab/unit/PetaJ',
#                                                      'http://qudt.org/vocab/unit/AttoJ',
#                                                      'http://qudt.org/vocab/unit/MilliJ',
#                                                      'http://qudt.org/vocab/unit/FemtoJ',
#                                                      'http://qudt.org/vocab/unit/ExaJ',
#                                                      'http://qudt.org/vocab/unit/GigaJ',
#                                                      'http://qudt.org/vocab/unit/TeraJ']},
#  'http://qudt.org/vocab/unit/J-M-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloJ-PER-KiloGM',
#                                                             'http://qudt.org/vocab/unit/J-PER-KiloGM',
#                                                             'http://qudt.org/vocab/unit/MilliJ-PER-GM']},
#  'http://qudt.org/vocab/unit/J-PER-GM-DEG_C': {'prefixed_units': ['http://qudt.org/vocab/unit/J-PER-KiloGM-DEG_C']},
#  'http://qudt.org/vocab/unit/J-PER-GM-K': {'prefixed_units': ['http://qudt.org/vocab/unit/J-PER-KiloGM-K',
#                                                               'http://qudt.org/vocab/unit/KiloJ-PER-KiloGM-K']},
#  'http://qudt.org/vocab/unit/J-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaJ-PER-HR',
#                                                             'http://qudt.org/vocab/unit/MegaJ-PER-HR']},
#  'http://qudt.org/vocab/unit/J-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloJ-PER-K']},
#  'http://qudt.org/vocab/unit/J-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliJ-PER-M2',
#                                                             'http://qudt.org/vocab/unit/MegaJ-PER-M2',
#                                                             'http://qudt.org/vocab/unit/J-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/GigaJ-PER-M2']},
#  'http://qudt.org/vocab/unit/J-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaJ-PER-M3']},
#  'http://qudt.org/vocab/unit/J-PER-M3-K': {'prefixed_units': ['http://qudt.org/vocab/unit/J-PER-CentiM3-K']},
#  'http://qudt.org/vocab/unit/J-PER-M4': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloJ-PER-MOL']},
#  'http://qudt.org/vocab/unit/J-PER-MOL-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaJ-PER-SEC']},
#  'http://qudt.org/vocab/unit/J-PER-T': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-T2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/AttoJ-SEC']},
#  'http://qudt.org/vocab/unit/J-SEC-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-M-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-M-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PA-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-T': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/KAT': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/KAT-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/PicoKAT-PER-L',
#                                                              'http://qudt.org/vocab/unit/NanoKAT-PER-L',
#                                                              'http://qudt.org/vocab/unit/KAT-PER-MicroL',
#                                                              'http://qudt.org/vocab/unit/MilliKAT-PER-L',
#                                                              'http://qudt.org/vocab/unit/MicroKAT-PER-L']},
#  'http://qudt.org/vocab/unit/L': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroL',
#                                                      'http://qudt.org/vocab/unit/MilliL',
#                                                      'http://qudt.org/vocab/unit/DecaL',
#                                                      'http://qudt.org/vocab/unit/HectoL',
#                                                      'http://qudt.org/vocab/unit/NanoL',
#                                                      'http://qudt.org/vocab/unit/DeciL',
#                                                      'http://qudt.org/vocab/unit/MegaL',
#                                                      'http://qudt.org/vocab/unit/KiloL',
#                                                      'http://qudt.org/vocab/unit/PicoL',
#                                                      'http://qudt.org/vocab/unit/FemtoL']},
#  'http://qudt.org/vocab/unit/L-PER-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-DAY']},
#  'http://qudt.org/vocab/unit/L-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-HR',
#                                                             'http://qudt.org/vocab/unit/KiloL-PER-HR']},
#  'http://qudt.org/vocab/unit/L-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-K']},
#  'http://qudt.org/vocab/unit/L-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-MIN']},
#  'http://qudt.org/vocab/unit/L-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/L-PER-MicroMOL']},
#  'http://qudt.org/vocab/unit/L-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-SEC']},
#  'http://qudt.org/vocab/unit/L-PER-SEC-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LM-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LM-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LUX': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LUX-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciM',
#                                                      'http://qudt.org/vocab/unit/HectoM',
#                                                      'http://qudt.org/vocab/unit/FemtoM',
#                                                      'http://qudt.org/vocab/unit/NanoM',
#                                                      'http://qudt.org/vocab/unit/MicroM',
#                                                      'http://qudt.org/vocab/unit/CentiM',
#                                                      'http://qudt.org/vocab/unit/KiloM',
#                                                      'http://qudt.org/vocab/unit/DecaM',
#                                                      'http://qudt.org/vocab/unit/PicoM',
#                                                      'http://qudt.org/vocab/unit/MilliM']},
#  'http://qudt.org/vocab/unit/M-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M-K-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M-PER-FARAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliM-PER-HR',
#                                                             'http://qudt.org/vocab/unit/CentiM-PER-HR',
#                                                             'http://qudt.org/vocab/unit/KiloM-PER-HR']},
#  'http://qudt.org/vocab/unit/M-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroM-PER-K',
#                                                            'http://qudt.org/vocab/unit/MilliM-PER-K',
#                                                            'http://qudt.org/vocab/unit/CentiM-PER-K']},
#  'http://qudt.org/vocab/unit/M-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroM-PER-MIN',
#                                                              'http://qudt.org/vocab/unit/MilliM-PER-MIN']},
#  'http://qudt.org/vocab/unit/M-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloM-PER-SEC',
#                                                              'http://qudt.org/vocab/unit/MilliM-PER-SEC',
#                                                              'http://qudt.org/vocab/unit/CentiM-PER-SEC',
#                                                              'http://qudt.org/vocab/unit/MicroM-PER-SEC']},
#  'http://qudt.org/vocab/unit/M-PER-SEC2': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM-PER-SEC2']},
#  'http://qudt.org/vocab/unit/M-PER-YR': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM-PER-YR',
#                                                             'http://qudt.org/vocab/unit/MilliM-PER-YR']},
#  'http://qudt.org/vocab/unit/M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroM2',
#                                                       'http://qudt.org/vocab/unit/MilliM2',
#                                                       'http://qudt.org/vocab/unit/CentiM2',
#                                                       'http://qudt.org/vocab/unit/DeciM2',
#                                                       'http://qudt.org/vocab/unit/NanoM2']},
#  'http://qudt.org/vocab/unit/M2-HZ': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-HZ2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-HZ3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-HZ4': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-K-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/M2-PER-KiloGM']},
#  'http://qudt.org/vocab/unit/M2-PER-HZ': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-HZ2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-N': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM2-PER-SEC',
#                                                               'http://qudt.org/vocab/unit/MilliM2-PER-SEC']},
#  'http://qudt.org/vocab/unit/M2-PER-SEC2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloM2-PER-SEC2']},
#  'http://qudt.org/vocab/unit/M2-PER-SEC2-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-SR-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-V-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM2-PER-V-SEC']},
#  'http://qudt.org/vocab/unit/M2-PER-W': {'prefixed_units': ['http://qudt.org/vocab/unit/M2-PER-KiloW']},
#  'http://qudt.org/vocab/unit/M2-SEC-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroM3',
#                                                       'http://qudt.org/vocab/unit/MilliM3',
#                                                       'http://qudt.org/vocab/unit/DeciM3',
#                                                       'http://qudt.org/vocab/unit/CentiM3',
#                                                       'http://qudt.org/vocab/unit/DecaM3']},
#  'http://qudt.org/vocab/unit/M3-PER-C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3-PER-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-DAY',
#                                                               'http://qudt.org/vocab/unit/DeciM3-PER-DAY']},
#  'http://qudt.org/vocab/unit/M3-PER-HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciM3-PER-HR',
#                                                              'http://qudt.org/vocab/unit/CentiM3-PER-HR']},
#  'http://qudt.org/vocab/unit/M3-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-K']},
#  'http://qudt.org/vocab/unit/M3-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-MIN',
#                                                               'http://qudt.org/vocab/unit/DeciM3-PER-MIN']},
#  'http://qudt.org/vocab/unit/M3-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-MOL',
#                                                               'http://qudt.org/vocab/unit/DeciM3-PER-MOL']},
#  'http://qudt.org/vocab/unit/M3-PER-MOL-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-MOL-SEC']},
#  'http://qudt.org/vocab/unit/M3-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-SEC',
#                                                               'http://qudt.org/vocab/unit/DeciM3-PER-SEC']},
#  'http://qudt.org/vocab/unit/M3-PER-SEC2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloM3-PER-SEC2']},
#  'http://qudt.org/vocab/unit/M3-PER-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M4': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM4',
#                                                       'http://qudt.org/vocab/unit/MilliM4']},
#  'http://qudt.org/vocab/unit/M4-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M5': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M6': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM6']},
#  'http://qudt.org/vocab/unit/MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MIN_Angle': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MO': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloMOL',
#                                                        'http://qudt.org/vocab/unit/FemtoMOL',
#                                                        'http://qudt.org/vocab/unit/MicroMOL',
#                                                        'http://qudt.org/vocab/unit/MilliMOL']},
#  'http://qudt.org/vocab/unit/MOL-DEG_C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-GM-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-GM-HR']},
#  'http://qudt.org/vocab/unit/MOL-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloMOL-PER-HR']},
#  'http://qudt.org/vocab/unit/MOL-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/FemtoMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/NanoMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/PicoMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/MilliMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/CentiMOL-PER-L']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliMOL-PER-M2',
#                                                               'http://qudt.org/vocab/unit/MicroMOL-PER-M2']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-M2-DAY',
#                                                                   'http://qudt.org/vocab/unit/PicoMOL-PER-M2-DAY',
#                                                                   'http://qudt.org/vocab/unit/NanoMOL-PER-M2-DAY',
#                                                                   'http://qudt.org/vocab/unit/MilliMOL-PER-M2-DAY']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-M2-SEC',
#                                                                   'http://qudt.org/vocab/unit/MilliMOL-PER-M2-SEC']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC-M-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/PicoMOL-PER-M3',
#                                                               'http://qudt.org/vocab/unit/MOL-PER-DeciM3',
#                                                               'http://qudt.org/vocab/unit/MilliMOL-PER-M3',
#                                                               'http://qudt.org/vocab/unit/KiloMOL-PER-M3']},
#  'http://qudt.org/vocab/unit/MOL-PER-M3-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/PicoMOL-PER-M3-SEC']},
#  'http://qudt.org/vocab/unit/MOL-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloMOL-PER-MIN']},
#  'http://qudt.org/vocab/unit/MOL-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliMOL-PER-MOL',
#                                                                'http://qudt.org/vocab/unit/MicroMOL-PER-MOL']},
#  'http://qudt.org/vocab/unit/MOL-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-SEC',
#                                                                'http://qudt.org/vocab/unit/KiloMOL-PER-SEC']},
#  'http://qudt.org/vocab/unit/N': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliN',
#                                                      'http://qudt.org/vocab/unit/MegaN',
#                                                      'http://qudt.org/vocab/unit/MicroN',
#                                                      'http://qudt.org/vocab/unit/KiloN']},
#  'http://qudt.org/vocab/unit/N-M': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciN-M',
#                                                        'http://qudt.org/vocab/unit/MegaN-M',
#                                                        'http://qudt.org/vocab/unit/MilliN-M',
#                                                        'http://qudt.org/vocab/unit/CentiN-M',
#                                                        'http://qudt.org/vocab/unit/N-CentiM',
#                                                        'http://qudt.org/vocab/unit/KiloN-M',
#                                                        'http://qudt.org/vocab/unit/MicroN-M']},
#  'http://qudt.org/vocab/unit/N-M-PER-A': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-M-PER-M']},
#  'http://qudt.org/vocab/unit/N-M-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-SEC-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-M2']},
#  'http://qudt.org/vocab/unit/N-M2-PER-A': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-PER-A': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-PER-C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-PER-M',
#                                                            'http://qudt.org/vocab/unit/MilliN-PER-M',
#                                                            'http://qudt.org/vocab/unit/N-PER-MilliM',
#                                                            'http://qudt.org/vocab/unit/N-PER-CentiM']},
#  'http://qudt.org/vocab/unit/N-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-PER-M2',
#                                                             'http://qudt.org/vocab/unit/N-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/N-PER-MilliM2']},
#  'http://qudt.org/vocab/unit/N-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-PER-M3']},
#  'http://qudt.org/vocab/unit/N-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/NP': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/NUM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/OHM': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaOHM',
#                                                        'http://qudt.org/vocab/unit/KiloOHM',
#                                                        'http://qudt.org/vocab/unit/MicroOHM',
#                                                        'http://qudt.org/vocab/unit/GigaOHM',
#                                                        'http://qudt.org/vocab/unit/MilliOHM',
#                                                        'http://qudt.org/vocab/unit/TeraOHM']},
#  'http://qudt.org/vocab/unit/OHM-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/OHM-M2-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaPA',
#                                                       'http://qudt.org/vocab/unit/MicroPA',
#                                                       'http://qudt.org/vocab/unit/DecaPA',
#                                                       'http://qudt.org/vocab/unit/MilliPA',
#                                                       'http://qudt.org/vocab/unit/GigaPA',
#                                                       'http://qudt.org/vocab/unit/KiloPA',
#                                                       'http://qudt.org/vocab/unit/HectoPA']},
#  'http://qudt.org/vocab/unit/PA-L-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaPA-L-PER-SEC',
#                                                                 'http://qudt.org/vocab/unit/HectoPA-L-PER-SEC']},
#  'http://qudt.org/vocab/unit/PA-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-M-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-M-PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-M3-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaPA-M3-PER-SEC',
#                                                                  'http://qudt.org/vocab/unit/HectoPA-M3-PER-SEC']},
#  'http://qudt.org/vocab/unit/PA-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/HectoPA-PER-HR']},
#  'http://qudt.org/vocab/unit/PA-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaPA-PER-K',
#                                                             'http://qudt.org/vocab/unit/KiloPA-PER-K',
#                                                             'http://qudt.org/vocab/unit/HectoPA-PER-K']},
#  'http://qudt.org/vocab/unit/PA-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliPA-SEC']},
#  'http://qudt.org/vocab/unit/PA-SEC-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA2-PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA2-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-EV2': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-GigaEV2']},
#  'http://qudt.org/vocab/unit/PER-GM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-H': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-J-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-J2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-MilliL']},
#  'http://qudt.org/vocab/unit/PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-KiloM',
#                                                          'http://qudt.org/vocab/unit/PER-MilliM',
#                                                          'http://qudt.org/vocab/unit/PER-PicoM',
#                                                          'http://qudt.org/vocab/unit/PER-CentiM',
#                                                          'http://qudt.org/vocab/unit/PER-NanoM',
#                                                          'http://qudt.org/vocab/unit/PER-MicroM']},
#  'http://qudt.org/vocab/unit/PER-M-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M2-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-CentiM3',
#                                                           'http://qudt.org/vocab/unit/PER-MilliM3']},
#  'http://qudt.org/vocab/unit/PER-M3-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-PA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-PA-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC-M2-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-T-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-T-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-WB': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PH': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PPTR_VOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/R': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloR',
#                                                      'http://qudt.org/vocab/unit/MilliR']},
#  'http://qudt.org/vocab/unit/RAD': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroRAD',
#                                                        'http://qudt.org/vocab/unit/MilliRAD']},
#  'http://qudt.org/vocab/unit/RAD-M2-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/S': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliS',
#                                                      'http://qudt.org/vocab/unit/MicroS',
#                                                      'http://qudt.org/vocab/unit/KiloS']},
#  'http://qudt.org/vocab/unit/S-M2-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/S-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/PicoS-PER-M',
#                                                            'http://qudt.org/vocab/unit/KiloS-PER-M',
#                                                            'http://qudt.org/vocab/unit/DeciS-PER-M',
#                                                            'http://qudt.org/vocab/unit/S-PER-CentiM',
#                                                            'http://qudt.org/vocab/unit/MicroS-PER-M',
#                                                            'http://qudt.org/vocab/unit/MegaS-PER-M',
#                                                            'http://qudt.org/vocab/unit/NanoS-PER-M',
#                                                            'http://qudt.org/vocab/unit/MilliS-PER-M']},
#  'http://qudt.org/vocab/unit/SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliSEC',
#                                                        'http://qudt.org/vocab/unit/KiloSEC',
#                                                        'http://qudt.org/vocab/unit/AttoSEC',
#                                                        'http://qudt.org/vocab/unit/DeciSEC',
#                                                        'http://qudt.org/vocab/unit/PicoSEC',
#                                                        'http://qudt.org/vocab/unit/FemtoSEC',
#                                                        'http://qudt.org/vocab/unit/MicroSEC',
#                                                        'http://qudt.org/vocab/unit/NanoSEC']},
#  'http://qudt.org/vocab/unit/SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/SEC-PER-RAD-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/T': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliT',
#                                                      'http://qudt.org/vocab/unit/NanoT',
#                                                      'http://qudt.org/vocab/unit/MicroT']},
#  'http://qudt.org/vocab/unit/T-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/T-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-HA-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-YR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloTONNE-PER-YR']},
#  'http://qudt.org/vocab/unit/TON_Metric': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloTON_Metric',
#                                                               'http://qudt.org/vocab/unit/DeciTON_Metric']},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaV',
#                                                      'http://qudt.org/vocab/unit/MilliV',
#                                                      'http://qudt.org/vocab/unit/KiloV',
#                                                      'http://qudt.org/vocab/unit/MicroV']},
#  'http://qudt.org/vocab/unit/V-A': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V-A-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloV-A-HR',
#                                                           'http://qudt.org/vocab/unit/MegaV-A-HR']},
#  'http://qudt.org/vocab/unit/V-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroV-PER-M',
#                                                            'http://qudt.org/vocab/unit/KiloV-PER-M',
#                                                            'http://qudt.org/vocab/unit/V-PER-MilliM',
#                                                            'http://qudt.org/vocab/unit/MilliV-PER-M',
#                                                            'http://qudt.org/vocab/unit/V-PER-CentiM',
#                                                            'http://qudt.org/vocab/unit/MegaV-PER-M']},
#  'http://qudt.org/vocab/unit/V-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/V-PER-MicroSEC']},
#  'http://qudt.org/vocab/unit/V-SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V2-PER-K2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroW',
#                                                      'http://qudt.org/vocab/unit/TeraW',
#                                                      'http://qudt.org/vocab/unit/KiloW',
#                                                      'http://qudt.org/vocab/unit/NanoW',
#                                                      'http://qudt.org/vocab/unit/MilliW',
#                                                      'http://qudt.org/vocab/unit/PicoW',
#                                                      'http://qudt.org/vocab/unit/GigaW',
#                                                      'http://qudt.org/vocab/unit/MegaW']},
#  'http://qudt.org/vocab/unit/W-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaW-HR',
#                                                         'http://qudt.org/vocab/unit/TeraW-HR',
#                                                         'http://qudt.org/vocab/unit/KiloW-HR',
#                                                         'http://qudt.org/vocab/unit/MegaW-HR']},
#  'http://qudt.org/vocab/unit/W-HR-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloW-HR-PER-M2']},
#  'http://qudt.org/vocab/unit/W-HR-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-M-PER-M2-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-M2-PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliW-PER-MilliGM',
#                                                             'http://qudt.org/vocab/unit/W-PER-KiloGM']},
#  'http://qudt.org/vocab/unit/W-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/W-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/MilliW-PER-M2',
#                                                             'http://qudt.org/vocab/unit/PicoW-PER-M2',
#                                                             'http://qudt.org/vocab/unit/MicroW-PER-M2']},
#  'http://qudt.org/vocab/unit/W-PER-M2-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M2-K4': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M2-M': {'prefixed_units': ['http://qudt.org/vocab/unit/W-PER-M2-NanoM']},
#  'http://qudt.org/vocab/unit/W-PER-M2-M-SR': {'prefixed_units': ['http://qudt.org/vocab/unit/W-PER-M2-NanoM-SR']},
#  'http://qudt.org/vocab/unit/W-PER-M2-PA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-SEC-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/WB': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliWB']},
#  'http://qudt.org/vocab/unit/WB-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/WB-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/WB-PER-MilliM',
#                                                             'http://qudt.org/vocab/unit/KiloWB-PER-M']},
#  'http://qudt.org/vocab/unit/WK': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/YR': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaYR']},
#  'http://qudt.org/vocab/unit/YR_TROPICAL': {'prefixed_units': []}}

# %% [markdown]
# ## Fetch OSL Schema for UnitPrefix, QuantityUnit, QuantityUnit

# %%
from osw.core import OSW
from osw.express import OswExpress
import osw.model.entity as model


required_schemas = [
    "Category:OSW99e0f46a40ca4129a420b4bb89c4cc45",  # Unit prefix
    "Category:OSWd2520fa016844e01af0097a85bb25b25",  # Quantity Unit
    "Category:OSW00fbd6feecb5408997ca18d4e681a131",  # Quantity Kind
    "Category:OSW08271a9eb60248a3a5cb7a13346255eb",  # Composed Quantity Unit with Unit Prefix (Ausreiser)
]


def update_local_osw(osw_obj):
    print("fetch schemas")
    osw_obj.fetch_schema(
        OSW.FetchSchemaParam(
            schema_title=required_schemas,
            mode="replace",
        )
    )


if __name__ == "__main__":
    # Authentication
    osw_obj = OswExpress(
        domain="wiki-dev.open-semantic-lab.org",  # cred_filepath=pwd_file_path
    )
    update_local_osw(osw_obj)
# Out:
# c:\Users\raeder\AppData\Local\pypoetry\Cache\virtualenvs\quantities-units-W4YBs7Av-py3.12\Lib\site-packages\osw\utils\strings.py:58: FutureWarning: Possible nested set at position 16
#   self.pattern = re.compile(self.pattern)
# c:\Users\raeder\AppData\Local\pypoetry\Cache\virtualenvs\quantities-units-W4YBs7Av-py3.12\Lib\site-packages\osw\express.py:323: UserWarning: An exception occurred while loading the module dependencies:
# 'module 'osw.model.entity' has no attribute 'File''You will be now have to connect to an OSW instance to fetch the dependencies from!
#   warn(
# Fetch Category:OSW3e3f5dd4f71842fbb8f270e511af8031
# Fetch Category:OSWff333fd349af4f65a69100405a9e60c7
# Fetch Category:OSW2ac4493f8635481eaf1db961b63c8325
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW11a53cdfbdc24524bf8ac435cbf65d9d
# Fetch Category:OSW05b244d0a669436e96fe4e1631d5a171
# Fetch Category:OSWff333fd349af4f65a69100405a9e60c7
# Fetch Category:OSW2ac4493f8635481eaf1db961b63c8325
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# ReadAccess
# AccessRestrictions
# Label
# Description
# WikiPage
# Meta
# Entity
# ObjectStatement
# DataStatement
# QuantityStatement
# Item
# Data
# File
# LocalFile
# c:\Users\raeder\AppData\Local\pypoetry\Cache\virtualenvs\quantities-units-W4YBs7Av-py3.12\Lib\site-packages\osw\express.py:335: UserWarning: Dependencies specified in the module 'osw.express' have been fetched from OSW:
# {'LocalFile': 'Category:OSW3e3f5dd4f71842fbb8f270e511af8031', 'WikiFile': 'Category:OSW11a53cdfbdc24524bf8ac435cbf65d9d'}
# Its recommended to restart the kernel, to apply all changes seamlessly.
#   warn(
# fetch schemas
# Fetch Category:OSW99e0f46a40ca4129a420b4bb89c4cc45
# Fetch Category:OSWd02741381aaa4709ae0753a0edc341ce
# Fetch Category:OSWcbb09a36336740c6a2cd62db9bf647ec
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSWd2520fa016844e01af0097a85bb25b25
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# ReadAccess
# AccessRestrictions
# Label
# Description
# WikiPage
# Meta
# Characteristic
# OntologyRelated
# Entity
# ObjectStatement
# DataStatement
# QuantityStatement
# Item
# IntangibleItem
# Enumeration
# Fetch Category:OSW00fbd6feecb5408997ca18d4e681a131
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# ReadAccess
# AccessRestrictions
# Label
# Description
# WikiPage
# Meta
# Characteristic
# OntologyRelated
# Entity
# ObjectStatement
# DataStatement
# QuantityStatement
# Item
# IntangibleItem
# Enumeration
# PrefixUnit
# Fetch Category:OSW08271a9eb60248a3a5cb7a13346255eb
# Fetch Category:OSWd2520fa016844e01af0097a85bb25b25
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSWd2520fa016844e01af0097a85bb25b25
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# ReadAccess
# AccessRestrictions
# Label
# Description
# WikiPage
# Meta
# Characteristic
# OntologyRelated
# Entity
# ObjectStatement
# DataStatement
# QuantityStatement
# Item
# IntangibleItem
# Enumeration
# PrefixUnit

# %% [markdown]
# ## Instanciate Example QuantityUnit (former Unit of Measure)

# %%
from pprint import pprint

title = "Item:OSWc73852e7049f42e7b5282866f3839f5e"  # Meter


meter_u = osw_obj.load_entity(title)


pprint(meter_u)
# Out:
# Fetch Category:OSW7199b9568d96476cacfe30060c64f371
# Fetch Category:OSWd2520fa016844e01af0097a85bb25b25
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# ReadAccess
# AccessRestrictions
# Label
# Description
# WikiPage
# Meta
# Characteristic
# OntologyRelated
# Entity
# ObjectStatement
# DataStatement
# QuantityStatement
# Item
# IntangibleItem
# Enumeration
# PrefixUnit
# Items
# BaseUnitOfMeasure(type=['Category:OSW7199b9568d96476cacfe30060c64f371'], uuid=UUID('c73852e7-049f-42e7-b528-2866f3839f5e'), exact_ontology_match=['https://qudt.org/vocab/unit/M', 'https://si-digital-framework.org/SI/units/metre', ' http://dbpedia.org/resource/Metre ', 'http://www.ontology-of-units-of-measure.org/resource/om-2/metre', 'urn:samm:org.eclipse.esmf.samm:unit:2.1.0#m'], close_ontology_match=None, rdf_type=None, iri=None, name='Meter', label=[Label(text='Meter', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=Meta(wiki_page=WikiPage(title='OSWc73852e7049f42e7b5282866f3839f5e', namespace='Item'), change_id=None), entry_access=None, main_symbol='m', conversion_factor_from_si=None, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='f454ccd2-582d-4727-9a2e-05e2b6f83c5a', exact_ontology_match=['https://qudt.org/vocab/unit/KiloM', ' http://dbpedia.org/resource/Kilometre ', 'urn:samm:org.eclipse.esmf.samm:unit:2.1.0#km'], close_ontology_match=None, osw_id='Item:OSWc73852e7049f42e7b5282866f3839f5e#OSWf454ccd2582d47279a2e05e2b6f83c5a', conversion_factor_from_si=None, prefix='Item:OSW9aae9552adf34f139f6766876a8d7c59', prefix_symbol='k', main_symbol='km'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='eb12f149-b594-4ded-bf96-018b953a8195', exact_ontology_match=['https://qudt.org/vocab/unit/MilliM', ' http://dbpedia.org/resource/Millimetre ', 'urn:samm:org.eclipse.esmf.samm:unit:2.1.0#mm'], close_ontology_match=None, osw_id='Item:OSWc73852e7049f42e7b5282866f3839f5e#OSWeb12f149b5944dedbf96018b953a8195', conversion_factor_from_si=None, prefix='Item:OSWa404be342a6b4b47ae1fd6f95cb7ab81', prefix_symbol='m', main_symbol='mm')])

# %% [markdown]
# ## Fetch Units from Ontology and complete properties of unit dictionary

# %%
from utils import sparql_wrapper
from pprint import pprint

sparql_qudt_unit_params = sparql_wrapper.Sparql(
    endpoint="https://www.qudt.org/fuseki/qudt/sparql",
    src_filepath="../ontology/qudt/sparql/units.sparql",
    tgt_filepath="../ontology/qudt/data/units.json",
    debug=False,
)
qudt_units_param_res = sparql_qudt_unit_params.execQuery()
sparql_qudt_unit_params.writeJsonFile(data=qudt_units_param_res)
print(
    f"num results.bindings: {len(qudt_units_param_res['results']['bindings'])}"
)
pprint(qudt_units_param_res)
# Out:
# Reading SPARQL Query from c:\Users\raeder\Desktop\dev\Gitlab\osw\apps\python-lvl2\quantities-units\src\quantities-units\utils\../ontology/qudt/sparql/units.sparql
# Writing JSON data to c:\Users\raeder\Desktop\dev\Gitlab\osw\apps\python-lvl2\quantities-units\src\quantities-units\utils\../ontology/qudt/data/units.json
# num results.bindings: 950
# {'head': {'vars': ['applicableUnit',
#                    'dimensionVector',
#                    'symbol',
#                    'conversionMultiplierSN',
#                    'dbpediaMatch',
#                    'siExactMatch',
#                    'plainTextDescription',
#                    'description',
#                    'ucumCodes',
#                    'applicableSystems',
#                    'qlabels']},
#  'results': {'bindings': [{'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS, '
#                                                           'http://qudt.org/vocab/sou/IMPERIAL, '
#                                                           'http://qudt.org/vocab/sou/USCS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/PER-WK'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.653439E-6'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'reciprocal of the unit '
#                                                     'week'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H0T-1D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': 'reciprocal of '
#                                                              'the unit week'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reciprocal Week@en'},
#                            'symbol': {'type': 'literal', 'value': '/wk'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/wk, wk-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/NanoM'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0E-9'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '0.000000001-fold of the '
#                                                     'SI base unit metre'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L1I0M0H0T0D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '0.000000001-fold '
#                                                              'of the SI base '
#                                                              'unit metre'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Nanometre@en'},
#                            'symbol': {'type': 'literal', 'value': 'nm'},
#                            'ucumCodes': {'type': 'literal', 'value': 'nm'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/M2-PER-KiloW'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '0.001e0'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M-1H0T3D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': 'A common unit '
#                                                              'for measuring '
#                                                              'area per power'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'square metre per Kilowatt@en'},
#                            'symbol': {'type': 'literal', 'value': 'm²/kW'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2.kW-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/K-PER-W'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '<p>Thermal resistance is '
#                                                     'a heat property and a '
#                                                     'measure of a temperature '
#                                                     'difference by which an '
#                                                     'object or material '
#                                                     'resists a heat flow (heat '
#                                                     'per time unit or thermal '
#                                                     'resistance). Thermal '
#                                                     'resistance is the '
#                                                     'reciprocal thermal '
#                                                     'conductance. Absolute '
#                                                     'thermal resistance is the '
#                                                     'temperature difference '
#                                                     'across a structure when a '
#                                                     'unit of heat energy flows '
#                                                     'through it in unit time. '
#                                                     'It is the reciprocal of '
#                                                     'thermal conductance. The '
#                                                     'SI units of thermal '
#                                                     'resistance are kelvins '
#                                                     'per watt or the '
#                                                     'equivalent degrees '
#                                                     'Celsius per watt (the two '
#                                                     'are the same since as '
#                                                     'intervals).</p>'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-2I0M-1H1T3D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Kelvin je Watt@de, kelvin per '
#                                                 'watt@en'},
#                            'symbol': {'type': 'literal', 'value': 'K/W'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'K.W-1, K/W'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS, '
#                                                           'http://qudt.org/vocab/sou/PLANCK'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/PicoA'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0E-12'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E1L0I0M0H0T0D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'picoampere@en'},
#                            'symbol': {'type': 'literal', 'value': 'pA'},
#                            'ucumCodes': {'type': 'literal', 'value': 'pA'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/MegaL'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '1 000 000-fold of the '
#                                                     'unit litre'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L3I0M0H0T0D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '1 000 000-fold '
#                                                              'of the unit '
#                                                              'litre'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Megalitre@en'},
#                            'symbol': {'type': 'literal', 'value': 'ML'},
#                            'ucumCodes': {'type': 'literal', 'value': 'ML'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/CentiM'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '0.01e0'},
#                            'dbpediaMatch': {'datatype': 'http://www.w3.org/2001/XMLSchema#anyURI',
#                                             'type': 'literal',
#                                             'value': 'http://dbpedia.org/resource/Centimetre'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': 'A centimetre is a unit of '
#                                                     'length in the metric '
#                                                     'system, equal to one '
#                                                     'hundredth of a metre, '
#                                                     'which is the SI base unit '
#                                                     'of length. Centi is the '
#                                                     'SI prefix for a factor of '
#                                                     '$10^{-2}$.  The '
#                                                     'centimetre is the base '
#                                                     'unit of length in the now '
#                                                     'deprecated '
#                                                     'centimetre-gram-second '
#                                                     '(CGS) system of units.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L1I0M0H0T0D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Centimetre@en'},
#                            'symbol': {'type': 'literal', 'value': 'cm'},
#                            'ucumCodes': {'type': 'literal', 'value': 'cm'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/DEG_C-PER-SEC'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': '$\\textit{Degree Celsius '
#                                                     'per Second}$ is a unit '
#                                                     "for 'Temperature Per "
#                                                     "Time' expressed as $degC "
#                                                     '/ s$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H1T-1D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Degree Celsius per Second@en'},
#                            'symbol': {'type': 'literal', 'value': '°C/s'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'Cel.s-1, Cel/s'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/PER-MicroM'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000000.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': 'Per Micrometer Unit is a '
#                                                     'denominator unit with '
#                                                     'dimensions $/microm$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M0H0T0D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reciprocal Micrometre@en'},
#                            'symbol': {'type': 'literal', 'value': '/µm'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/um, um-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/DecaPA'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '10.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '10-fold of the derived SI '
#                                                     'unit pascal'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M1H0T-2D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '10-fold of the '
#                                                              'derived SI unit '
#                                                              'pascal'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Decapascal@en'},
#                            'symbol': {'type': 'literal', 'value': 'daPa'},
#                            'ucumCodes': {'type': 'literal', 'value': 'daPa'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/CentiM2-PER-V-SEC'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0E-4'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E1L0I0M-1H0T2D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'square centimetre per volt '
#                                                 'second@en'},
#                            'symbol': {'type': 'literal', 'value': 'cm²/(V·s)'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'cm2.V-1.s-1, cm2/(V.s)'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/MicroSV-PER-HR'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '2.77778E-10'},
#                            'dbpediaMatch': {'datatype': 'http://www.w3.org/2001/XMLSchema#anyURI',
#                                             'type': 'literal',
#                                             'value': 'http://dbpedia.org/resource/Sievert'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '0.000001-fold of the '
#                                                     'derived SI unit sievert '
#                                                     'divided by the unit hour'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L2I0M0H0T-3D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'MicroSievert per hour@en'},
#                            'symbol': {'type': 'literal', 'value': 'µSv/hr'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'uSv.h-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/M3-PER-YR'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '3.168808781E-8'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'power of the SI base unit '
#                                                     'metre with the exponent 3 '
#                                                     'divided by the unit year'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L3I0M0H0T-1D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': 'cubic meter '
#                                                              'divided by the '
#                                                              'unit year with '
#                                                              '365 days'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Cubic Metre per Year@en'},
#                            'symbol': {'type': 'literal', 'value': 'm³/a'},
#                            'ucumCodes': {'type': 'literal', 'value': 'm3.a-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-ESU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS, '
#                                                           'http://qudt.org/vocab/sou/ASU, '
#                                                           'http://qudt.org/vocab/sou/IMPERIAL, '
#                                                           'http://qudt.org/vocab/sou/PLANCK'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/FRACTION'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'Fraction is a unit for '
#                                                     "'Dimensionless Ratio' "
#                                                     'expressed as the value of '
#                                                     'the ratio itself.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H0T0D1'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': 'Fraction is a '
#                                                              'unit for '
#                                                              "'Dimensionless "
#                                                              "Ratio' expressed "
#                                                              'as the value of '
#                                                              'the ratio '
#                                                              'itself.'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Fraction@en'},
#                            'symbol': {'type': 'literal', 'value': '÷'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '{fraction}'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/K-PER-SEC2'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': '$\\textit{Kelvin per '
#                                                     'Square Second}$ is a unit '
#                                                     "for 'Temperature Per Time "
#                                                     "Squared' expressed as $K "
#                                                     '/ s^2$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H1T-2D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Kelvin per Square Second@en'},
#                            'symbol': {'type': 'literal', 'value': 'K/s²'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'K.s-2, K/s^2'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/MilliM'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '0.001e0'},
#                            'dbpediaMatch': {'datatype': 'http://www.w3.org/2001/XMLSchema#anyURI',
#                                             'type': 'literal',
#                                             'value': 'http://dbpedia.org/resource/Millimetre'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'The millimetre '
#                                                     '(International spelling '
#                                                     'as used by the '
#                                                     'International Bureau of '
#                                                     'Weights and Measures) or '
#                                                     'millimeter (American '
#                                                     'spelling) (SI unit symbol '
#                                                     'mm) is a unit of length '
#                                                     'in the metric system, '
#                                                     'equal to one thousandth '
#                                                     'of a metre, which is the '
#                                                     'SI base unit of length. '
#                                                     'It is equal to 1000 '
#                                                     'micrometres or 1000000 '
#                                                     'nanometres. A millimetre '
#                                                     'is equal to exactly\u200a'
#                                                     '5/127 (approximately '
#                                                     '0.039370) of an inch.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L1I0M0H0T0D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Millimetre@en'},
#                            'symbol': {'type': 'literal', 'value': 'mm'},
#                            'ucumCodes': {'type': 'literal', 'value': 'mm'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/KiloV-PER-M'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '1 000-fold of the SI '
#                                                     'derived unit volt divided '
#                                                     'by the SI base unit '
#                                                     'metre'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E-1L1I0M1H0T-3D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '1 000-fold of '
#                                                              'the SI derived '
#                                                              'unit volt '
#                                                              'divided by the '
#                                                              'SI base unit '
#                                                              'metre'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Kilovolt per Metre@en'},
#                            'symbol': {'type': 'literal', 'value': 'kV/m'},
#                            'ucumCodes': {'type': 'literal', 'value': 'kV.m-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/KiloA-PER-M'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '1 000-fold of the SI base '
#                                                     'unit ampere divided by '
#                                                     'the SI base unit metre'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E1L-1I0M0H0T0D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '1 000-fold of '
#                                                              'the SI base unit '
#                                                              'ampere divided '
#                                                              'by the SI base '
#                                                              'unit metre'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Kiloampere per Metre@en'},
#                            'symbol': {'type': 'literal', 'value': 'kA/m'},
#                            'ucumCodes': {'type': 'literal', 'value': 'kA.m-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/PER-MilliM'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': 'Per Millimeter Unit is a '
#                                                     'denominator unit with '
#                                                     'dimensions $/mm$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M0H0T0D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reciprocal Millimetre@en'},
#                            'symbol': {'type': 'literal', 'value': '/mm'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/mm, mm-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/PER-EV2'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '3.89564405E37'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': 'Per Square Electron Volt '
#                                                     'is a denominator unit '
#                                                     'with dimensions $/eV^2$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-4I0M-2H0T4D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reciprocal Square Electron '
#                                                 'Volt@en'},
#                            'symbol': {'type': 'literal', 'value': '/eV²'},
#                            'ucumCodes': {'type': 'literal', 'value': 'eV-2'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/PER-M-K'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': 'Per Meter Kelvin Unit is '
#                                                     'a denominator unit with '
#                                                     'dimensions $/m.k$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M0H-1T0D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reciprocal Metre Kelvin@en'},
#                            'symbol': {'type': 'literal', 'value': '/(m·K)'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm-1.K-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/PER-CentiM3'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000000.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'reciprocal of the '
#                                                     '0.000001-fold of the '
#                                                     'power of the SI base unit '
#                                                     'metre with the exponent '
#                                                     '3'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-3I0M0H0T0D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': 'reciprocal of '
#                                                              'the '
#                                                              '0.000001-fold of '
#                                                              'the power of the '
#                                                              'SI base unit '
#                                                              'metre with the '
#                                                              'exponent 3'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reciprocal Cubic '
#                                                 'Centimetre@en'},
#                            'symbol': {'type': 'literal', 'value': '/cm³'},
#                            'ucumCodes': {'type': 'literal', 'value': 'cm-3'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/C-PER-CentiM3'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000000.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'derived SI unit coulomb '
#                                                     'divided by the 0.000 '
#                                                     '001-fold of the power of '
#                                                     'the SI base unit metre by '
#                                                     'exponent 3'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E1L-3I0M0H0T1D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': 'derived SI unit '
#                                                              'coulomb divided '
#                                                              'by the 0.000 '
#                                                              '001-fold of the '
#                                                              'power of the SI '
#                                                              'base unit metre '
# ...
#                                                     'the unit day'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M1H0T-1D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '0,001-fold of '
#                                                              'the SI base unit '
#                                                              'kilogram divided '
#                                                              'by the unit day'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Gram per Day@en'},
#                            'symbol': {'type': 'literal', 'value': 'g/day'},
#                            'ucumCodes': {'type': 'literal', 'value': 'g.d-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/GM-PER-MOL'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '0.001e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '0.01-fold of the SI base '
#                                                     'unit kilogram divided by '
#                                                     'the SI base unit mol'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A-1E0L0I0M1H0T0D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '0.01-fold of the '
#                                                              'SI base unit '
#                                                              'kilogram divided '
#                                                              'by the SI base '
#                                                              'unit mol'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Gram per Mole@en'},
#                            'symbol': {'type': 'literal', 'value': 'g/mol'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'g.mol-1, g/mol'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS, '
#                                                           'http://qudt.org/vocab/sou/IMPERIAL, '
#                                                           'http://qudt.org/vocab/sou/USCS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/MegaHZ'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000000.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': '"Megahertz" is a C.G.S '
#                                                     'System unit for  '
#                                                     "'Frequency' expressed as "
#                                                     '$MHz$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H0T-1D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Megahertz@en'},
#                            'symbol': {'type': 'literal', 'value': 'MHz'},
#                            'ucumCodes': {'type': 'literal', 'value': 'MHz'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/W-PER-M2-PA'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': 'Watt Per Square Meter Per '
#                                                     'Pascal ($W/m^2-pa$) is a '
#                                                     'unit of Evaporative Heat '
#                                                     'Transfer.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L1I0M0H0T-1D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Watt per Square Metre '
#                                                 'Pascal@en'},
#                            'symbol': {'type': 'literal', 'value': 'W/(m²·Pa)'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'W.m-2.Pa-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS, '
#                                                           'http://qudt.org/vocab/sou/IMPERIAL, '
#                                                           'http://qudt.org/vocab/sou/USCS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/MO'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '2551442.976e0'},
#                            'dbpediaMatch': {'datatype': 'http://www.w3.org/2001/XMLSchema#anyURI',
#                                             'type': 'literal',
#                                             'value': 'http://dbpedia.org/resource/Month'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'A unit of time '
#                                                     'corresponding '
#                                                     'approximately to one '
#                                                     "cycle of the moon's "
#                                                     'phases, or about 30 days '
#                                                     'or 4 weeks. Also known as '
#                                                     "the 'Synodic Month' and "
#                                                     'calculated as 29.53059 '
#                                                     'days.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H0T1D0'},
#                            'qlabels': {'type': 'literal', 'value': 'Month@en'},
#                            'symbol': {'type': 'literal', 'value': 'mo'},
#                            'ucumCodes': {'type': 'literal', 'value': 'mo'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/J-PER-M3-K'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0e0'},
#                            'description': {'datatype': 'http://qudt.org/schema/qudt/LatexString',
#                                            'type': 'literal',
#                                            'value': '$\\textit{Joule per Cubic '
#                                                     'Meter Kelvin}$ is a unit '
#                                                     "for 'Volumetric Heat "
#                                                     "Capacity' expressed as "
#                                                     '$J/(m^{3} K)$.'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M1H-1T-2D0'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Joule per Cubic Metre '
#                                                 'Kelvin@en'},
#                            'symbol': {'type': 'literal', 'value': 'J/(m³·K)'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J.m-3.K-1'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/KiloN-M'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1000.0e0'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': '1 000-fold of the product '
#                                                     'of the SI derived unit '
#                                                     'newton and the SI base '
#                                                     'unit metre'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L2I0M1H0T-2D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': '1 000-fold of '
#                                                              'the product of '
#                                                              'the SI derived '
#                                                              'unit newton and '
#                                                              'the SI base unit '
#                                                              'metre'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Kilonewton Metre@en'},
#                            'symbol': {'type': 'literal', 'value': 'kN·m'},
#                            'ucumCodes': {'type': 'literal', 'value': 'kN.m'}},
#                           {'applicableSystems': {'type': 'literal',
#                                                  'value': 'http://qudt.org/vocab/sou/SI, '
#                                                           'http://qudt.org/vocab/sou/CGS, '
#                                                           'http://qudt.org/vocab/sou/CGS-EMU, '
#                                                           'http://qudt.org/vocab/sou/CGS-GAUSS'},
#                            'applicableUnit': {'type': 'uri',
#                                               'value': 'http://qudt.org/vocab/unit/KiloGM-MilliM2'},
#                            'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                                       'type': 'literal',
#                                                       'value': '1.0E-6'},
#                            'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                                            'type': 'literal',
#                                            'value': 'product of the SI base '
#                                                     'kilogram and the  '
#                                                     '0.001-fold of the power '
#                                                     'of the SI base metre with '
#                                                     'the exponent 2'},
#                            'dimensionVector': {'type': 'uri',
#                                                'value': 'http://qudt.org/vocab/dimensionvector/A0E0L2I0M1H0T0D0'},
#                            'plainTextDescription': {'type': 'literal',
#                                                     'value': 'product of the '
#                                                              'SI base kilogram '
#                                                              'and the  '
#                                                              '0.001-fold of '
#                                                              'the power of the '
#                                                              'SI base metre '
#                                                              'with the '
#                                                              'exponent 2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Kilogram Square '
#                                                 'Millimetre@en'},
#                            'symbol': {'type': 'literal', 'value': 'kg·mm²'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'kg.mm2'}}]}}

# %%
# from jsonpath_ng import jsonpath, parse

# # use json path to extract all another info of same level in results.bindings where the identifier is results.bindings[*].applicableUnit.value and the value is "http://qudt.org/vocab/unit#Meter"
# jsonpath_expr = parse(
#     "$.results.bindings[?(@.applicableUnit.value == 'http://qudt.org/vocab/unit#Meter')]"
# )
# meter_unit_info = [match.value for match in jsonpath_expr.find(qudt_units_param_res)]

from jsonpath_ng.ext import parse
import uuid

# Use json path to extract all another info of same level in results.bindings where the identifier is results.bindings[*].applicableUnit.value and the value is "http://qudt.org/vocab/unit#Meter"
jsonpath_expr = parse(
    '$.results.bindings[?(@.applicableUnit.value = "http://qudt.org/vocab/unit/MilliPA-SEC")]'
)
# meter_unit_info = [match.value for match in jsonpath_expr.find(qudt_units_param_res)]
# pprint(meter_unit_info)

pprint(jsonpath_expr.find(qudt_units_param_res)[0].value)


def match_json_path_key(qudt_units_param_res, identifier="", key=""):
    jsonpath_expr = parse(
        f'$.results.bindings[?(@.applicableUnit.value = "{identifier}")].{key}.value'
    )
    return jsonpath_expr.find(qudt_units_param_res)[0].value


def match_object_json_path(qudt_units_param_res=None, identifier=""):
    # print(f"IDENTIFIER: {identifier}")
    jsonpath_expr = parse(
        f'$.results.bindings[?(@.applicableUnit.value = "{identifier}")]'
    )

    return jsonpath_expr.find(qudt_units_param_res)[0].value


def get_prefix_uuid(data=[], prefix=""):
    jsonpath_expr = parse(f'$[?(@.label = "{prefix}")].pid')
    return uuid.uuid5(
        namespace=uuid.NAMESPACE_URL, name=jsonpath_expr.find(data)[0].value
    )


# test
# pprint(
#     match_json_path_key(
#         qudt_units_param_res,
#         identifier="http://qudt.org/vocab/unit/KiloBYTE",
#         key="ucumCodes",
#     )
# )

pprint(
    match_object_json_path(
        qudt_units_param_res=qudt_units_param_res,
        identifier="http://qudt.org/vocab/unit/KiloBYTE",
    )
)

pprint(get_prefix_uuid(sidf_prefixes_de, "kilo"))
# Out:
# {'applicableSystems': {'type': 'literal',
#                        'value': 'http://qudt.org/vocab/sou/SI, '
#                                 'http://qudt.org/vocab/sou/CGS, '
#                                 'http://qudt.org/vocab/sou/CGS-EMU, '
#                                 'http://qudt.org/vocab/sou/CGS-GAUSS'},
#  'applicableUnit': {'type': 'uri',
#                     'value': 'http://qudt.org/vocab/unit/MilliPA-SEC'},
#  'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                             'type': 'literal',
#                             'value': '0.001e0'},
#  'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                  'type': 'literal',
#                  'value': '0.001-fold of the product of the SI derived unit '
#                           'pascal and the SI base unit second'},
#  'dimensionVector': {'type': 'uri',
#                      'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M1H0T-1D0'},
#  'plainTextDescription': {'type': 'literal',
#                           'value': '0.001-fold of the product of the SI '
#                                    'derived unit pascal and the SI base unit '
#                                    'second'},
#  'qlabels': {'type': 'literal', 'value': 'Millipascal Second@en'},
#  'symbol': {'type': 'literal', 'value': 'mPa·s'},
#  'ucumCodes': {'type': 'literal', 'value': 'mPa.s'}}
# {'applicableSystems': {'type': 'literal',
#                        'value': 'http://qudt.org/vocab/sou/SI, '
#                                 'http://qudt.org/vocab/sou/CGS, '
#                                 'http://qudt.org/vocab/sou/CGS-EMU, '
#                                 'http://qudt.org/vocab/sou/CGS-ESU, '
#                                 'http://qudt.org/vocab/sou/CGS-GAUSS, '
#                                 'http://qudt.org/vocab/sou/ASU, '
#                                 'http://qudt.org/vocab/sou/IMPERIAL, '
#                                 'http://qudt.org/vocab/sou/PLANCK'},
#  'applicableUnit': {'type': 'uri',
#                     'value': 'http://qudt.org/vocab/unit/KiloBYTE'},
#  'conversionMultiplierSN': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                             'type': 'literal',
#                             'value': '5545.177444479563e0'},
#  'dbpediaMatch': {'datatype': 'http://www.w3.org/2001/XMLSchema#anyURI',
#                   'type': 'literal',
#                   'value': 'http://dbpedia.org/resource/Byte'},
#  'description': {'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#HTML',
#                  'type': 'literal',
#                  'value': 'The kilobyte is a multiple of the unit byte for '
#                           'digital information equivalent to 1000 bytes. '
#                           'Although the prefix kilo- means 1000, the term '
#                           'kilobyte and symbol kB have historically been used '
#                           'to refer to either 1024 (210) bytes or 1000 (103) '
#                           'bytes, dependent upon context, in the fields of '
#                           'computer science and information technology. This '
#                           'ambiguity is removed in QUDT, with KibiBYTE used to '
#                           'refer to 1024 bytes.'},
#  'dimensionVector': {'type': 'uri',
#                      'value': 'http://qudt.org/vocab/dimensionvector/A0E0L0I0M0H0T0D1'},
#  'qlabels': {'type': 'literal', 'value': 'Kilo Byte@en'},
#  'symbol': {'type': 'literal', 'value': 'kB'},
#  'ucumCodes': {'type': 'literal', 'value': 'kBy'}}
# UUID('4b380554-7fd8-5820-83af-f8562ba4b4c5')

# %% [markdown]
# ## Map Attributes from Ontology Data to OSL Schema

# %%
import uuid

units = []


def dict_from_comma_separated_list(qlabel):
    parts = qlabel.split(", ")
    ret = {}
    for part in parts:
        value, key = part.split("@")
        ret[key] = value
    return ret


def get_osw_prefix_unit(
    qudt_units_param_res=None, prefixes_list=None, url=None, parent_uuid=None
):

    prefix_unit_dict = match_object_json_path(
        qudt_units_param_res=qudt_units_param_res,
        identifier=url,
    )
    # print(prefix_unit_dict)
    ontology_match_list = [prefix_unit_dict["applicableUnit"]["value"]]
    # print("dbpediaMatch" in prefix_unit_dict.keys())
    # print(prefix_unit_dict.keys())
    if "dbpediaMatch" in prefix_unit_dict.keys():
        ontology_match_list.append(prefix_unit_dict["dbpediaMatch"]["value"])
        # print(prefix_unit_dict["dbpediaMatch"]["value"])
    if "siExactMatch" in prefix_unit_dict:
        ontology_match_list.append(prefix_unit_dict["siExactMatch"]["value"])
    conversion_multiplier = None
    if "conversionMultiplierSN" in prefix_unit_dict:

        conversion_multiplier = prefix_unit_dict["conversionMultiplierSN"][
            "value"
        ]
        # print(conversion_multiplier)

    _uuid = str(uuid.uuid5(namespace=uuid.NAMESPACE_URL, name=url))
    # print(_uuid)
    prefix_unit = model.PrefixUnit(
        uuid=_uuid,
        osw_id="Item:OSW"
        + str(parent_uuid).replace("-", "")
        + "#OSW"
        + _uuid.replace("-", ""),
        prefix="Item:OSW"
        + str(get_prefix_uuid(prefixes_list, get_unit_prefix(url))).replace(
            "-", ""
        ),
        # prefix_symbol="",  # Causes edge case error
        main_symbol=match_json_path_key(
            qudt_units_param_res,
            identifier=url,
            key="symbol",
        ),
        exact_ontology_match=ontology_match_list,
        conversion_factor_from_si=conversion_multiplier,
        description=[{"text": "Description", "lang": "en"}],
    )

    return prefix_unit


i = 0
# Iteration over the unit_dict to create the QuantityUnit objects
for non_prefixed_unit_iri, unit_property_dict in unit_dict.items():
    name = non_prefixed_unit_iri.split("/")[-1]

    match_unit_dict = match_object_json_path(
        qudt_units_param_res=qudt_units_param_res,
        identifier=non_prefixed_unit_iri,
    )
    ontology_match_list = [match_unit_dict["applicableUnit"]["value"]]
    if "dbpediaMatch" in match_unit_dict.keys():
        ontology_match_list.append(match_unit_dict["dbpediaMatch"]["value"])
    if "siExactMatch" in match_unit_dict:
        ontology_match_list.append(match_unit_dict["siExactMatch"]["value"])
    conversion_multiplier = None
    if "conversionMultiplierSN" in match_unit_dict:
        conversion_multiplier = match_unit_dict["conversionMultiplierSN"][
            "value"
        ]
    # sequence of description before plainTextDescription is essential for overwriting
    description_list = None
    plainTextDescription = None
    if "description" in match_unit_dict:
        plainTextDescription = match_unit_dict["description"]["value"]
        description_list = [
            model.Description(
                text=plainTextDescription,
                lang="en",
            )
        ]
        # print(description_list)
    # overwrite description if plainTextDescription is present
    if "plainTextDescription" in match_unit_dict:
        plainTextDescription = match_unit_dict["plainTextDescription"]["value"]
        description_list = [
            model.Description(
                text=plainTextDescription,
                lang="en",
            )
        ]
        # print(description_list)
    if description_list == None:
        i += 1
        # print("No description found for ", name)

    qlabels = match_json_path_key(
        qudt_units_param_res,
        identifier=non_prefixed_unit_iri,
        key="qlabels",
    )

    label_dict = dict_from_comma_separated_list(qlabels)
    ### clean missing "en"
    if "" in label_dict.keys():
        label_dict["en"] = label_dict[""]
        del label_dict[""]

    osw_label_list = [
        model.Label(text=value, lang=key) for key, value in label_dict.items()
    ]
    symbol = match_json_path_key(
        qudt_units_param_res,
        identifier=non_prefixed_unit_iri,
        key="symbol",
    )
    _uuid = uuid.uuid5(
        namespace=uuid.NAMESPACE_URL, name=non_prefixed_unit_iri
    )
    # print(_uuid)
    prefix_unit_list = [
        get_osw_prefix_unit(
            qudt_units_param_res=qudt_units_param_res,
            prefixes_list=sidf_prefixes_de,
            url=url,
            parent_uuid=_uuid,
        )
        for url in unit_property_dict["prefixed_units"]
    ]

    unit = model.QuantityUnit(
        uuid=_uuid,
        exact_ontology_match=ontology_match_list,
        name=name,
        label=osw_label_list,
        main_symbol=symbol,
        prefix_units=prefix_unit_list,
        description=description_list,
        conversion_factor_from_si=conversion_multiplier,
    )
    units.append(unit)

pprint(units)
print("not described units couter: ", i)
print("num of non prfixed units: ", len(unit_dict.items()))
# Out:
# [QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('7f1fb9d6-ddeb-5fb7-a8a3-9067553a6dc1'), exact_ontology_match=['http://qudt.org/vocab/unit/WB', 'http://dbpedia.org/resource/Weber', 'https://si-digital-framework.org/SI/units/weber'], close_ontology_match=None, rdf_type=None, iri=None, name='WB', label=[Label(text='Weber', lang='de'), Label(text='weber', lang='en')], short_name=None, query_label=None, description=[Description(text='The SI unit of magnetic flux. "Flux" is the rate (per unit of time) at which something crosses a surface perpendicular to the flow. The weber is a large unit, equal to $10^{8}$ maxwells, and practical fluxes are usually fractions of one weber. The weber is the magnetic flux which, linking a circuit of one turn, would produce in it an electromotive force of 1 volt if it were reduced to zero at a uniform rate in 1 second. In SI base units, the dimensions of the weber are $(kg \\cdot m^2)/(s^2 \\cdot A)$. The weber is commonly expressed in terms of other derived units as the Tesla-square meter ($T \\cdot m^2$), volt-seconds ($V \\cdot s$), or joules per ampere ($J/A$).', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='Wb', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='a09dcefc-c2be-5cb1-ae11-6d0189c300e3', exact_ontology_match=['http://qudt.org/vocab/unit/MilliWB'], close_ontology_match=None, osw_id='Item:OSW7f1fb9d6ddeb5fb7a8a39067553a6dc1#OSWa09dcefcc2be5cb1ae116d0189c300e3', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mWb')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('21febbc7-35d2-5a9b-adef-e5f3191757d9'), exact_ontology_match=['http://qudt.org/vocab/unit/HZ-PER-K'], close_ontology_match=None, rdf_type=None, iri=None, name='HZ-PER-K', label=[Label(text='Hertz je Kelvin', lang='de'), Label(text='hertz per kelvin', lang='en')], short_name=None, query_label=None, description=[Description(text="\n  $\\textit{Hertz per Kelvin}$ is a unit for 'Inverse Time Temperature' expressed as $Hz K^{-1}$.\n  ", lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='Hz/K', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='1214143f-4aa9-52e7-8f3e-c1c339d9500b', exact_ontology_match=['http://qudt.org/vocab/unit/MegaHZ-PER-K'], close_ontology_match=None, osw_id='Item:OSW21febbc735d25a9badefe5f3191757d9#OSW1214143f4aa952e78f3ec1c339d9500b', conversion_factor_from_si=1000000.0, prefix='Item:OSWed7019528a135715a25263d19a2d5bef', prefix_symbol=None, main_symbol='MHz/K')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('f925ff17-54bb-5b05-ae3b-b6cdfde1e27d'), exact_ontology_match=['http://qudt.org/vocab/unit/K-PER-MIN'], close_ontology_match=None, rdf_type=None, iri=None, name='K-PER-MIN', label=[Label(text='Kelvin per Minute', lang='en')], short_name=None, query_label=None, description=[Description(text="$\\textit{Kelvin per Minute}$ is a unit for 'Temperature Per Time' expressed as $K / m$.", lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='K/min', conversion_factor_from_si=0.01666667, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('50e05e2d-20e8-58f2-81ef-0d396691ec1e'), exact_ontology_match=['http://qudt.org/vocab/unit/V-PER-M2'], close_ontology_match=None, rdf_type=None, iri=None, name='V-PER-M2', label=[Label(text='Volt per Square Metre', lang='en')], short_name=None, query_label=None, description=[Description(text="\n  $\\textit{Volt per Square Metre}$ is the divergence at a particular point in a vector field is (roughly) how much the vector field 'spreads out' from that point. \n  Operationally, we take the partial derivative of each of the field with respect to each of its space variables and add all the derivatives together to get the divergence. \n  $\\textit{Electric field}$ ($V/m$) differentiated with respect to distance ($m$) yields $V/(m^2)$.\n  ", lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='V/m²', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('4f047e2d-a1fc-5ea4-97c9-e22eb8e98ce5'), exact_ontology_match=['http://qudt.org/vocab/unit/CD-PER-M2'], close_ontology_match=None, rdf_type=None, iri=None, name='CD-PER-M2', label=[Label(text='candela per square metre', lang='en')], short_name=None, query_label=None, description=[Description(text='The candela per square metre ($cd/m^2$) is the derived SI unit of luminance. The unit is based on the candela, the SI unit of luminous intensity, and the square metre, the SI unit of area. Nit (nt) is a deprecated non-SI name also used for this unit ($1 nit = 1 cd/m^2$). As a measure of light emitted per unit area, this unit is frequently used to specify the brightness of a display device. Most consumer desktop liquid crystal displays have luminances of 200 to 300 $cd/m^2$; the sRGB spec for monitors targets 80 cd/m2. HDTVs range from 450 to about 1000 cd/m2. Typically, calibrated monitors should have a brightness of $120 cd/m^2$. $Nit$ is believed to come from the Latin word nitere, to shine.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='cd/m²', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('b663e6bf-f359-5e7b-93b2-8fffce66c50c'), exact_ontology_match=['http://qudt.org/vocab/unit/PA', 'http://dbpedia.org/resource/Pascal', 'https://si-digital-framework.org/SI/units/pascal'], close_ontology_match=None, rdf_type=None, iri=None, name='PA', label=[Label(text='Pascal', lang='de'), Label(text='pascal', lang='en')], short_name=None, query_label=None, description=[Description(text='The SI unit of pressure. The pascal is the standard pressure unit in the MKS metric system, equal to one newton per square meter or one "kilogram per meter per second per second." The unit is named for Blaise Pascal (1623-1662), French philosopher and mathematician, who was the first person to use a barometer to measure differences in altitude.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='Pa', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='0ec5bf81-32b2-5e58-b703-2766bd9b3225', exact_ontology_match=['http://qudt.org/vocab/unit/MegaPA'], close_ontology_match=None, osw_id='Item:OSWb663e6bff3595e7b93b28fffce66c50c#OSW0ec5bf8132b25e58b7032766bd9b3225', conversion_factor_from_si=1000000.0, prefix='Item:OSWed7019528a135715a25263d19a2d5bef', prefix_symbol=None, main_symbol='MPa'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='5def4be3-09ce-50ee-933c-99cf4b74e310', exact_ontology_match=['http://qudt.org/vocab/unit/MicroPA'], close_ontology_match=None, osw_id='Item:OSWb663e6bff3595e7b93b28fffce66c50c#OSW5def4be309ce50ee933c99cf4b74e310', conversion_factor_from_si=1e-06, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='μPa'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='8d40059d-9e39-51bb-9737-8fe3f119ba21', exact_ontology_match=['http://qudt.org/vocab/unit/DecaPA'], close_ontology_match=None, osw_id='Item:OSWb663e6bff3595e7b93b28fffce66c50c#OSW8d40059d9e3951bb97378fe3f119ba21', conversion_factor_from_si=10.0, prefix='Item:OSW2b7aeb54b7395e99b3d5c20b77de4b15', prefix_symbol=None, main_symbol='daPa'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='38b0e125-39b0-5ce2-8cd1-26c8eea29f95', exact_ontology_match=['http://qudt.org/vocab/unit/MilliPA'], close_ontology_match=None, osw_id='Item:OSWb663e6bff3595e7b93b28fffce66c50c#OSW38b0e12539b05ce28cd126c8eea29f95', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mPa'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='49bb4743-a573-5e18-9777-f3c6bd422a52', exact_ontology_match=['http://qudt.org/vocab/unit/GigaPA'], close_ontology_match=None, osw_id='Item:OSWb663e6bff3595e7b93b28fffce66c50c#OSW49bb4743a5735e189777f3c6bd422a52', conversion_factor_from_si=1000000000.0, prefix='Item:OSW62e04cd0df5c5ad4b76d5632fa7b47a0', prefix_symbol=None, main_symbol='GPa'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='264ebdc2-1f54-5685-93a9-1bbd832b6fbf', exact_ontology_match=['http://qudt.org/vocab/unit/KiloPA', 'http://dbpedia.org/resource/Pascal_%28unit%29'], close_ontology_match=None, osw_id='Item:OSWb663e6bff3595e7b93b28fffce66c50c#OSW264ebdc21f54568593a91bbd832b6fbf', conversion_factor_from_si=1000.0, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='kPa'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='482939f1-2359-5314-beca-39ad32d65a15', exact_ontology_match=['http://qudt.org/vocab/unit/HectoPA'], close_ontology_match=None, osw_id='Item:OSWb663e6bff3595e7b93b28fffce66c50c#OSW482939f123595314beca39ad32d65a15', conversion_factor_from_si=100.0, prefix='Item:OSWfa81836c0a3951e8ac1f4c6d0fba3e25', prefix_symbol=None, main_symbol='hPa')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('6db7b397-b404-59e6-a976-f9f77c568089'), exact_ontology_match=['http://qudt.org/vocab/unit/TONNE-PER-YR'], close_ontology_match=None, rdf_type=None, iri=None, name='TONNE-PER-YR', label=[Label(text='Tonne per Year', lang='en')], short_name=None, query_label=None, description=[Description(text='1,000-fold of the SI base unit kilogram divided by the unit year', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='t/y', conversion_factor_from_si=3.168808781e-05, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='ca073491-ff03-557f-9405-4c2212cb8275', exact_ontology_match=['http://qudt.org/vocab/unit/KiloTONNE-PER-YR'], close_ontology_match=None, osw_id='Item:OSW6db7b397b40459e6a976f9f77c568089#OSWca073491ff03557f94054c2212cb8275', conversion_factor_from_si=0.03168808781, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='kt/year')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('78331234-e1a1-5aee-bd8b-0caa71201939'), exact_ontology_match=['http://qudt.org/vocab/unit/M-PER-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='M-PER-SEC', label=[Label(text='Meter je Sekunde', lang='de'), Label(text='metre per second', lang='en')], short_name=None, query_label=None, description=[Description(text='Metre per second is an SI derived unit of both speed (scalar) and velocity (vector quantity which specifies both magnitude and a specific direction), defined by distance in metres divided by time in seconds.\nThe official SI symbolic abbreviation is mu00b7s-1, or equivalently either m/s.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='m/s', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='9f12ce12-bc72-5cd5-9791-265e2e480fd2', exact_ontology_match=['http://qudt.org/vocab/unit/KiloM-PER-SEC'], close_ontology_match=None, osw_id='Item:OSW78331234e1a15aeebd8b0caa71201939#OSW9f12ce12bc725cd59791265e2e480fd2', conversion_factor_from_si=1000.0, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='km/s'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='4937ac85-021f-506c-b7ba-3958f2216bd1', exact_ontology_match=['http://qudt.org/vocab/unit/MilliM-PER-SEC'], close_ontology_match=None, osw_id='Item:OSW78331234e1a15aeebd8b0caa71201939#OSW4937ac85021f506cb7ba3958f2216bd1', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mm/s'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='d094e4cf-d62c-5224-8aad-5ef87c19fb7d', exact_ontology_match=['http://qudt.org/vocab/unit/CentiM-PER-SEC'], close_ontology_match=None, osw_id='Item:OSW78331234e1a15aeebd8b0caa71201939#OSWd094e4cfd62c52248aad5ef87c19fb7d', conversion_factor_from_si=0.01, prefix='Item:OSWbca49386a57457c1a1b250da355d94fe', prefix_symbol=None, main_symbol='cm/s'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='fc9fca27-ba5b-543c-8780-521b4af39189', exact_ontology_match=['http://qudt.org/vocab/unit/MicroM-PER-SEC'], close_ontology_match=None, osw_id='Item:OSW78331234e1a15aeebd8b0caa71201939#OSWfc9fca27ba5b543c8780521b4af39189', conversion_factor_from_si=1e-06, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='μm/s')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('e9c4745c-4d3a-5c17-a288-b08a7f870ffc'), exact_ontology_match=['http://qudt.org/vocab/unit/M2-PER-SR', 'http://dbpedia.org/resource/Steradian'], close_ontology_match=None, rdf_type=None, iri=None, name='M2-PER-SR', label=[Label(text='Square Metre per Steradian', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='m²/sr', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('fab9cdc7-da3e-5a26-b5e3-12fec00e7297'), exact_ontology_match=['http://qudt.org/vocab/unit/KAT-PER-L', 'http://dbpedia.org/resource/Katal'], close_ontology_match=None, rdf_type=None, iri=None, name='KAT-PER-L', label=[Label(text='Katal per Litre', lang='en')], short_name=None, query_label=None, description=[Description(text='A unit of catalytic activity used especially in the chemistry of enzymes. A catalyst is a substance that starts or speeds a chemical reaction. Enzymes are proteins that act as catalysts within the bodies of living plants and animals. A catalyst has an activity of one katal if it enables a reaction to proceed at the rate of one mole per second. ', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='kat/L', conversion_factor_from_si=1000.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='30338003-c36a-506b-88ac-1aa82533c6ad', exact_ontology_match=['http://qudt.org/vocab/unit/PicoKAT-PER-L'], close_ontology_match=None, osw_id='Item:OSWfab9cdc7da3e5a26b5e312fec00e7297#OSW30338003c36a506b88ac1aa82533c6ad', conversion_factor_from_si=1e-15, prefix='Item:OSW5f8f94601be05a078108b2be4d74e461', prefix_symbol=None, main_symbol='pkat/L'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='4e11cd7e-8e4e-5926-858a-05d39b03c454', exact_ontology_match=['http://qudt.org/vocab/unit/NanoKAT-PER-L'], close_ontology_match=None, osw_id='Item:OSWfab9cdc7da3e5a26b5e312fec00e7297#OSW4e11cd7e8e4e5926858a05d39b03c454', conversion_factor_from_si=1e-12, prefix='Item:OSWb6a5fd00b91058d1909514095f84fe6f', prefix_symbol=None, main_symbol='nkat/L'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='c641377c-3136-583b-bb07-b35b8de829af', exact_ontology_match=['http://qudt.org/vocab/unit/KAT-PER-MicroL', 'http://dbpedia.org/resource/Katal'], close_ontology_match=None, osw_id='Item:OSWfab9cdc7da3e5a26b5e312fec00e7297#OSWc641377c3136583bbb07b35b8de829af', conversion_factor_from_si=1000000000.0, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='kat/µL'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='2563bbed-b001-57be-9da5-f07785b473ae', exact_ontology_match=['http://qudt.org/vocab/unit/MilliKAT-PER-L'], close_ontology_match=None, osw_id='Item:OSWfab9cdc7da3e5a26b5e312fec00e7297#OSW2563bbedb00157be9da5f07785b473ae', conversion_factor_from_si=1e-06, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mkat/L'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='7c158d91-3660-561d-b200-e5011b7a810f', exact_ontology_match=['http://qudt.org/vocab/unit/MicroKAT-PER-L'], close_ontology_match=None, osw_id='Item:OSWfab9cdc7da3e5a26b5e312fec00e7297#OSW7c158d913660561db200e5011b7a810f', conversion_factor_from_si=1e-09, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='µkat/L')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('5e6ed82c-6855-5dc2-b379-25babf728409'), exact_ontology_match=['http://qudt.org/vocab/unit/N-M-SEC', 'http://dbpedia.org/resource/Newton_metre'], close_ontology_match=None, rdf_type=None, iri=None, name='N-M-SEC', label=[Label(text='Newtonmetersekunde', lang='de'), Label(text='newton metre second', lang='en')], short_name=None, query_label=None, description=[Description(text='The SI derived unit of angular momentum. ', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='N·m·s', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('bcb63569-64e6-59df-ad78-833199412afc'), exact_ontology_match=['http://qudt.org/vocab/unit/M2-HZ'], close_ontology_match=None, rdf_type=None, iri=None, name='M2-HZ', label=[Label(text='Square metres Hertz', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='m²·Hz', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('afebb36f-7bb6-5377-baeb-39c5c782bc93'), exact_ontology_match=['http://qudt.org/vocab/unit/A-HR'], close_ontology_match=None, rdf_type=None, iri=None, name='A-HR', label=[Label(text='Ampere Hour', lang='en')], short_name=None, query_label=None, description=[Description(text='$\\textit{Ampere Hour}$ is a practical unit of electric charge equal to the charge flowing\n   in one hour through a conductor passing one ampere. \n   An ampere-hour or amp-hour (symbol $Ah,\\,AHr,\\, A \\cdot h, A h$) is a unit of electric\n    charge, with sub-units milliampere-hour ($mAh$) and milliampere second ($mAs$).\n    One ampere-hour is equal to 3600 coulombs (ampere-seconds), the electric charge transferred\n     by a steady current of one ampere for one hour. \n    The ampere-hour is frequently used in measurements of electrochemical systems such as\n     electroplating and electrical batteries. \n    The commonly seen milliampere-hour ($mAh$ or $mA \\cdot h$) is one-thousandth of an\n     ampere-hour ($3.6 \\,coulombs$).\n  ', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='A·hr', conversion_factor_from_si=3600.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='35d01b84-f9fd-58ae-b65a-b3bd19002e82', exact_ontology_match=['http://qudt.org/vocab/unit/KiloA-HR'], close_ontology_match=None, osw_id='Item:OSWafebb36f7bb65377baeb39c5c782bc93#OSW35d01b84f9fd58aeb65ab3bd19002e82', conversion_factor_from_si=3600000.0, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='kA·hr'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='0f2851b9-e012-5b93-9293-3d2723c88912', exact_ontology_match=['http://qudt.org/vocab/unit/MilliA-HR'], close_ontology_match=None, osw_id='Item:OSWafebb36f7bb65377baeb39c5c782bc93#OSW0f2851b9e0125b9392933d2723c88912', conversion_factor_from_si=3.6, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mA·hr')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('0505357d-e255-592e-b766-bdfce883acb3'), exact_ontology_match=['http://qudt.org/vocab/unit/J-PER-M', 'http://dbpedia.org/resource/Steradian'], close_ontology_match=None, rdf_type=None, iri=None, name='J-PER-M', label=[Label(text='Joule per Metre', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='J/m', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('804e40f8-2f49-55ab-8f1b-d0c1e9e77d28'), exact_ontology_match=['http://qudt.org/vocab/unit/PER-M3-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='PER-M3-SEC', label=[Label(text='Reciprocal Cubic Metre Second', lang='en')], short_name=None, query_label=None, description=[Description(text='unit of the slowing-down density as reciprocal of the power of the SI base unit metre with exponent 3 divided by the SI base unit second', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='/(m³·s)', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('e180e39c-49d7-563c-a3bb-04314b1b3c90'), exact_ontology_match=['http://qudt.org/vocab/unit/T-M'], close_ontology_match=None, rdf_type=None, iri=None, name='T-M', label=[Label(text='T-M', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='T·m', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('da81752d-a4a7-532f-b7d5-790cd2e41a1c'), exact_ontology_match=['http://qudt.org/vocab/unit/PA-PER-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='PA-PER-SEC', label=[Label(text='Pascal per Second', lang='en')], short_name=None, query_label=None, description=[Description(text='A rate of change of pressure measured as the number of Pascals in a period of one second.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='Pa/s', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('913bed1f-aa62-5f22-9f4d-b01de7ffb322'), exact_ontology_match=['http://qudt.org/vocab/unit/NP', 'http://dbpedia.org/resource/Neper', 'https://si-digital-framework.org/SI/units/neper'], close_ontology_match=None, rdf_type=None, iri=None, name='NP', label=[Label(text='Neper', lang='en')], short_name=None, query_label=None, description=[Description(text="The neper is a logarithmic unit for ratios of measurements of physical field and power quantities, such as gain and loss of electronic signals. It has the unit symbol Np. The unit's name is derived from the name of John Napier, the inventor of logarithms. As is the case for the decibel and bel, the neper is not a unit in the International System of Units (SI), but it is accepted for use alongside the SI. Like the decibel, the neper is a unit in a logarithmic scale. While the bel uses the decadic (base-10) logarithm to compute ratios, the neper uses the natural logarithm, based on Euler's number", lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='Np', conversion_factor_from_si=None, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('9907d7b7-5187-5942-8675-13bbb8d8c43e'), exact_ontology_match=['http://qudt.org/vocab/unit/K-PA-PER-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='K-PA-PER-SEC', label=[Label(text='Kelvin Pascals per second', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='K·Pa/s', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('8113ac9c-2561-5c21-902a-9447ab03cc0a'), exact_ontology_match=['http://qudt.org/vocab/unit/N', 'http://dbpedia.org/resource/Newton', 'https://si-digital-framework.org/SI/units/newton'], close_ontology_match=None, rdf_type=None, iri=None, name='N', label=[Label(text='Newton', lang='de'), Label(text='newton', lang='en')], short_name=None, query_label=None, description=[Description(text='The "Newton" is the SI unit of force. A force of one newton will accelerate a mass of one kilogram at the rate of one meter per second per second. The newton is named for Isaac Newton (1642-1727), the British mathematician, physicist, and natural philosopher. He was the first person to understand clearly the relationship between force (F), mass (m), and acceleration (a) expressed by the formula $F = m \\cdot a$.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='N', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='f2fd2b42-f5a6-53f3-98f9-fb35200f39fe', exact_ontology_match=['http://qudt.org/vocab/unit/MilliN'], close_ontology_match=None, osw_id='Item:OSW8113ac9c25615c21902a9447ab03cc0a#OSWf2fd2b42f5a653f398f9fb35200f39fe', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mN'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='2b1c9c4b-6238-5c44-88e5-2fc40d8b7bbb', exact_ontology_match=['http://qudt.org/vocab/unit/MegaN'], close_ontology_match=None, osw_id='Item:OSW8113ac9c25615c21902a9447ab03cc0a#OSW2b1c9c4b62385c4488e52fc40d8b7bbb', conversion_factor_from_si=1000000.0, prefix='Item:OSWed7019528a135715a25263d19a2d5bef', prefix_symbol=None, main_symbol='MN'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='31a9dadf-8383-58bf-a550-4d7781711397', exact_ontology_match=['http://qudt.org/vocab/unit/MicroN'], close_ontology_match=None, osw_id='Item:OSW8113ac9c25615c21902a9447ab03cc0a#OSW31a9dadf838358bfa5504d7781711397', conversion_factor_from_si=1e-06, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='μN'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='9e26f437-74ed-54c9-b9bf-757fca6ad5e7', exact_ontology_match=['http://qudt.org/vocab/unit/KiloN'], close_ontology_match=None, osw_id='Item:OSW8113ac9c25615c21902a9447ab03cc0a#OSW9e26f43774ed54c9b9bf757fca6ad5e7', conversion_factor_from_si=1000.0, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='kN')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('2f3941ad-9ce2-5c6b-a674-4243dcc8c352'), exact_ontology_match=['http://qudt.org/vocab/unit/M3-PER-C'], close_ontology_match=None, rdf_type=None, iri=None, name='M3-PER-C', label=[Label(text='Cubic Metre per Coulomb', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='m³/C', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('5a4996a6-ea90-5a00-b974-6369e1c9fa36'), exact_ontology_match=['http://qudt.org/vocab/unit/L-PER-DAY'], close_ontology_match=None, rdf_type=None, iri=None, name='L-PER-DAY', label=[Label(text='Litre per Day', lang='en')], short_name=None, query_label=None, description=[Description(text='unit litre divided by the unit day', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='L/day', conversion_factor_from_si=1.157407e-08, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='da34b5bb-0a15-516f-ba29-781df0096e7f', exact_ontology_match=['http://qudt.org/vocab/unit/MilliL-PER-DAY'], close_ontology_match=None, osw_id='Item:OSW5a4996a6ea905a00b9746369e1c9fa36#OSWda34b5bb0a15516fba29781df0096e7f', conversion_factor_from_si=1.157407e-11, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mL/day')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('22ea6fd3-2be6-5173-b6ce-52e47446c8ed'), exact_ontology_match=['http://qudt.org/vocab/unit/PER-M3'], close_ontology_match=None, rdf_type=None, iri=None, name='PER-M3', label=[Label(text='Reciprocal Cubic Metre', lang='en')], short_name=None, query_label=None, description=[Description(text='"Per Cubic Meter" is a denominator unit with dimensions $/m^3$.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='m⁻³', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='f6d64151-fc83-5995-b48c-0fc8bb64a36a', exact_ontology_match=['http://qudt.org/vocab/unit/PER-CentiM3'], close_ontology_match=None, osw_id='Item:OSW22ea6fd32be65173b6ce52e47446c8ed#OSWf6d64151fc835995b48c0fc8bb64a36a', conversion_factor_from_si=1000000.0, prefix='Item:OSWbca49386a57457c1a1b250da355d94fe', prefix_symbol=None, main_symbol='/cm³'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='d3bd49d9-2647-5edf-be5b-54108429d801', exact_ontology_match=['http://qudt.org/vocab/unit/PER-MilliM3'], close_ontology_match=None, osw_id='Item:OSW22ea6fd32be65173b6ce52e47446c8ed#OSWd3bd49d926475edfbe5b54108429d801', conversion_factor_from_si=1000000000.0, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='/mm³')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('7f2c167c-5a39-550d-91c1-f95cc01a9a11'), exact_ontology_match=['http://qudt.org/vocab/unit/W-PER-M2'], close_ontology_match=None, rdf_type=None, iri=None, name='W-PER-M2', label=[Label(text='Watt je Quadratmeter', lang='de'), Label(text='watt per square metre', lang='en')], short_name=None, query_label=None, description=[Description(text='"Watt per Square Meter} is a unit of irradiance defined as the power received per area. This is a unit in the category of Energy flux. It is also known as watts per square meter, watt per square metre, watts per square metre, watt/square meter, watt/square metre. This unit is commonly used in the SI unit system. Watt Per Square Meter ($W/m^2$) has a dimension of $MT^{-3"$ where $M$ is mass, and $T$ is time. This unit is the standard SI unit in this category.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='W/m²', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='a735be7b-016c-510f-98dd-404ee42c6722', exact_ontology_match=['http://qudt.org/vocab/unit/W-PER-CentiM2'], close_ontology_match=None, osw_id='Item:OSW7f2c167c5a39550d91c1f95cc01a9a11#OSWa735be7b016c510f98dd404ee42c6722', conversion_factor_from_si=10000.0, prefix='Item:OSWbca49386a57457c1a1b250da355d94fe', prefix_symbol=None, main_symbol='W/cm²'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='f33a1a99-c605-5b17-8a0b-973e57e1aacb', exact_ontology_match=['http://qudt.org/vocab/unit/MilliW-PER-M2'], close_ontology_match=None, osw_id='Item:OSW7f2c167c5a39550d91c1f95cc01a9a11#OSWf33a1a99c6055b178a0b973e57e1aacb', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mW/m²'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='f194c328-c8ef-587c-8237-73008774afc8', exact_ontology_match=['http://qudt.org/vocab/unit/PicoW-PER-M2'], close_ontology_match=None, osw_id='Item:OSW7f2c167c5a39550d91c1f95cc01a9a11#OSWf194c328c8ef587c823773008774afc8', conversion_factor_from_si=1e-12, prefix='Item:OSW5f8f94601be05a078108b2be4d74e461', prefix_symbol=None, main_symbol='pW/m²'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='bec47ab0-8594-5564-b8bc-080ab7934395', exact_ontology_match=['http://qudt.org/vocab/unit/MicroW-PER-M2'], close_ontology_match=None, osw_id='Item:OSW7f2c167c5a39550d91c1f95cc01a9a11#OSWbec47ab085945564b8bc080ab7934395', conversion_factor_from_si=1e-06, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='µW/m²')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('1dd1ded9-a570-5629-b47a-a64b3ac3deea'), exact_ontology_match=['http://qudt.org/vocab/unit/EV-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='EV-SEC', label=[Label(text='Electron Volt Second', lang='en')], short_name=None, query_label=None, description=[Description(text='"Electron Volt Second" is a unit for  \'Angular Momentum\' expressed as $eV s$.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='eV·s', conversion_factor_from_si=1.602176634e-19, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('c3111bc3-2832-5013-9974-feaa71b99c31'), exact_ontology_match=['http://qudt.org/vocab/unit/PPTR_VOL'], close_ontology_match=None, rdf_type=None, iri=None, name='PPTR_VOL', label=[Label(text='Parts per trillion by volume', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='pptr', conversion_factor_from_si=1e-12, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('85efe142-8cb7-5363-a75a-ab6435e2d98d'), exact_ontology_match=['http://qudt.org/vocab/unit/V', 'http://dbpedia.org/resource/Volt', 'https://si-digital-framework.org/SI/units/volt'], close_ontology_match=None, rdf_type=None, iri=None, name='V', label=[Label(text='Volt', lang='de'), Label(text='volt', lang='en')], short_name=None, query_label=None, description=[Description(text='$\\textit{Volt}$ is the SI unit of electric potential. \n  Separating electric charges creates potential energy, which can be measured in energy units such as joules. \n  Electric potential is defined as the amount of potential energy present per unit of charge. \n  Electric potential is measured in volts, with one volt representing a potential of one joule per coulomb of charge. \n  The name of the unit honors the Italian scientist Count Alessandro Volta (1745-1827), the inventor of the first battery.\n  The volt also may be expressed with a variety of other units. \n  For example, a volt is also equal to one watt per ampere ($W/A$) and one joule per ampere per second ($J/A/s$).\n  ', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='V', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='78798aa1-bdcb-57f0-aea8-d4eb86ff3355', exact_ontology_match=['http://qudt.org/vocab/unit/MegaV'], close_ontology_match=None, osw_id='Item:OSW85efe1428cb75363a75aab6435e2d98d#OSW78798aa1bdcb57f0aea8d4eb86ff3355', conversion_factor_from_si=1000000.0, prefix='Item:OSWed7019528a135715a25263d19a2d5bef', prefix_symbol=None, main_symbol='MV'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='82d25d00-b148-5cc1-8c20-4f95de4536a9', exact_ontology_match=['http://qudt.org/vocab/unit/MilliV'], close_ontology_match=None, osw_id='Item:OSW85efe1428cb75363a75aab6435e2d98d#OSW82d25d00b1485cc18c204f95de4536a9', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mV'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='4deed980-237a-5360-b48e-0dd1331d4199', exact_ontology_match=['http://qudt.org/vocab/unit/KiloV'], close_ontology_match=None, osw_id='Item:OSW85efe1428cb75363a75aab6435e2d98d#OSW4deed980237a5360b48e0dd1331d4199', conversion_factor_from_si=1000.0, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='kV'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='c0cb09a9-4aa5-5358-9a59-ea70bfccfc96', exact_ontology_match=['http://qudt.org/vocab/unit/MicroV'], close_ontology_match=None, osw_id='Item:OSW85efe1428cb75363a75aab6435e2d98d#OSWc0cb09a94aa553589a59ea70bfccfc96', conversion_factor_from_si=1e-06, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='µV')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('6591fe27-dbb9-5ace-b00d-28ceb772167f'), exact_ontology_match=['http://qudt.org/vocab/unit/TON_Metric-PER-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='TON_Metric-PER-SEC', label=[Label(text='Tonne per Second (metric Ton)', lang='en')], short_name=None, query_label=None, description=[Description(text='unit ton divided by the SI base unit second', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='t/s', conversion_factor_from_si=1000.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('fabd2eab-e9d5-542f-9de7-24b3d10058ec'), exact_ontology_match=['http://qudt.org/vocab/unit/M2-PER-N'], close_ontology_match=None, rdf_type=None, iri=None, name='M2-PER-N', label=[Label(text='Square Metre per Newton', lang='en')], short_name=None, query_label=None, description=[Description(text='power of the SI base unit metre with the exponent 2 divided by the derived SI unit newton', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='m²/N', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('efcd851d-7183-5201-8f73-55bf1594398e'), exact_ontology_match=['http://qudt.org/vocab/unit/N-PER-A'], close_ontology_match=None, rdf_type=None, iri=None, name='N-PER-A', label=[Label(text='Newton per Ampere', lang='en')], short_name=None, query_label=None, description=[Description(text='SI derived unit newton divided by the SI base unit ampere', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='N/A', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('404a6456-c6e8-5787-a64b-a84779ef3d70'), exact_ontology_match=['http://qudt.org/vocab/unit/N-M-SEC-PER-RAD'], close_ontology_match=None, rdf_type=None, iri=None, name='N-M-SEC-PER-RAD', label=[Label(text='Newton metre seconds per radian', lang='en'), Label(text='Newtonmetersekunden pro Radian', lang='de')], short_name=None, query_label=None, description=[Description(text='Newton metre seconds measured per radian', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='N·m·s/rad', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('dedbe50d-76c7-5dc2-a87b-1000faa99b10'), exact_ontology_match=['http://qudt.org/vocab/unit/PER-T-M'], close_ontology_match=None, rdf_type=None, iri=None, name='PER-T-M', label=[Label(text='Reciprocal Tesla Metre', lang='en')], short_name=None, query_label=None, description=[Description(text='\n  A $\\textit{Per Tesla Meter Unit}$ is a denominator unit with dimensions $/m .\\cdot T$.\n  ', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='/(T·m)', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('cd1c2695-4cdf-5421-b201-b431b289ee94'), exact_ontology_match=['http://qudt.org/vocab/unit/W-PER-K'], close_ontology_match=None, rdf_type=None, iri=None, name='W-PER-K', label=[Label(text='Watt per Kelvin', lang='en')], short_name=None, query_label=None, description=[Description(text='Watt Per Kelvin ($W/K$) is a unit in the category of Thermal conductivity.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='W/K', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('394d6a9b-2791-55cc-9f14-6dae49bb649a'), exact_ontology_match=['http://qudt.org/vocab/unit/TON_Metric-PER-DAY'], close_ontology_match=None, rdf_type=None, iri=None, name='TON_Metric-PER-DAY', label=[Label(text='Tonne per Day', lang='en')], short_name=None, query_label=None, description=[Description(text='metric unit ton divided by the unit for time day', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='t/day', conversion_factor_from_si=0.011574074074074, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('f6d6f2af-6129-5484-ab10-221fe5922f97'), exact_ontology_match=['http://qudt.org/vocab/unit/M2-PER-SEC2'], close_ontology_match=None, rdf_type=None, iri=None, name='M2-PER-SEC2', label=[Label(text='Square metres per square second', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='m²/s²', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='f19ea831-be10-53a9-b70d-6403acc15022', exact_ontology_match=['http://qudt.org/vocab/unit/KiloM2-PER-SEC2'], close_ontology_match=None, osw_id='Item:OSWf6d6f2af61295484ab10221fe5922f97#OSWf19ea831be1053a9b70d6403acc15022', conversion_factor_from_si=1000000.0, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='km²/s²')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('2b851764-0ac7-5611-a57b-26b56bd5124c'), exact_ontology_match=['http://qudt.org/vocab/unit/W-PER-M-K'], close_ontology_match=None, rdf_type=None, iri=None, name='W-PER-M-K', label=[Label(text='Watt per Metre Kelvin', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='W/(m·K)', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('467e2e80-ae48-546c-b313-55254d2f4fd7'), exact_ontology_match=['http://qudt.org/vocab/unit/MOL-PER-MIN'], close_ontology_match=None, rdf_type=None, iri=None, name='MOL-PER-MIN', label=[Label(text='Mole per Minute', lang='en')], short_name=None, query_label=None, description=[Description(text='SI base unit mole divided by the unit for time minute', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='mol/min', conversion_factor_from_si=0.016666667, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='1e936211-6408-5cd5-8893-663c44d43e70', exact_ontology_match=['http://qudt.org/vocab/unit/KiloMOL-PER-MIN'], close_ontology_match=None, osw_id='Item:OSW467e2e80ae48546cb31355254d2f4fd7#OSW1e93621164085cd58893663c44d43e70', conversion_factor_from_si=16.666666666666668, prefix='Item:OSW4b3805547fd8582083aff8562ba4b4c5', prefix_symbol=None, main_symbol='kmol/min')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('e0b09824-8f75-57aa-a6a8-92a6ecbd32b8'), exact_ontology_match=['http://qudt.org/vocab/unit/C4-M4-PER-J3'], close_ontology_match=None, rdf_type=None, iri=None, name='C4-M4-PER-J3', label=[Label(text='Quartic Coulomb Metre per Cubic Energy', lang='en')], short_name=None, query_label=None, description=[Description(text='"Quartic Coulomb Meter per Cubic Energy" is a unit for  \'Quartic Electric Dipole Moment Per Cubic Energy\' expressed as $C^{4} m^{4} J^{-3}$.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='C⁴·m⁴/J³', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('2e906b32-78d0-5a35-aec5-82cba0191b65'), exact_ontology_match=['http://qudt.org/vocab/unit/DEG_C-WK'], close_ontology_match=None, rdf_type=None, iri=None, name='DEG_C-WK', label=[Label(text='Degree Celsius week', lang='en')], short_name=None, query_label=None, description=[Description(text='temperature multiplied by unit of time.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='°C·wk', conversion_factor_from_si=604800.0, prefix_units=[]),
# ...
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('7be773fb-9517-51d2-bb78-e91aee179d91'), exact_ontology_match=['http://qudt.org/vocab/unit/K-PER-HR'], close_ontology_match=None, rdf_type=None, iri=None, name='K-PER-HR', label=[Label(text='Kelvin per Hour', lang='en')], short_name=None, query_label=None, description=[Description(text="$\\textit{Kelvin per Hour}$ is a unit for 'Temperature Per Time' expressed as $K / h$.", lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='K/hr', conversion_factor_from_si=0.0002777777777777778, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('a1b4f9da-4183-543a-8161-e3fe99751be2'), exact_ontology_match=['http://qudt.org/vocab/unit/FARAD', 'http://dbpedia.org/resource/Farad', 'https://si-digital-framework.org/SI/units/farad'], close_ontology_match=None, rdf_type=None, iri=None, name='FARAD', label=[Label(text='Farad', lang='de'), Label(text='farad', lang='en')], short_name=None, query_label=None, description=[Description(text='The SI unit of electric capacitance. Very early in the study of electricity scientists discovered that a pair of conductors separated by an insulator can store a much larger charge than an isolated conductor can store. The better the insulator, the larger the charge that the conductors can hold. This property of a circuit is called capacitance, and it is measured in farads. One farad is defined as the ability to store one coulomb of charge per volt of potential difference between the two conductors. This is a natural definition, but the unit it defines is very large. In practical circuits, capacitance is often measured in microfarads, nanofarads, or sometimes even in picofarads (10-12 farad, or trillionths of a farad). The unit is named for the British physicist Michael Faraday (1791-1867), who was known for his work in electricity and electrochemistry.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='F', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='2c99e79b-872e-50d7-a3cd-b3b0614bbb1d', exact_ontology_match=['http://qudt.org/vocab/unit/NanoFARAD', 'http://dbpedia.org/resource/Farad'], close_ontology_match=None, osw_id='Item:OSWa1b4f9da4183543a8161e3fe99751be2#OSW2c99e79b872e50d7a3cdb3b0614bbb1d', conversion_factor_from_si=1e-09, prefix='Item:OSWb6a5fd00b91058d1909514095f84fe6f', prefix_symbol=None, main_symbol='nF'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='328bea7c-3686-59c0-ab27-29ace2604ebc', exact_ontology_match=['http://qudt.org/vocab/unit/AttoFARAD'], close_ontology_match=None, osw_id='Item:OSWa1b4f9da4183543a8161e3fe99751be2#OSW328bea7c368659c0ab2729ace2604ebc', conversion_factor_from_si=1e-18, prefix='Item:OSWa569fd62d673576f8150159be578c72d', prefix_symbol=None, main_symbol='aF'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='ea22beb7-c143-50cf-b4a8-029430e0a9e3', exact_ontology_match=['http://qudt.org/vocab/unit/PicoFARAD', 'http://dbpedia.org/resource/Farad'], close_ontology_match=None, osw_id='Item:OSWa1b4f9da4183543a8161e3fe99751be2#OSWea22beb7c14350cfb4a8029430e0a9e3', conversion_factor_from_si=1e-12, prefix='Item:OSW5f8f94601be05a078108b2be4d74e461', prefix_symbol=None, main_symbol='pF'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='233c7ca1-25dc-5092-bdc6-9b05723ba75b', exact_ontology_match=['http://qudt.org/vocab/unit/MilliFARAD'], close_ontology_match=None, osw_id='Item:OSWa1b4f9da4183543a8161e3fe99751be2#OSW233c7ca125dc5092bdc69b05723ba75b', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mF'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='3690c26e-937c-55f1-aeb3-dcba3c5d79f4', exact_ontology_match=['http://qudt.org/vocab/unit/MicroFARAD'], close_ontology_match=None, osw_id='Item:OSWa1b4f9da4183543a8161e3fe99751be2#OSW3690c26e937c55f1aeb3dcba3c5d79f4', conversion_factor_from_si=1e-06, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='μF')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('1e6dd22f-b3e0-5098-9adb-41d7b5d18290'), exact_ontology_match=['http://qudt.org/vocab/unit/PA-PER-HR'], close_ontology_match=None, rdf_type=None, iri=None, name='PA-PER-HR', label=[Label(text='Pascal per Hour', lang='en')], short_name=None, query_label=None, description=[Description(text='A rate of change of pressure measured as the number of Pascals in a period of one hour.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='Pa/hr', conversion_factor_from_si=0.000277777778, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='a2065930-0e43-557d-b5c3-7f3b8e8532b5', exact_ontology_match=['http://qudt.org/vocab/unit/HectoPA-PER-HR'], close_ontology_match=None, osw_id='Item:OSW1e6dd22fb3e050989adb41d7b5d18290#OSWa20659300e43557db5c37f3b8e8532b5', conversion_factor_from_si=0.0277777777777778, prefix='Item:OSWfa81836c0a3951e8ac1f4c6d0fba3e25', prefix_symbol=None, main_symbol='hPa/hr')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('580b455c-e69e-5741-8303-f409d43f373a'), exact_ontology_match=['http://qudt.org/vocab/unit/PER-M2-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='PER-M2-SEC', label=[Label(text='Reciprocal Square Metre Second', lang='en')], short_name=None, query_label=None, description=[Description(text='unit of the particle current density', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='/(m²·s)', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('bb252cb7-b950-5d5c-9369-be8da21e274d'), exact_ontology_match=['http://qudt.org/vocab/unit/BQ-PER-L'], close_ontology_match=None, rdf_type=None, iri=None, name='BQ-PER-L', label=[Label(text='Becquerels per litre', lang='en')], short_name=None, query_label=None, description=[Description(text='One radioactive disintegration per second from a one part in 10**3 of the SI unit of volume (cubic metre).', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='Bq/L', conversion_factor_from_si=1000.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='ea37c502-2a28-5510-8938-0a9351fb06a6', exact_ontology_match=['http://qudt.org/vocab/unit/MicroBQ-PER-L'], close_ontology_match=None, osw_id='Item:OSWbb252cb7b9505d5c9369be8da21e274d#OSWea37c5022a28551089380a9351fb06a6', conversion_factor_from_si=0.001, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='μBq/L'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='5ca6e9dc-c49f-53d6-921d-b368597bdc2a', exact_ontology_match=['http://qudt.org/vocab/unit/MilliBQ-PER-L'], close_ontology_match=None, osw_id='Item:OSWbb252cb7b9505d5c9369be8da21e274d#OSW5ca6e9dcc49f53d6921db368597bdc2a', conversion_factor_from_si=1.0, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mBq/L'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='0ac5a24d-6907-5e45-80b8-8126796660ea', exact_ontology_match=['http://qudt.org/vocab/unit/NanoBQ-PER-L'], close_ontology_match=None, osw_id='Item:OSWbb252cb7b9505d5c9369be8da21e274d#OSW0ac5a24d69075e4580b88126796660ea', conversion_factor_from_si=1e-06, prefix='Item:OSWb6a5fd00b91058d1909514095f84fe6f', prefix_symbol=None, main_symbol='nBq/L')]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('646be396-8f18-5e0a-b183-2d987570b812'), exact_ontology_match=['http://qudt.org/vocab/unit/S-M2-PER-MOL'], close_ontology_match=None, rdf_type=None, iri=None, name='S-M2-PER-MOL', label=[Label(text='Siemens Square metre per mole', lang='en')], short_name=None, query_label=None, description=None, image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='S·m²/mol', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('4223c921-2104-5211-96c4-e0355088f6a2'), exact_ontology_match=['http://qudt.org/vocab/unit/DEG_C-PER-MIN'], close_ontology_match=None, rdf_type=None, iri=None, name='DEG_C-PER-MIN', label=[Label(text='Degree Celsius per Minute', lang='en')], short_name=None, query_label=None, description=[Description(text="$\\textit{Degree Celsius per Minute}$ is a unit for 'Temperature Per Time' expressed as $degC / m$.", lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='°C/min', conversion_factor_from_si=0.016666666666666666, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('c51652fc-56f1-518e-babb-2c7f7701436e'), exact_ontology_match=['http://qudt.org/vocab/unit/K-M-PER-W'], close_ontology_match=None, rdf_type=None, iri=None, name='K-M-PER-W', label=[Label(text='Kelvin Metre per Watt', lang='en')], short_name=None, query_label=None, description=[Description(text='product of the SI base unit kelvin and the SI base unit metre divided by the derived SI unit watt', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='K·m/W', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('5a0326dc-cf68-5dfc-a1de-8fb221a03e5d'), exact_ontology_match=['http://qudt.org/vocab/unit/K-PER-SEC'], close_ontology_match=None, rdf_type=None, iri=None, name='K-PER-SEC', label=[Label(text='Kelvin per Second', lang='en')], short_name=None, query_label=None, description=[Description(text="$\\textit{Kelvin per Second}$ is a unit for 'Temperature Per Time' expressed as $K / s$.", lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='K/s', conversion_factor_from_si=1.0, prefix_units=[]),
#  QuantityUnit(type=['Category:OSWd2520fa016844e01af0097a85bb25b25'], uuid=UUID('7f25bfbc-7678-5295-bbbe-8366288c6466'), exact_ontology_match=['http://qudt.org/vocab/unit/MOL-PER-M2'], close_ontology_match=None, rdf_type=None, iri=None, name='MOL-PER-M2', label=[Label(text='Moles per square metre', lang='en')], short_name=None, query_label=None, description=[Description(text='SI unit of quantity of matter per SI unit area.', lang='en')], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=None, entry_access=None, main_symbol='mol/m²', conversion_factor_from_si=1.0, prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='03d5494b-fe83-598c-baee-9c6ae30b3b0c', exact_ontology_match=['http://qudt.org/vocab/unit/MilliMOL-PER-M2'], close_ontology_match=None, osw_id='Item:OSW7f25bfbc76785295bbbe8366288c6466#OSW03d5494bfe83598cbaee9c6ae30b3b0c', conversion_factor_from_si=0.001, prefix='Item:OSW6d63c0f4ea7b56b280d1a6d363ec48c6', prefix_symbol=None, main_symbol='mmol/m²'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='389ad365-990b-5b5a-ac4e-ebdad967c1b9', exact_ontology_match=['http://qudt.org/vocab/unit/MicroMOL-PER-M2'], close_ontology_match=None, osw_id='Item:OSW7f25bfbc76785295bbbe8366288c6466#OSW389ad365990b5b5aac4eebdad967c1b9', conversion_factor_from_si=1e-06, prefix='Item:OSW59f1ae99ce85577d995c76e442b46e74', prefix_symbol=None, main_symbol='µmol/m²')])]
# not described units couter:  69
# num of non prfixed units:  333

# %% [markdown]
# ## HANDLE Kilogram and Gram

# %%
# Step 1 - Create the QuantityUnit object of Kilogram
from pprint import pprint

# check if http://qudt.org/vocab/unit/KiloGM is in the list of all_prefixed_units
if "http://qudt.org/vocab/unit/KiloGM" in all_prefixed_units:
    print("http://qudt.org/vocab/unit/KiloGM is in all_prefixed_units")


unit_kg = model.PrefixUnit

unit = model.QuantityUnit(
    uuid=_uuid,
    exact_ontology_match=ontology_match_list,
    name=name,
    label=osw_label_list,
    main_symbol=symbol,
    # prefix_units=prefix_unit_list, # must be empty
    description=description_list,
    conversion_factor_from_si=conversion_multiplier,
)
# Out:
# http://qudt.org/vocab/unit/KiloGM is in all_prefixed_units

# %% [markdown]
# ## Upload Units to DEV WIKI

# %%
# # Test of single unit
# # test_unit = units[6]
# # pprint(test_unit.dict())

# from osw.core import OSW

# # Upload single unit to OSW
# # osw_obj.delete_entity(test_unit)
# # osw_obj.store_entity(test_unit)

# # Upload all units to OSW
# # osw_obj.delete_entity(units)
# # osw_obj.store_entity(units)
# osw_obj.store_entity(OSW.StoreEntityParam(entities=units, overwrite=True))

# %% [markdown]
# # Quantity Kind

# %% [markdown]
# ## Check uploaded units with quantities for unit reference

# %%
import uuid


# Already fetched all Quantity Kind from Qudt
qudt_quantitykind_bindings = qudt_qk["results"]["bindings"]
print("num of quantities: ", len(qudt_quantitykind_bindings))
# pprint(qudt_quantitykind_bindings[0])

match_uploaded_units_counter = 0
match_not_uploaded_units_counter = 0
undefined_non_prefixed_units_counter = 0
undefined_descriptions_counter = 0

for quantity_binding in qudt_quantitykind_bindings:

    # Set deterministic UUID for the quantity kind
    _uuid_quantity = uuid.uuid5(
        namespace=uuid.NAMESPACE_URL,
        name=quantity_binding["quantity"]["value"],
    )

    # Get all the prefixed and non prefixed units of the quantity kind
    non_prefixed_units, prefixed_units = split_prefixed_applicable_units(
        quantity_binding["applicableUnits"]["value"]
    )

    # Set deterministic UUIDs for the non prefixed units
    osw_item_uuids_non_prefixed_units = [
        f"Item:OSW{str(uuid.uuid5(namespace=uuid.NAMESPACE_URL, name=unit)).replace('-', '')}"
        for unit in non_prefixed_units
    ]

    # sequence of "description" before "plainTextDescription" is essential for overwriting
    description_list = None
    if "descriptions" in quantity_binding:
        description_split_list = quantity_binding["descriptions"][
            "value"
        ].split(" #,# ")
        # if len(description_split_list) > 1:
        #     # This is just one case, set default to use the first description and english
        #     print(description_split_list)
        description_list = [
            model.Description(
                text=description_split_list[0].strip(),
                lang="en",
            )
        ]
    # Overwrite description if plainTextDescription is present
    if "plainTextDescriptions" in quantity_binding:
        plain_description_split_list = quantity_binding[
            "plainTextDescriptions"
        ]["value"].split(" #,# ")
        # if len(plain_description_split_list) > 1:
        #     # This is just one case, set default to use the first description and englishSW
        #     print(plain_description_split_list)
        description_list = [
            model.Description(
                text=plain_description_split_list[0].strip(),
                lang="en",
            )
        ]

    qlabels = quantity_binding["labels"]["value"]
    label_dict = dict_from_comma_separated_list(qlabels)
    # print(label_dict)
    clean_label_dict = label_dict.copy()
    for lang, text in label_dict.items():
        # print(lang, text)
        # Remove item if "en-US" and "en" are present
        if lang == "en-US" and "en" in label_dict.keys():
            del clean_label_dict["en-US"]
        # Rename "en-US" to "en" if "en" is not present
        if lang == "en-US" and "en" not in label_dict.keys():
            clean_label_dict["en"] = text
            del clean_label_dict["en-US"]
        # Set default language to "en" if key is empty and "en" is not present
        if lang == "" and "en" not in label_dict.keys():
            clean_label_dict["en"] = clean_label_dict[""]
            del clean_label_dict[""]
        # Remove empty item if "en" is present
        if lang == "" and "en" in label_dict.keys():
            del clean_label_dict[""]

        # print(f"clean_label_dict: {clean_label_dict}")

    osw_label_list = [
        model.Label(text=value, lang=key)
        for key, value in clean_label_dict.items()
    ]

    # if "Polarizability" in quantity_binding["quantity"]["value"]:
    #     print(description_list)
    #     print(osw_label_list)
    #     print(
    #         f"osw_item_uuid_non_prefixed_units: {osw_item_uuids_non_prefixed_units}"
    #     )

    # Match uploaded Unit with applicable units of the Quantity Kind
    gramm_units = []
    matched_uploaded_units = []
    mateched_not_uploaded_units = []
    if non_prefixed_units != []:
        match_uploaded_units_counter += 1
    else:
        #
        gramm_units = remove_kilo_list(prefixed_units)
        # print(f"Gramm units: {gramm_units}")
        # print(f"Try to match with uploaded units")
        for gramm_unit in gramm_units:
            if gramm_unit in all_non_prefixed_units:
                print(
                    f"Quantity exists: {quantity_binding['quantity']['value']}"
                )
                print(f"Matched with uploaded unit: {gramm_unit}")
                # match_uploaded_units_counter += 1
                matched_uploaded_units.append(gramm_unit)

            else:
                # print(
                #     f"Non prefixed units empty for {quantity_binding['quantity']['value']}"
                # )
                # print(f"No match found for: {gramm_unit}")
                mateched_not_uploaded_units = prefixed_units

        if matched_uploaded_units != []:
            match_uploaded_units_counter += 1
        else:
            match_not_uploaded_units_counter += 1
            print(
                f"QuantityKind of not uploaded units: {quantity_binding['quantity']['value']}"
            )
            print(
                f"Mateched not uploaded units: {mateched_not_uploaded_units}"
            )

    # osw_quantity = model.QuantityKind(
    #     uuid=_uuid_quantity,
    #     label=osw_label_list,
    #     description=description_list,
    #     exact_ontology_match=[quantity_binding["quantity"]["value"]],
    #     units=osw_item_uuids_non_prefixed_units,
    # )

    # print(f"OSW Quantity Kind: {osw_quantity.dict()}")
    # throw error if osw_item_uuids_non_prefixed_units is empty

    if len(osw_item_uuids_non_prefixed_units) == 0:
        undefined_non_prefixed_units_counter += 1
        # print(f"Empty units for {osw_quantity.exact_ontology_match}")
        # print(f"prefixed_units: {prefixed_units}")

    if description_list == None:
        undefined_descriptions_counter += 1
        # print(f"Empty description for {osw_quantity.exact_ontology_match}")


print(f"match_uploaded_units_counter: {match_uploaded_units_counter}")
print(f"match_not_uploaded_units_counter: {match_not_uploaded_units_counter}")
print(
    f"undefined_non_prefixed_units_counter: {undefined_non_prefixed_units_counter}"
)
print(f"undefined_descriptions_counter: {undefined_descriptions_counter}")
# Out:
# num of quantities:  329
# Quantity exists: http://qudt.org/vocab/quantitykind/MassConcentrationOfWaterVapour
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M3
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/SpecificVolume
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/CentiM3-PER-GM', 'http://qudt.org/vocab/unit/DeciL-PER-GM', 'http://qudt.org/vocab/unit/L-PER-KiloGM', 'http://qudt.org/vocab/unit/M3-PER-KiloGM', 'http://qudt.org/vocab/unit/MilliL-PER-GM', 'http://qudt.org/vocab/unit/MilliL-PER-KiloGM', 'http://qudt.org/vocab/unit/MilliM3-PER-GM', 'http://qudt.org/vocab/unit/MilliM3-PER-KiloGM']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/ExposureRate
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/C-PER-KiloGM-SEC']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/InverseEnergy
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/PER-KiloV-A-HR']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/MomentOfInertia
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/KiloGM-CentiM2', 'http://qudt.org/vocab/unit/KiloGM-M2', 'http://qudt.org/vocab/unit/KiloGM-MilliM2']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/LengthTemperatureTime
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/CentiM-SEC-DEG_C']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/RotationalMass
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/KiloGM-CentiM2', 'http://qudt.org/vocab/unit/KiloGM-M2', 'http://qudt.org/vocab/unit/KiloGM-MilliM2']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/VolumetricFlux
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/MilliL-PER-CentiM2-MIN', 'http://qudt.org/vocab/unit/MilliL-PER-CentiM2-SEC']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/IonicStrength
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/CentiMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/KiloMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/MOL-PER-KiloGM', 'http://qudt.org/vocab/unit/MicroMOL-PER-GM', 'http://qudt.org/vocab/unit/MilliMOL-PER-GM', 'http://qudt.org/vocab/unit/MilliMOL-PER-KiloGM']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/SpecificHeatVolume
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/J-PER-KiloGM-K-M3']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/BloodGlucoseLevel
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/MilliMOL-PER-L']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/MassTemperature
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/KiloGM-K']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/LengthMass
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/GM-MilliM', 'http://qudt.org/vocab/unit/M-KiloGM']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/WaterVaporDiffusionCoefficient
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/KiloGM-PER-PA-SEC-M']
# Quantity exists: http://qudt.org/vocab/quantitykind/EnergyPerTemperature
# Matched with uploaded unit: http://qudt.org/vocab/unit/J-PER-K
# Quantity exists: http://qudt.org/vocab/quantitykind/SpecificWeight
# Matched with uploaded unit: http://qudt.org/vocab/unit/N-PER-M3
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/LengthEnergy
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/MegaEV-FemtoM']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/Permeance
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/NanoH']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/MassicActivity
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/BQ-PER-KiloGM']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/SpecificOpticalRotatoryPower
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/RAD-M2-PER-KiloGM']
# Quantity exists: http://qudt.org/vocab/quantitykind/MassConcentration
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M3
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/BloodGlucoseLevel_Mass
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/MilliGM-PER-DeciL']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/PhotosyntheticPhotonFlux
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/MicroMOL-PER-SEC']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/LinearCompressibility
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/MicroM-PER-N']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/VaporPermeability
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/KiloGM-PER-M2-PA-SEC', 'http://qudt.org/vocab/unit/NanoGM-PER-M2-PA-SEC']
# Quantity exists: http://qudt.org/vocab/quantitykind/SurfaceDensity
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M2
# Quantity exists: http://qudt.org/vocab/quantitykind/SurfaceDensity
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M2
# Quantity exists: http://qudt.org/vocab/quantitykind/LinearDensity
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/AmountOfSubstancePerMass
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/CentiMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/FemtoMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/KiloMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/MOL-PER-KiloGM', 'http://qudt.org/vocab/unit/MicroMOL-PER-GM', 'http://qudt.org/vocab/unit/MicroMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/MilliMOL-PER-GM', 'http://qudt.org/vocab/unit/MilliMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/NanoMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/PicoMOL-PER-KiloGM']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/SpecificHeatPressure
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/J-PER-KiloGM-K-PA']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/SpecificActivity
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/BQ-PER-KiloGM', 'http://qudt.org/vocab/unit/MicroBQ-PER-KiloGM', 'http://qudt.org/vocab/unit/MilliBQ-PER-GM', 'http://qudt.org/vocab/unit/MilliBQ-PER-KiloGM']
# Quantity exists: http://qudt.org/vocab/quantitykind/MeanMassRange
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M2
# Quantity exists: http://qudt.org/vocab/quantitykind/MassEnergyTransferCoefficient
# Matched with uploaded unit: http://qudt.org/vocab/unit/M2-PER-GM
# Quantity exists: http://qudt.org/vocab/quantitykind/MassAbsorptionCoefficient
# Matched with uploaded unit: http://qudt.org/vocab/unit/M2-PER-GM
# Quantity exists: http://qudt.org/vocab/quantitykind/BodyMassIndex
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M2
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/AmountOfSubstancePerMassPressure
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/MOL-PER-KiloGM-PA']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/PressureLossPerLength
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/KiloGM-PER-M2-SEC2']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/TotalMassStoppingPower
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/J-M2-PER-KiloGM']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/AreaTime
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/CentiM2-MIN', 'http://qudt.org/vocab/unit/CentiM2-SEC']
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/InverseMass_Squared
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/PER-KiloGM2']
# Quantity exists: http://qudt.org/vocab/quantitykind/MassConcentrationOfWater
# Matched with uploaded unit: http://qudt.org/vocab/unit/GM-PER-M3
# QuantityKind of not uploaded units: http://qudt.org/vocab/quantitykind/MassPerEnergy
# Mateched not uploaded units: ['http://qudt.org/vocab/unit/KiloGM-PER-GigaJ', 'http://qudt.org/vocab/unit/KiloGM-PER-J']
# match_uploaded_units_counter: 299
# match_not_uploaded_units_counter: 30
# undefined_non_prefixed_units_counter: 41
# undefined_descriptions_counter: 59

# %% [markdown]
# ### Helper for OSW Domain Check by unit_path

# %%
import uuid


def get_qudt_osl_item(
    qudt_uri="http://qudt.org/vocab/unit/GM-PER-M3",
    osl_domain="https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW",
):

    return osl_domain + str(
        uuid.uuid5(
            namespace=uuid.NAMESPACE_URL,
            name=qudt_uri,
        )

    ).replace("-", "")


get_qudt_osl_item()
# Out:
# 'https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW9161ae8b61ca56a687f8db32bdf2ddd3'

# %% [markdown]
# ### Manually update missing Qudt non-prefixed-units

# %%
import requests
import re

qudt_unit_domain = "http://qudt.org/vocab/unit/"
missing_non_prefixed_units_GM = [
    "M3-PER-GM",
    "GM-PER-M3",
    "L-PER-GM",
    "GM-PER-L",
    "C-PER-GM-SEC",
    "GM-M2",
    "MOL-PER-GM",
    "J-PER-GM-K-M3",
    "GM-K",
    "GM-M",
    "GM-PER-PA-SEC-M",
    "BQ-PER-GM",
    "RAD-M2-PER-GM",
]

# TODO: handle others (prefixes must be deleted, just to show where prefix is used)
missing_non_prefixed_units_others = [
    "PER-KiloV-A-HR",
    "CentiM-SEC-DEG_C",
    "MilliL-PER-CentiM2-MIN",
    "MilliMOL-PER-L",
    "MegaEV-FemtoM",
    "NanoH",
]

# For each missing non prefixed unit, check if URI exists
for unit in missing_non_prefixed_units_GM:
    res = requests.get(qudt_unit_domain + unit)
    print(f"{qudt_unit_domain + unit}: {res.status_code}")
    # If exists show the url of the osw item
    if res.status_code == 200:
        print(
            f"osw url: {get_qudt_osl_item(qudt_uri=qudt_unit_domain + unit)}\n"
        )
    # If not exists check if prefixed unit with "Kilo added to GM" exists
    if res.status_code == 404:
        # Use Regex to replace "GM" with "KiloGM"
        print(
            "above unit not found in QUDT ontology, try to replace GM with KiloGM"
        )
        unit = re.sub(r"GM", "KiloGM", unit)
        res = requests.get(qudt_unit_domain + unit)
        print(f"{qudt_unit_domain + unit}: {res.status_code}\n")
# Out:
# http://qudt.org/vocab/unit/M3-PER-GM: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/M3-PER-KiloGM: 200
#
# http://qudt.org/vocab/unit/GM-PER-M3: 200
# osw url: https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW9161ae8b61ca56a687f8db32bdf2ddd3
#
# http://qudt.org/vocab/unit/L-PER-GM: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/L-PER-KiloGM: 200
#
# http://qudt.org/vocab/unit/GM-PER-L: 200
# osw url: https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW754b1a3564725113ac583f91ae2ea959
#
# http://qudt.org/vocab/unit/C-PER-GM-SEC: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/C-PER-KiloGM-SEC: 200
#
# http://qudt.org/vocab/unit/GM-M2: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/KiloGM-M2: 200
#
# http://qudt.org/vocab/unit/MOL-PER-GM: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/MOL-PER-KiloGM: 200
#
# http://qudt.org/vocab/unit/J-PER-GM-K-M3: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/J-PER-KiloGM-K-M3: 200
#
# http://qudt.org/vocab/unit/GM-K: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/KiloGM-K: 200
#
# http://qudt.org/vocab/unit/GM-M: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/KiloGM-M: 200
#
# http://qudt.org/vocab/unit/GM-PER-PA-SEC-M: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/KiloGM-PER-PA-SEC-M: 200
#
# http://qudt.org/vocab/unit/BQ-PER-GM: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/BQ-PER-KiloGM: 200
#
# http://qudt.org/vocab/unit/RAD-M2-PER-GM: 404
# above unit not found in QUDT ontology, try to replace GM with KiloGM
# http://qudt.org/vocab/unit/RAD-M2-PER-KiloGM: 200

# %%
print(get_qudt_osl_item(qudt_uri="http://qudt.org/vocab/unit/GM"))
# Out:
# https://wiki-dev.open-semantic-lab.org/wiki/Item:OSW3c9bf4c3682f5a52b6e99f7ad7949903
