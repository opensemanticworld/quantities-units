# %% [markdown]
# # 2. Units

# %% [markdown]
# ## Fetch prefixes name list

# %%
import requests
from pprint import pprint
import json

sidf_prefixes_res_de = requests.get(
    url="https://si-digital-framework.org/SI/prefixes",
    params={"lang": "de"},
)

# Convert result to dict
sidf_prefixes_de = sidf_prefixes_res_de.json()
print(sidf_prefixes_de)
prefix_name_list = [item["label"] for item in sidf_prefixes_de]
print(prefix_name_list)
# Out:
# [{'label': 'quecto', 'symbol': 'q', 'scalingFactor': 1e-30, 'prefixId': 'quecto', 'scalingFactorStr': '1e-30', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/quecto'}, {'label': 'ronto', 'symbol': 'r', 'scalingFactor': 1e-27, 'prefixId': 'ronto', 'scalingFactorStr': '1e-27', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/ronto'}, {'label': 'yocto', 'symbol': 'y', 'scalingFactor': 1e-24, 'prefixId': 'yocto', 'scalingFactorStr': '1e-24', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/yocto'}, {'label': 'zepto', 'symbol': 'z', 'scalingFactor': 1e-21, 'prefixId': 'zepto', 'scalingFactorStr': '1e-21', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/zepto'}, {'label': 'atto', 'symbol': 'a', 'scalingFactor': 1e-18, 'prefixId': 'atto', 'scalingFactorStr': '1e-18', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/atto'}, {'label': 'femto', 'symbol': 'f', 'scalingFactor': 1e-15, 'prefixId': 'femto', 'scalingFactorStr': '1e-15', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/femto'}, {'label': 'pico', 'symbol': 'p', 'scalingFactor': 1e-12, 'prefixId': 'pico', 'scalingFactorStr': '1e-12', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/pico'}, {'label': 'nano', 'symbol': 'n', 'scalingFactor': 1e-09, 'prefixId': 'nano', 'scalingFactorStr': '1e-09', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/nano'}, {'label': 'micro', 'symbol': 'µ', 'scalingFactor': 1e-06, 'prefixId': 'micro', 'scalingFactorStr': '1e-06', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/micro'}, {'label': 'milli', 'symbol': 'm', 'scalingFactor': 0.001, 'prefixId': 'milli', 'scalingFactorStr': '1e-03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/milli'}, {'label': 'centi', 'symbol': 'c', 'scalingFactor': 0.01, 'prefixId': 'centi', 'scalingFactorStr': '1e-02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/centi'}, {'label': 'deci', 'symbol': 'd', 'scalingFactor': 0.1, 'prefixId': 'deci', 'scalingFactorStr': '1e-01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/deci'}, {'label': 'deca', 'symbol': 'da', 'scalingFactor': 10.0, 'prefixId': 'deca', 'scalingFactorStr': '1e+01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/deca'}, {'label': 'hecto', 'symbol': 'h', 'scalingFactor': 100.0, 'prefixId': 'hecto', 'scalingFactorStr': '1e+02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/hecto'}, {'label': 'kilo', 'symbol': 'k', 'scalingFactor': 1000.0, 'prefixId': 'kilo', 'scalingFactorStr': '1e+03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http ...
# ['quecto', 'ronto', 'yocto', 'zepto', 'atto', 'femto', 'pico', 'nano', 'micro', 'milli', 'centi', 'deci', 'deca', 'hecto', 'kilo', 'mega', 'giga', 'tera', 'peta', 'exa', 'zetta', 'yotta', 'ronna', 'quetta']

# %% [markdown]
# ## Fetch all units from Qudt

# %%
from utils import sparql_wrapper

sparql_qudt_qk = sparql_wrapper.Sparql(
    endpoint="https://www.qudt.org/fuseki/qudt/sparql",
    src_filepath="../ontology/qudt/sparql/quantitykind.sparql",
    tgt_filepath="../ontology/qudt/data/quantitykind.json",
    debug=False,
)
qudt_qk = sparql_qudt_qk.execQuery()
# sparql_qudt_qk.writeJsonFile(data=qudt_qk)
pprint(qudt_qk)
print(len(qudt_qk))
# Out:
# Reading SPARQL Query from c:\Users\raeder\Desktop\dev\Gitlab\osw\apps\python-lvl2\quantities-units\src\quantities-units\utils\../ontology/qudt/sparql/quantitykind.sparql
# {'head': {'vars': ['quantity', 'qlabels', 'applicableUnits', 'ucumCodes']},
#  'results': {'bindings': [{'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/CentiM-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/CentiM-PER-KiloYR, '
#                                                         'http://qudt.org/vocab/unit/CentiM-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/CentiM-PER-YR, '
#                                                         'http://qudt.org/vocab/unit/GigaHZ-M, '
#                                                         'http://qudt.org/vocab/unit/KiloM-PER-DAY, '
#                                                         'http://qudt.org/vocab/unit/KiloM-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloM-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/M-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/M-PER-MIN, '
#                                                         'http://qudt.org/vocab/unit/M-PER-YR, '
#                                                         'http://qudt.org/vocab/unit/MicroM-PER-MIN, '
#                                                         'http://qudt.org/vocab/unit/MicroM-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/MilliM-PER-DAY, '
#                                                         'http://qudt.org/vocab/unit/MilliM-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/MilliM-PER-MIN, '
#                                                         'http://qudt.org/vocab/unit/MilliM-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/MilliM-PER-YR'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Geschwindigkeit@de, '
#                                                 'Halaju@ms, Rychlost@cs, '
#                                                 'hitrost@sl, hız@tr, '
#                                                 'prędkość@pl, velocidad@es, '
#                                                 'velocidade@pt, velocitas@la, '
#                                                 'velocity@en, velocità@it, '
#                                                 'vitesse@fr, viteză@ro, '
#                                                 'Επιφάνεια@el, Ско́рость@ru, '
#                                                 'מהירות@he, السرعة@ar, '
#                                                 'سرعت/تندی@fa, गति@hi, 速力@ja, '
#                                                 '速度@zh'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Velocity'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm.s-1, m/s, cm.h-1, cm/h, '
#                                                   'cm.ka-1, cm/ka, cm.s-1, '
#                                                   'cm/s, cm.a-1, cm/a, GHz.m, '
#                                                   'km.d-1, km.h-1, km/h, '
#                                                   'km.s-1, km/s, m.h-1, m/h, '
#                                                   'm.min-1, m/min, m.a-1, '
#                                                   'um.min-1, um/min, um.s-1, '
#                                                   'um/s, mm.d-1, mm/d, mm.h-1, '
#                                                   'mm/h, mm.min-1, mm/min, '
#                                                   'mm.s-1, mm/s, mm.a-1, '
#                                                   'mm/a'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/GigaW, '
#                                                         'http://qudt.org/vocab/unit/KiloW, '
#                                                         'http://qudt.org/vocab/unit/MegaW, '
#                                                         'http://qudt.org/vocab/unit/MicroW, '
#                                                         'http://qudt.org/vocab/unit/MilliW, '
#                                                         'http://qudt.org/vocab/unit/NanoW, '
#                                                         'http://qudt.org/vocab/unit/PicoW, '
#                                                         'http://qudt.org/vocab/unit/TeraW, '
#                                                         'http://qudt.org/vocab/unit/W, '
#                                                         'http://qudt.org/vocab/unit/GigaJ-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/HectoPA-L-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/HectoPA-M3-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/J-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/J-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/MegaJ-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/MegaJ-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/MegaPA-L-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/MegaPA-M3-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/PA-L-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/PA-M3-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/TeraW-HR-PER-YR'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Schallleistung@de, moc '
#                                                 'akustyczna@pl, potencie '
#                                                 'acústica@es, potenza '
#                                                 'sonora@it, potência '
#                                                 'acústica@pt, puissance '
#                                                 'acoustique@fr, sound '
#                                                 'power@en, звуковая '
#                                                 'мощность@ru, القدرة '
#                                                 'الصوتية@ar, 音源の音響出力@ja'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/SoundPower'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'GW, kW, MW, uW, mW, nW, pW, '
#                                                   'TW, W, GJ.h-1, hPa.L.s-1, '
#                                                   'hPa.m3.s-1, J.h-1, J.s-1, '
#                                                   'MJ.h-1, MJ.s-1, MPa.L.s-1, '
#                                                   'MPa.L/s, MPa.m3.s-1, '
#                                                   'Pa.L.s-1, Pa.L/s, '
#                                                   'Pa.m3.s-1, Pa.m3/s, TWh/a'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/LUX'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Luminous Emmitance@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/LuminousEmittance'},
#                            'ucumCodes': {'type': 'literal', 'value': 'lx'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/NP, '
#                                                         'http://qudt.org/vocab/unit/NUM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Lift Coefficient@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/LiftCoefficient'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'Np, 1, {#}'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/KiloGM, '
#                                                         'http://qudt.org/vocab/unit/CentiGM, '
#                                                         'http://qudt.org/vocab/unit/DecaGM, '
#                                                         'http://qudt.org/vocab/unit/DeciGM, '
#                                                         'http://qudt.org/vocab/unit/DeciTON_Metric, '
#                                                         'http://qudt.org/vocab/unit/GM, '
#                                                         'http://qudt.org/vocab/unit/HectoGM, '
#                                                         'http://qudt.org/vocab/unit/KiloTON_Metric, '
#                                                         'http://qudt.org/vocab/unit/MegaGM, '
#                                                         'http://qudt.org/vocab/unit/MicroGM, '
#                                                         'http://qudt.org/vocab/unit/MilliGM, '
#                                                         'http://qudt.org/vocab/unit/NanoGM, '
#                                                         'http://qudt.org/vocab/unit/PicoGM, '
#                                                         'http://qudt.org/vocab/unit/TONNE, '
#                                                         'http://qudt.org/vocab/unit/TON_Metric'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Mass Margin@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MASS-MARGIN'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'kg, cg, dag, dg, dt, g, hg, '
#                                                   'kt, Mg, ug, mg, ng, pg, t'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/SEC2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Time Squared@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Time_Squared'},
#                            'ucumCodes': {'type': 'literal', 'value': 's2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/BQ-PER-L, '
#                                                         'http://qudt.org/vocab/unit/BQ-PER-M3, '
#                                                         'http://qudt.org/vocab/unit/MicroBQ-PER-L, '
#                                                         'http://qudt.org/vocab/unit/MilliBQ-PER-L, '
#                                                         'http://qudt.org/vocab/unit/NanoBQ-PER-L'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Activity Concentration@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ActivityConcentration'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'Bq.L-1, Bq/L, Bq.m-3, '
#                                                   'Bq/m3, uBq.L-1, uBq/L, '
#                                                   'mBq.L-1, mBq/L, nBq.L-1, '
#                                                   'nBq/L'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/N-SEC-PER-RAD'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Momentum per Angle@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MomentumPerAngle'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'N.s.rad-1, N.s/rad'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J-SEC, '
#                                                         'http://qudt.org/vocab/unit/AttoJ-SEC'},
#                            'qlabels': {'type': 'literal', 'value': 'Action@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Action'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J.s, aJ.s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/AttoFARAD, '
#                                                         'http://qudt.org/vocab/unit/FARAD, '
#                                                         'http://qudt.org/vocab/unit/MicroFARAD, '
#                                                         'http://qudt.org/vocab/unit/MilliFARAD, '
#                                                         'http://qudt.org/vocab/unit/NanoFARAD, '
#                                                         'http://qudt.org/vocab/unit/PicoFARAD'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Capacitance@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Capacitance'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'aF, F, uF, mF, nF, pF'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J, '
#                                                         'http://qudt.org/vocab/unit/MegaEV, '
#                                                         'http://qudt.org/vocab/unit/EV, '
#                                                         'http://qudt.org/vocab/unit/GigaEV, '
#                                                         'http://qudt.org/vocab/unit/AttoJ, '
#                                                         'http://qudt.org/vocab/unit/ExaJ, '
#                                                         'http://qudt.org/vocab/unit/FemtoJ, '
#                                                         'http://qudt.org/vocab/unit/GigaJ, '
#                                                         'http://qudt.org/vocab/unit/GigaW-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloEV, '
#                                                         'http://qudt.org/vocab/unit/KiloJ, '
#                                                         'http://qudt.org/vocab/unit/KiloV-A-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloW-HR, '
#                                                         'http://qudt.org/vocab/unit/MegaJ, '
#                                                         'http://qudt.org/vocab/unit/MegaV-A-HR, '
#                                                         'http://qudt.org/vocab/unit/MegaW-HR, '
#                                                         'http://qudt.org/vocab/unit/MilliJ, '
#                                                         'http://qudt.org/vocab/unit/PetaJ, '
#                                                         'http://qudt.org/vocab/unit/TeraJ, '
#                                                         'http://qudt.org/vocab/unit/TeraW-HR, '
#                                                         'http://qudt.org/vocab/unit/V-A-HR, '
#                                                         'http://qudt.org/vocab/unit/W-HR, '
#                                                         'http://qudt.org/vocab/unit/W-SEC'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Energy Level@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/EnergyLevel'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J, MeV, eV, GeV, aJ, EJ, '
#                                                   'fJ, GJ, GW.h, keV, kJ, '
#                                                   'kV.A.h, kW.h, MJ, MV.A.h, '
#                                                   'MW.h, mJ, PJ, TJ, TW/h, '
#                                                   'V.A.h, W.h, W.s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/DEG, '
#                                                         'http://qudt.org/vocab/unit/GON, '
#                                                         'http://qudt.org/vocab/unit/MIN_Angle, '
#                                                         'http://qudt.org/vocab/unit/MicroRAD, '
#                                                         'http://qudt.org/vocab/unit/MilliRAD, '
#                                                         'http://qudt.org/vocab/unit/RAD'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Angle of Optical Rotation@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/AngleOfOpticalRotation'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': "deg, gon, ', urad, mrad, "
#                                                   'rad'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-SEC2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Inverse Square Time@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/InverseTime_Squared'},
#                            'ucumCodes': {'type': 'literal', 'value': 's-2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M2-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/CentiM2-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/M2-HZ, '
#                                                         'http://qudt.org/vocab/unit/MilliM2-PER-SEC'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Thermal Diffusivity@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ThermalDiffusivity'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2.s-1, m2/s, cm2.s-1, '
#                                                   'cm2/s, m2.Hz, mm2.s-1, '
#                                                   'mm2/s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PA, '
#                                                         'http://qudt.org/vocab/unit/DecaPA, '
#                                                         'http://qudt.org/vocab/unit/GigaPA, '
#                                                         'http://qudt.org/vocab/unit/HectoPA, '
#                                                         'http://qudt.org/vocab/unit/KiloGM-PER-M-SEC2, '
#                                                         'http://qudt.org/vocab/unit/KiloN-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/KiloPA, '
#                                                         'http://qudt.org/vocab/unit/KiloPA_A, '
#                                                         'http://qudt.org/vocab/unit/MegaPA, '
#                                                         'http://qudt.org/vocab/unit/MicroPA, '
#                                                         'http://qudt.org/vocab/unit/MilliPA, '
#                                                         'http://qudt.org/vocab/unit/N-PER-CentiM2, '
#                                                         'http://qudt.org/vocab/unit/N-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/N-PER-MilliM2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Web Time Average Pressure@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/WebTimeAveragePressure'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'Pa, daPa, GPa, hPa, '
#                                                   'kg.m-1.s-2, kN.m-2, kPa, '
#                                                   'kPa{absolute}, MPa, uPa, '
#                                                   'mPa, N.cm-2, N.m-2, '
#                                                   'N.mm-2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/NUM'},
#                            'qlabels': {'type': 'literal', 'value': 'Count@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Count'},
#                            'ucumCodes': {'type': 'literal', 'value': '1, {#}'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M, '
#                                                         'http://qudt.org/vocab/unit/AU, '
#                                                         'http://qudt.org/vocab/unit/CentiM, '
#                                                         'http://qudt.org/vocab/unit/DecaM, '
#                                                         'http://qudt.org/vocab/unit/DeciM, '
#                                                         'http://qudt.org/vocab/unit/FemtoM, '
#                                                         'http://qudt.org/vocab/unit/HectoM, '
#                                                         'http://qudt.org/vocab/unit/KiloM, '
#                                                         'http://qudt.org/vocab/unit/MicroM, '
#                                                         'http://qudt.org/vocab/unit/MilliM, '
#                                                         'http://qudt.org/vocab/unit/NanoM, '
#                                                         'http://qudt.org/vocab/unit/PicoM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Positive Length@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/PositiveLength'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm, AU, cm, dam, dm, fm, hm, '
#                                                   'km, um, mm, nm, pm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J, '
#                                                         'http://qudt.org/vocab/unit/MegaEV, '
#                                                         'http://qudt.org/vocab/unit/EV, '
#                                                         'http://qudt.org/vocab/unit/GigaEV, '
#                                                         'http://qudt.org/vocab/unit/AttoJ, '
#                                                         'http://qudt.org/vocab/unit/ExaJ, '
#                                                         'http://qudt.org/vocab/unit/FemtoJ, '
#                                                         'http://qudt.org/vocab/unit/GigaJ, '
#                                                         'http://qudt.org/vocab/unit/GigaW-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloEV, '
#                                                         'http://qudt.org/vocab/unit/KiloJ, '
#                                                         'http://qudt.org/vocab/unit/KiloV-A-HR, '
#                                                         'http://qudt.org/vocab/unit/KiloW-HR, '
#                                                         'http://qudt.org/vocab/unit/MegaJ, '
#                                                         'http://qudt.org/vocab/unit/MegaV-A-HR, '
#                                                         'http://qudt.org/vocab/unit/MegaW-HR, '
#                                                         'http://qudt.org/vocab/unit/MilliJ, '
#                                                         'http://qudt.org/vocab/unit/PetaJ, '
#                                                         'http://qudt.org/vocab/unit/TeraJ, '
#                                                         'http://qudt.org/vocab/unit/TeraW-HR, '
#                                                         'http://qudt.org/vocab/unit/V-A-HR, '
#                                                         'http://qudt.org/vocab/unit/W-HR, '
#                                                         'http://qudt.org/vocab/unit/W-SEC'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Donor Ionization Energy@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/DonorIonizationEnergy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J, MeV, eV, GeV, aJ, EJ, '
#                                                   'fJ, GJ, GW.h, keV, kJ, '
#                                                   'kV.A.h, kW.h, MJ, MV.A.h, '
#                                                   'MW.h, mJ, PJ, TJ, TW/h, '
#                                                   'V.A.h, W.h, W.s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/RAD-PER-M'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Kreisrepetenz@de, angular '
#                                                 'wavenumber@en, liczba falowa '
#                                                 "kątowa@pl, nombre d'onde "
#                                                 "angulaire@fr, numero d'onda "
#                                                 'angolare@it, número de onda '
#                                                 'angular@es, número de onda '
#                                                 'angular@pt, عدد موجى زاوى@ar, '
#                                                 '角波数@ja, 角波数@zh'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/AngularWavenumber'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'rad.m-1, rad/m'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-PA'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Inverse Pressure@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/InversePressure'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/Pa, Pa-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J-PER-CentiM2-DAY, '
#                                                         'http://qudt.org/vocab/unit/MicroW-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/MilliW-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/PicoW-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/W-PER-CentiM2, '
#                                                         'http://qudt.org/vocab/unit/W-PER-M2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Bestrahlungsstärke@de, '
#                                                 'Intenzita záření@cs, '
#                                                 'Kepenyinaran@ms, '
#                                                 'irradiance@en, '
#                                                 'irradiancia@es, '
#                                                 'irradianza@it, '
#                                                 'irradiância@pt, yoğunluk@tr, '
#                                                 'éclairement énergétique@fr, '
#                                                 'Поверхностная плотность '
#                                                 'потока энергии@ru, الطاقة '
#                                                 'الهلامية@ar, پرتو افکنی/چگالی '
#                                                 'تابش@fa, 熱流束@ja, 辐照度@zh'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Irradiance'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J.cm-2.d-1, uW.m-2, mW.m-2, '
#                                                   'pW.m-2, W.cm-2, W.m-2, '
#                                                   'W/m2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/BQ-SEC-PER-M3'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Absolute Activity@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/AbsoluteActivity'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'Bq.s.m-3'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/RAD-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/RAD-PER-MIN, '
#                                                         'http://qudt.org/vocab/unit/RAD-PER-SEC'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Larmor Angular Frequency@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/LarmorAngularFrequency'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'rad.h-1, rad/h, rad.min-1, '
#                                                   'rad/min, rad.s-1, rad/s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M, '
#                                                         'http://qudt.org/vocab/unit/AU, '
#                                                         'http://qudt.org/vocab/unit/CentiM, '
#                                                         'http://qudt.org/vocab/unit/DecaM, '
#                                                         'http://qudt.org/vocab/unit/DeciM, '
#                                                         'http://qudt.org/vocab/unit/FemtoM, '
#                                                         'http://qudt.org/vocab/unit/HectoM, '
#                                                         'http://qudt.org/vocab/unit/KiloM, '
#                                                         'http://qudt.org/vocab/unit/MicroM, '
#                                                         'http://qudt.org/vocab/unit/MilliM, '
#                                                         'http://qudt.org/vocab/unit/NanoM, '
#                                                         'http://qudt.org/vocab/unit/PicoM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Radial Distance@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/RadialDistance'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm, AU, cm, dam, dm, fm, hm, '
#                                                   'km, um, mm, nm, pm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-M3'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Particle Number Density@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ParticleNumberDensity'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/m3, m-3'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M2, '
#                                                         'http://qudt.org/vocab/unit/ARE, '
#                                                         'http://qudt.org/vocab/unit/CentiM2, '
#                                                         'http://qudt.org/vocab/unit/DecaARE, '
#                                                         'http://qudt.org/vocab/unit/DeciM2, '
#                                                         'http://qudt.org/vocab/unit/HA, '
#                                                         'http://qudt.org/vocab/unit/MicroM2, '
#                                                         'http://qudt.org/vocab/unit/MilliM2, '
#                                                         'http://qudt.org/vocab/unit/NanoM2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Migration Area@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MigrationArea'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2, ar, cm2, daar, dm2, '
#                                                   'har, um2, mm2, nm2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M2-PER-KiloW, '
#                                                         'http://qudt.org/vocab/unit/M2-PER-W'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Fläche pro Heizlast@de, area '
#                                                 'per heating load@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/AreaPerPower'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2.kW-1, m2.W-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/NUM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Stoichiometric Number@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/StoichiometricNumber'},
#                            'ucumCodes': {'type': 'literal', 'value': '1, {#}'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-K'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Hullámszám@hu, '
#                                                 'Volumenausdehnungskoeffizient@de, '
#                                                 'coefficient de dilatation '
#                                                 'volumique@fr, coefficiente di '
#                                                 'dilatazione volumica@it, '
#                                                 'coeficiente de dilatación '
#                                                 'cúbica@es, coeficiente de '
#                                                 'dilatação volúmica@pt, cubic '
#                                                 'expansion coefficient@en, '
#                                                 'kübik genleşme katsayısı@tr, '
#                                                 'współczynnik rozszerzalności '
#                                                 'objętościowej@pl, '
#                                                 'Κυματαριθμός@el, Вълново '
#                                                 'число@bg, Температурный '
#                                                 'коэффициент@ru, מספר גל@he, '
#                                                 'ضریب انبساط گرمایی@fa, معامل '
#                                                 'التمدد الحجمى@ar, 体膨胀系数@zh, '
#                                                 '線膨張係数@ja'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/CubicExpansionCoefficient'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/K, K-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/PER-H'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reluctance@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Reluctance'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '/H, H-1'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/DEG_C-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/DEG_C-PER-MIN, '
#                                                         'http://qudt.org/vocab/unit/DEG_C-PER-SEC, '
#                                                         'http://qudt.org/vocab/unit/DEG_C-PER-YR, '
#                                                         'http://qudt.org/vocab/unit/K-PER-HR, '
#                                                         'http://qudt.org/vocab/unit/K-PER-MIN, '
#                                                         'http://qudt.org/vocab/unit/K-PER-SEC'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Temperature per Time@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/TemperaturePerTime'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'Cel.h-1, Cel/h, Cel.min-1, '
#                                                   'Cel/min, Cel.s-1, Cel/s, '
#                                                   'Cel.a-1, Cel/a, K.h-1, '
#                                                   'K.min-1, K.s-1, K/s'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/NUM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Mass Number@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MassNumber'},
#                            'ucumCodes': {'type': 'literal', 'value': '1, {#}'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M, '
#                                                         'http://qudt.org/vocab/unit/AU, '
#                                                         'http://qudt.org/vocab/unit/CentiM, '
#                                                         'http://qudt.org/vocab/unit/DecaM, '
#                                                         'http://qudt.org/vocab/unit/DeciM, '
#                                                         'http://qudt.org/vocab/unit/FemtoM, '
#                                                         'http://qudt.org/vocab/unit/HectoM, '
#                                                         'http://qudt.org/vocab/unit/KiloM, '
#                                                         'http://qudt.org/vocab/unit/MicroM, '
#                                                         'http://qudt.org/vocab/unit/MilliM, '
#                                                         'http://qudt.org/vocab/unit/NanoM, '
#                                                         'http://qudt.org/vocab/unit/PicoM'},
#                            'qlabels': {'type': 'literal', 'value': 'Radius@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Radius'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm, AU, cm, dam, dm, fm, hm, '
#                                                   'km, um, mm, nm, pm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/J-PER-CentiM2-DAY, '
#                                                         'http://qudt.org/vocab/unit/MicroW-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/MilliW-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/PicoW-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/W-PER-CentiM2, '
#                                                         'http://qudt.org/vocab/unit/W-PER-M2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Power Per Area@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/PowerPerArea'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'J.cm-2.d-1, uW.m-2, mW.m-2, '
#                                                   'pW.m-2, W.cm-2, W.m-2, '
#                                                   'W/m2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/CentiN-M, '
#                                                         'http://qudt.org/vocab/unit/DeciN-M, '
#                                                         'http://qudt.org/vocab/unit/KiloN-M, '
#                                                         'http://qudt.org/vocab/unit/MegaN-M, '
#                                                         'http://qudt.org/vocab/unit/MicroN-M, '
#                                                         'http://qudt.org/vocab/unit/MilliN-M, '
#                                                         'http://qudt.org/vocab/unit/N-CentiM, '
#                                                         'http://qudt.org/vocab/unit/N-M'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Torsionmoment@de, coppia@it, '
#                                                 'couple@fr, moment '
#                                                 'obrotowy@pl, momento de '
#                                                 'torção@pt, par@es, torque@en, '
#                                                 'عزم محورى@ar, トルク@ja, 转矩@zh'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Torque'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'cN.m, dN.m, kN.m, MN.m, '
#                                                   'uN.m, mN.m, N.cm, N.m'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M2-PER-MOL'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Molar Attenuation '
#                                                 'Coefficient@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MolarAttenuationCoefficient'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2.mol-1, m2/mol'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/K-PER-T'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Temperature per Magnetic Flux '
#                                                 'Density@en'},
#                            'quantity': {'type': 'uri',
# ...
#                                                         'http://qudt.org/vocab/unit/FemtoM, '
#                                                         'http://qudt.org/vocab/unit/HectoM, '
#                                                         'http://qudt.org/vocab/unit/KiloM, '
#                                                         'http://qudt.org/vocab/unit/MicroM, '
#                                                         'http://qudt.org/vocab/unit/MilliM, '
#                                                         'http://qudt.org/vocab/unit/NanoM, '
#                                                         'http://qudt.org/vocab/unit/PicoM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Over-range distance@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/OverRangeDistance'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm, AU, cm, dam, dm, fm, hm, '
#                                                   'km, um, mm, nm, pm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/A-PER-RAD'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Electric Current per '
#                                                 'Angle@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/ElectricCurrentPerAngle'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'A.rad-1, A/rad'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M, '
#                                                         'http://qudt.org/vocab/unit/AU, '
#                                                         'http://qudt.org/vocab/unit/CentiM, '
#                                                         'http://qudt.org/vocab/unit/DecaM, '
#                                                         'http://qudt.org/vocab/unit/DeciM, '
#                                                         'http://qudt.org/vocab/unit/FemtoM, '
#                                                         'http://qudt.org/vocab/unit/HectoM, '
#                                                         'http://qudt.org/vocab/unit/KiloM, '
#                                                         'http://qudt.org/vocab/unit/MicroM, '
#                                                         'http://qudt.org/vocab/unit/MilliM, '
#                                                         'http://qudt.org/vocab/unit/NanoM, '
#                                                         'http://qudt.org/vocab/unit/PicoM'},
#                            'qlabels': {'type': 'literal', 'value': 'Depth@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Depth'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm, AU, cm, dam, dm, fm, hm, '
#                                                   'km, um, mm, nm, pm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M, '
#                                                         'http://qudt.org/vocab/unit/AU, '
#                                                         'http://qudt.org/vocab/unit/CentiM, '
#                                                         'http://qudt.org/vocab/unit/DecaM, '
#                                                         'http://qudt.org/vocab/unit/DeciM, '
#                                                         'http://qudt.org/vocab/unit/FemtoM, '
#                                                         'http://qudt.org/vocab/unit/HectoM, '
#                                                         'http://qudt.org/vocab/unit/KiloM, '
#                                                         'http://qudt.org/vocab/unit/MicroM, '
#                                                         'http://qudt.org/vocab/unit/MilliM, '
#                                                         'http://qudt.org/vocab/unit/NanoM, '
#                                                         'http://qudt.org/vocab/unit/PicoM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Center of Gravity in the Y '
#                                                 'axis@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/CenterOfGravity_Y'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm, AU, cm, dam, dm, fm, hm, '
#                                                   'km, um, mm, nm, pm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/N-M-PER-M2, '
#                                                         'http://qudt.org/vocab/unit/KiloN-PER-M, '
#                                                         'http://qudt.org/vocab/unit/MilliN-PER-M, '
#                                                         'http://qudt.org/vocab/unit/N-PER-CentiM, '
#                                                         'http://qudt.org/vocab/unit/N-PER-M, '
#                                                         'http://qudt.org/vocab/unit/N-PER-MilliM'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Linear Force@en, '
#                                                 'Streckenlast@de'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/LinearForce'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'N.m.m-2, kN.m-1, mN.m-1, '
#                                                   'mN/m, N.cm-1, N/cm, N.m-1, '
#                                                   'N/m, N.mm-1, N/mm'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/NUM, '
#                                                         'http://qudt.org/vocab/unit/FRACTION, '
#                                                         'http://qudt.org/vocab/unit/PERCENT, '
#                                                         'http://qudt.org/vocab/unit/PPB, '
#                                                         'http://qudt.org/vocab/unit/PPM, '
#                                                         'http://qudt.org/vocab/unit/PPQ, '
#                                                         'http://qudt.org/vocab/unit/PPT, '
#                                                         'http://qudt.org/vocab/unit/PPTH'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Voltage Ratio@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/VoltageRatio'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '1, {#}, {fraction}, %, '
#                                                   '[ppb], [ppm], [ppq], [ppt], '
#                                                   '[ppth]'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/FRACTION, '
#                                                         'http://qudt.org/vocab/unit/PERCENT'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Reflectance@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/Reflectance'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '{fraction}, %'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/LM-PER-W'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Luminous Efficacy@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/LuminousEfficacy'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'lm.W-1, lm/W'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/M2, '
#                                                         'http://qudt.org/vocab/unit/ARE, '
#                                                         'http://qudt.org/vocab/unit/CentiM2, '
#                                                         'http://qudt.org/vocab/unit/DecaARE, '
#                                                         'http://qudt.org/vocab/unit/DeciM2, '
#                                                         'http://qudt.org/vocab/unit/HA, '
#                                                         'http://qudt.org/vocab/unit/MicroM2, '
#                                                         'http://qudt.org/vocab/unit/MilliM2, '
#                                                         'http://qudt.org/vocab/unit/NanoM2'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Equivalent absorption '
#                                                 'area@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/EquivalentAbsorptionArea'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'm2, ar, cm2, daar, dm2, '
#                                                   'har, um2, mm2, nm2'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/DEG, '
#                                                         'http://qudt.org/vocab/unit/GON, '
#                                                         'http://qudt.org/vocab/unit/MIN_Angle, '
#                                                         'http://qudt.org/vocab/unit/MicroRAD, '
#                                                         'http://qudt.org/vocab/unit/MilliRAD, '
#                                                         'http://qudt.org/vocab/unit/RAD'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Phasenverschiebungswinkel@de, '
#                                                 'diferencia de fase@es, '
#                                                 'diferença de fase@pt, '
#                                                 'différence de phase@fr, phase '
#                                                 'difference@en, przesunięcie '
#                                                 'fazowe@pl, sfasamento '
#                                                 'angolare@it, اختلاف طور@ar, '
#                                                 '位相差@ja'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/PhaseDifference'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': "deg, gon, ', urad, mrad, "
#                                                   'rad'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/NUM, '
#                                                         'http://qudt.org/vocab/unit/FRACTION, '
#                                                         'http://qudt.org/vocab/unit/PERCENT, '
#                                                         'http://qudt.org/vocab/unit/PPB, '
#                                                         'http://qudt.org/vocab/unit/PPM, '
#                                                         'http://qudt.org/vocab/unit/PPQ, '
#                                                         'http://qudt.org/vocab/unit/PPT, '
#                                                         'http://qudt.org/vocab/unit/PPTH'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Positive Dimensionless '
#                                                 'Ratio@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/PositiveDimensionlessRatio'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '1, {#}, {fraction}, %, '
#                                                   '[ppb], [ppm], [ppq], [ppt], '
#                                                   '[ppth]'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/N, '
#                                                         'http://qudt.org/vocab/unit/KiloN, '
#                                                         'http://qudt.org/vocab/unit/MegaN, '
#                                                         'http://qudt.org/vocab/unit/MicroN, '
#                                                         'http://qudt.org/vocab/unit/MilliN'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Max Operating Thrust@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/MaxOperatingThrust'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': 'N, kN, MN, uN, mN'}},
#                           {'applicableUnits': {'type': 'literal',
#                                                'value': 'http://qudt.org/vocab/unit/NUM, '
#                                                         'http://qudt.org/vocab/unit/FRACTION, '
#                                                         'http://qudt.org/vocab/unit/PERCENT, '
#                                                         'http://qudt.org/vocab/unit/PPB, '
#                                                         'http://qudt.org/vocab/unit/PPM, '
#                                                         'http://qudt.org/vocab/unit/PPQ, '
#                                                         'http://qudt.org/vocab/unit/PPT, '
#                                                         'http://qudt.org/vocab/unit/PPTH'},
#                            'qlabels': {'type': 'literal',
#                                        'value': 'Length Ratio@en'},
#                            'quantity': {'type': 'uri',
#                                         'value': 'http://qudt.org/vocab/quantitykind/LengthRatio'},
#                            'ucumCodes': {'type': 'literal',
#                                          'value': '1, {#}, {fraction}, %, '
#                                                   '[ppb], [ppm], [ppq], [ppt], '
#                                                   '[ppth]'}}]}}
# 2

# %% [markdown]
# ## Split applicableUnits into prefixedUnits and nonPrefixedUnits

# %%
from utils import sparql_wrapper
from pprint import pprint
import json
import requests

quant_kind_list = json.load(open("ontology/qudt/data/quantitykind.json", "r"))[
    "results"
]["bindings"]

pprint(quant_kind_list[5]["applicableUnits"])


def get_prefix_list():

    sidf_prefixes_res_de = requests.get(
        url="https://si-digital-framework.org/SI/prefixes",
        params={"lang": "de"},
    )

    # Convert result to dict
    sidf_prefixes_de = sidf_prefixes_res_de.json()
    print(sidf_prefixes_de)
    prefix_name_list = [item["label"] for item in sidf_prefixes_de]
    print(prefix_name_list)
    return prefix_name_list


prefix_name_list = get_prefix_list()


def get_unit_prefix(unit_str):
    for prefix in prefix_name_list:
        if prefix in unit_str.lower():
            return prefix
    return None


def get_non_prefixed_units_from_applicable_units(applicable_units_str):
    non_prefixed_units = []
    prefixed_units = []
    for unit_str in applicable_units_str.split(", "):

        print(unit_str)
        print(get_unit_prefix(unit_str))
        if get_unit_prefix(unit_str) == None:
            print("no prefix: ", unit_str)
            non_prefixed_units.append(unit_str)
        else:
            print("prefix: ", get_unit_prefix(unit_str), "found in ", unit_str)
            prefixed_units.append(unit_str)
    return non_prefixed_units, prefixed_units


all_prefixed_units = []
all_non_prefixed_units = []
for quant_kind in quant_kind_list:
    non_prefixed, prefixed = get_non_prefixed_units_from_applicable_units(
        quant_kind["applicableUnits"]["value"]
    )
    all_prefixed_units = all_prefixed_units + prefixed
    all_non_prefixed_units = all_non_prefixed_units + non_prefixed

all_prefixed_units = list(set(all_prefixed_units))
all_non_prefixed_units = list(set(all_non_prefixed_units))

print(len(all_prefixed_units))
print(len(all_non_prefixed_units))
# Out:
# {'type': 'literal', 'value': 'http://qudt.org/vocab/unit/SEC2'}
# [{'label': 'quecto', 'symbol': 'q', 'scalingFactor': 1e-30, 'prefixId': 'quecto', 'scalingFactorStr': '1e-30', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/quecto'}, {'label': 'ronto', 'symbol': 'r', 'scalingFactor': 1e-27, 'prefixId': 'ronto', 'scalingFactorStr': '1e-27', 'doi': 'https://doi.org/10.59161/cgpm2022res3e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/ronto'}, {'label': 'yocto', 'symbol': 'y', 'scalingFactor': 1e-24, 'prefixId': 'yocto', 'scalingFactorStr': '1e-24', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/yocto'}, {'label': 'zepto', 'symbol': 'z', 'scalingFactor': 1e-21, 'prefixId': 'zepto', 'scalingFactorStr': '1e-21', 'doi': 'https://doi.org/10.59161/cgpm1991res4e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/zepto'}, {'label': 'atto', 'symbol': 'a', 'scalingFactor': 1e-18, 'prefixId': 'atto', 'scalingFactorStr': '1e-18', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/atto'}, {'label': 'femto', 'symbol': 'f', 'scalingFactor': 1e-15, 'prefixId': 'femto', 'scalingFactorStr': '1e-15', 'doi': 'https://doi.org/10.59161/cgpm1964res8e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/femto'}, {'label': 'pico', 'symbol': 'p', 'scalingFactor': 1e-12, 'prefixId': 'pico', 'scalingFactorStr': '1e-12', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/pico'}, {'label': 'nano', 'symbol': 'n', 'scalingFactor': 1e-09, 'prefixId': 'nano', 'scalingFactorStr': '1e-09', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/nano'}, {'label': 'micro', 'symbol': 'µ', 'scalingFactor': 1e-06, 'prefixId': 'micro', 'scalingFactorStr': '1e-06', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#float', 'pid': 'https://si-digital-framework.org/SI/prefixes/micro'}, {'label': 'milli', 'symbol': 'm', 'scalingFactor': 0.001, 'prefixId': 'milli', 'scalingFactorStr': '1e-03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/milli'}, {'label': 'centi', 'symbol': 'c', 'scalingFactor': 0.01, 'prefixId': 'centi', 'scalingFactorStr': '1e-02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/centi'}, {'label': 'deci', 'symbol': 'd', 'scalingFactor': 0.1, 'prefixId': 'deci', 'scalingFactorStr': '1e-01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#decimal', 'pid': 'https://si-digital-framework.org/SI/prefixes/deci'}, {'label': 'deca', 'symbol': 'da', 'scalingFactor': 10.0, 'prefixId': 'deca', 'scalingFactorStr': '1e+01', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/deca'}, {'label': 'hecto', 'symbol': 'h', 'scalingFactor': 100.0, 'prefixId': 'hecto', 'scalingFactorStr': '1e+02', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http://www.w3.org/2001/XMLSchema#integer', 'pid': 'https://si-digital-framework.org/SI/prefixes/hecto'}, {'label': 'kilo', 'symbol': 'k', 'scalingFactor': 1000.0, 'prefixId': 'kilo', 'scalingFactorStr': '1e+03', 'doi': 'https://doi.org/10.59161/cgpm1960res12e', 'dataType': 'http ...
# ['quecto', 'ronto', 'yocto', 'zepto', 'atto', 'femto', 'pico', 'nano', 'micro', 'milli', 'centi', 'deci', 'deca', 'hecto', 'kilo', 'mega', 'giga', 'tera', 'peta', 'exa', 'zetta', 'yotta', 'ronna', 'quetta']
# http://qudt.org/vocab/unit/M-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/M-PER-SEC
# http://qudt.org/vocab/unit/CentiM-PER-HR
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM-PER-HR
# http://qudt.org/vocab/unit/CentiM-PER-KiloYR
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM-PER-KiloYR
# http://qudt.org/vocab/unit/CentiM-PER-SEC
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM-PER-SEC
# http://qudt.org/vocab/unit/CentiM-PER-YR
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM-PER-YR
# http://qudt.org/vocab/unit/GigaHZ-M
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaHZ-M
# http://qudt.org/vocab/unit/KiloM-PER-DAY
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM-PER-DAY
# http://qudt.org/vocab/unit/KiloM-PER-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM-PER-HR
# http://qudt.org/vocab/unit/KiloM-PER-SEC
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM-PER-SEC
# http://qudt.org/vocab/unit/M-PER-HR
# None
# no prefix:  http://qudt.org/vocab/unit/M-PER-HR
# http://qudt.org/vocab/unit/M-PER-MIN
# None
# no prefix:  http://qudt.org/vocab/unit/M-PER-MIN
# http://qudt.org/vocab/unit/M-PER-YR
# None
# no prefix:  http://qudt.org/vocab/unit/M-PER-YR
# http://qudt.org/vocab/unit/MicroM-PER-MIN
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM-PER-MIN
# http://qudt.org/vocab/unit/MicroM-PER-SEC
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM-PER-SEC
# http://qudt.org/vocab/unit/MilliM-PER-DAY
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM-PER-DAY
# http://qudt.org/vocab/unit/MilliM-PER-HR
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM-PER-HR
# http://qudt.org/vocab/unit/MilliM-PER-MIN
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM-PER-MIN
# http://qudt.org/vocab/unit/MilliM-PER-SEC
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM-PER-SEC
# http://qudt.org/vocab/unit/MilliM-PER-YR
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM-PER-YR
# http://qudt.org/vocab/unit/GigaW
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaW
# http://qudt.org/vocab/unit/KiloW
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloW
# http://qudt.org/vocab/unit/MegaW
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaW
# http://qudt.org/vocab/unit/MicroW
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroW
# http://qudt.org/vocab/unit/MilliW
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliW
# http://qudt.org/vocab/unit/NanoW
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoW
# http://qudt.org/vocab/unit/PicoW
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoW
# http://qudt.org/vocab/unit/TeraW
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraW
# http://qudt.org/vocab/unit/W
# None
# no prefix:  http://qudt.org/vocab/unit/W
# http://qudt.org/vocab/unit/GigaJ-PER-HR
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaJ-PER-HR
# http://qudt.org/vocab/unit/HectoPA-L-PER-SEC
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoPA-L-PER-SEC
# http://qudt.org/vocab/unit/HectoPA-M3-PER-SEC
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoPA-M3-PER-SEC
# http://qudt.org/vocab/unit/J-PER-HR
# None
# no prefix:  http://qudt.org/vocab/unit/J-PER-HR
# http://qudt.org/vocab/unit/J-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/J-PER-SEC
# http://qudt.org/vocab/unit/MegaJ-PER-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaJ-PER-HR
# http://qudt.org/vocab/unit/MegaJ-PER-SEC
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaJ-PER-SEC
# http://qudt.org/vocab/unit/MegaPA-L-PER-SEC
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaPA-L-PER-SEC
# http://qudt.org/vocab/unit/MegaPA-M3-PER-SEC
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaPA-M3-PER-SEC
# http://qudt.org/vocab/unit/PA-L-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/PA-L-PER-SEC
# http://qudt.org/vocab/unit/PA-M3-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/PA-M3-PER-SEC
# http://qudt.org/vocab/unit/TeraW-HR-PER-YR
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraW-HR-PER-YR
# http://qudt.org/vocab/unit/LUX
# None
# no prefix:  http://qudt.org/vocab/unit/LUX
# http://qudt.org/vocab/unit/NP
# None
# no prefix:  http://qudt.org/vocab/unit/NP
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/KiloGM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloGM
# http://qudt.org/vocab/unit/CentiGM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiGM
# http://qudt.org/vocab/unit/DecaGM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaGM
# http://qudt.org/vocab/unit/DeciGM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciGM
# http://qudt.org/vocab/unit/DeciTON_Metric
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciTON_Metric
# http://qudt.org/vocab/unit/GM
# None
# no prefix:  http://qudt.org/vocab/unit/GM
# http://qudt.org/vocab/unit/HectoGM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoGM
# http://qudt.org/vocab/unit/KiloTON_Metric
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloTON_Metric
# http://qudt.org/vocab/unit/MegaGM
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaGM
# http://qudt.org/vocab/unit/MicroGM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroGM
# http://qudt.org/vocab/unit/MilliGM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliGM
# http://qudt.org/vocab/unit/NanoGM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoGM
# http://qudt.org/vocab/unit/PicoGM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoGM
# http://qudt.org/vocab/unit/TONNE
# None
# no prefix:  http://qudt.org/vocab/unit/TONNE
# http://qudt.org/vocab/unit/TON_Metric
# None
# no prefix:  http://qudt.org/vocab/unit/TON_Metric
# http://qudt.org/vocab/unit/SEC2
# None
# no prefix:  http://qudt.org/vocab/unit/SEC2
# http://qudt.org/vocab/unit/BQ-PER-L
# None
# no prefix:  http://qudt.org/vocab/unit/BQ-PER-L
# http://qudt.org/vocab/unit/BQ-PER-M3
# None
# no prefix:  http://qudt.org/vocab/unit/BQ-PER-M3
# http://qudt.org/vocab/unit/MicroBQ-PER-L
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroBQ-PER-L
# http://qudt.org/vocab/unit/MilliBQ-PER-L
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliBQ-PER-L
# http://qudt.org/vocab/unit/NanoBQ-PER-L
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoBQ-PER-L
# http://qudt.org/vocab/unit/N-SEC-PER-RAD
# None
# no prefix:  http://qudt.org/vocab/unit/N-SEC-PER-RAD
# http://qudt.org/vocab/unit/J-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/J-SEC
# http://qudt.org/vocab/unit/AttoJ-SEC
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoJ-SEC
# http://qudt.org/vocab/unit/AttoFARAD
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoFARAD
# http://qudt.org/vocab/unit/FARAD
# None
# no prefix:  http://qudt.org/vocab/unit/FARAD
# http://qudt.org/vocab/unit/MicroFARAD
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroFARAD
# http://qudt.org/vocab/unit/MilliFARAD
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliFARAD
# http://qudt.org/vocab/unit/NanoFARAD
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoFARAD
# http://qudt.org/vocab/unit/PicoFARAD
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoFARAD
# http://qudt.org/vocab/unit/J
# None
# no prefix:  http://qudt.org/vocab/unit/J
# http://qudt.org/vocab/unit/MegaEV
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaEV
# http://qudt.org/vocab/unit/EV
# None
# no prefix:  http://qudt.org/vocab/unit/EV
# http://qudt.org/vocab/unit/GigaEV
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaEV
# http://qudt.org/vocab/unit/AttoJ
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoJ
# http://qudt.org/vocab/unit/ExaJ
# exa
# prefix:  exa found in  http://qudt.org/vocab/unit/ExaJ
# http://qudt.org/vocab/unit/FemtoJ
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoJ
# http://qudt.org/vocab/unit/GigaJ
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaJ
# http://qudt.org/vocab/unit/GigaW-HR
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaW-HR
# http://qudt.org/vocab/unit/KiloEV
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloEV
# http://qudt.org/vocab/unit/KiloJ
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloJ
# http://qudt.org/vocab/unit/KiloV-A-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloV-A-HR
# http://qudt.org/vocab/unit/KiloW-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloW-HR
# http://qudt.org/vocab/unit/MegaJ
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaJ
# http://qudt.org/vocab/unit/MegaV-A-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaV-A-HR
# http://qudt.org/vocab/unit/MegaW-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaW-HR
# http://qudt.org/vocab/unit/MilliJ
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliJ
# http://qudt.org/vocab/unit/PetaJ
# peta
# prefix:  peta found in  http://qudt.org/vocab/unit/PetaJ
# http://qudt.org/vocab/unit/TeraJ
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraJ
# http://qudt.org/vocab/unit/TeraW-HR
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraW-HR
# http://qudt.org/vocab/unit/V-A-HR
# None
# no prefix:  http://qudt.org/vocab/unit/V-A-HR
# http://qudt.org/vocab/unit/W-HR
# None
# no prefix:  http://qudt.org/vocab/unit/W-HR
# http://qudt.org/vocab/unit/W-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/W-SEC
# http://qudt.org/vocab/unit/DEG
# None
# no prefix:  http://qudt.org/vocab/unit/DEG
# http://qudt.org/vocab/unit/GON
# None
# no prefix:  http://qudt.org/vocab/unit/GON
# http://qudt.org/vocab/unit/MIN_Angle
# None
# no prefix:  http://qudt.org/vocab/unit/MIN_Angle
# http://qudt.org/vocab/unit/MicroRAD
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroRAD
# http://qudt.org/vocab/unit/MilliRAD
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliRAD
# http://qudt.org/vocab/unit/RAD
# None
# no prefix:  http://qudt.org/vocab/unit/RAD
# http://qudt.org/vocab/unit/PER-SEC2
# None
# no prefix:  http://qudt.org/vocab/unit/PER-SEC2
# http://qudt.org/vocab/unit/M2-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/M2-PER-SEC
# http://qudt.org/vocab/unit/CentiM2-PER-SEC
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM2-PER-SEC
# http://qudt.org/vocab/unit/M2-HZ
# None
# no prefix:  http://qudt.org/vocab/unit/M2-HZ
# http://qudt.org/vocab/unit/MilliM2-PER-SEC
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM2-PER-SEC
# http://qudt.org/vocab/unit/PA
# None
# no prefix:  http://qudt.org/vocab/unit/PA
# http://qudt.org/vocab/unit/DecaPA
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaPA
# http://qudt.org/vocab/unit/GigaPA
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaPA
# http://qudt.org/vocab/unit/HectoPA
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoPA
# http://qudt.org/vocab/unit/KiloGM-PER-M-SEC2
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloGM-PER-M-SEC2
# http://qudt.org/vocab/unit/KiloN-PER-M2
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloN-PER-M2
# http://qudt.org/vocab/unit/KiloPA
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloPA
# http://qudt.org/vocab/unit/KiloPA_A
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloPA_A
# http://qudt.org/vocab/unit/MegaPA
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaPA
# http://qudt.org/vocab/unit/MicroPA
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroPA
# http://qudt.org/vocab/unit/MilliPA
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliPA
# http://qudt.org/vocab/unit/N-PER-CentiM2
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/N-PER-CentiM2
# http://qudt.org/vocab/unit/N-PER-M2
# None
# no prefix:  http://qudt.org/vocab/unit/N-PER-M2
# http://qudt.org/vocab/unit/N-PER-MilliM2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/N-PER-MilliM2
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/J
# None
# no prefix:  http://qudt.org/vocab/unit/J
# http://qudt.org/vocab/unit/MegaEV
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaEV
# http://qudt.org/vocab/unit/EV
# None
# no prefix:  http://qudt.org/vocab/unit/EV
# http://qudt.org/vocab/unit/GigaEV
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaEV
# http://qudt.org/vocab/unit/AttoJ
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoJ
# http://qudt.org/vocab/unit/ExaJ
# exa
# prefix:  exa found in  http://qudt.org/vocab/unit/ExaJ
# http://qudt.org/vocab/unit/FemtoJ
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoJ
# http://qudt.org/vocab/unit/GigaJ
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaJ
# http://qudt.org/vocab/unit/GigaW-HR
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaW-HR
# http://qudt.org/vocab/unit/KiloEV
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloEV
# http://qudt.org/vocab/unit/KiloJ
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloJ
# http://qudt.org/vocab/unit/KiloV-A-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloV-A-HR
# http://qudt.org/vocab/unit/KiloW-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloW-HR
# http://qudt.org/vocab/unit/MegaJ
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaJ
# http://qudt.org/vocab/unit/MegaV-A-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaV-A-HR
# http://qudt.org/vocab/unit/MegaW-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaW-HR
# http://qudt.org/vocab/unit/MilliJ
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliJ
# http://qudt.org/vocab/unit/PetaJ
# peta
# prefix:  peta found in  http://qudt.org/vocab/unit/PetaJ
# http://qudt.org/vocab/unit/TeraJ
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraJ
# http://qudt.org/vocab/unit/TeraW-HR
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraW-HR
# http://qudt.org/vocab/unit/V-A-HR
# None
# no prefix:  http://qudt.org/vocab/unit/V-A-HR
# http://qudt.org/vocab/unit/W-HR
# None
# no prefix:  http://qudt.org/vocab/unit/W-HR
# http://qudt.org/vocab/unit/W-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/W-SEC
# http://qudt.org/vocab/unit/RAD-PER-M
# None
# no prefix:  http://qudt.org/vocab/unit/RAD-PER-M
# http://qudt.org/vocab/unit/PER-PA
# None
# no prefix:  http://qudt.org/vocab/unit/PER-PA
# http://qudt.org/vocab/unit/J-PER-CentiM2-DAY
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/J-PER-CentiM2-DAY
# http://qudt.org/vocab/unit/MicroW-PER-M2
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroW-PER-M2
# http://qudt.org/vocab/unit/MilliW-PER-M2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliW-PER-M2
# http://qudt.org/vocab/unit/PicoW-PER-M2
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoW-PER-M2
# http://qudt.org/vocab/unit/W-PER-CentiM2
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/W-PER-CentiM2
# http://qudt.org/vocab/unit/W-PER-M2
# None
# no prefix:  http://qudt.org/vocab/unit/W-PER-M2
# http://qudt.org/vocab/unit/BQ-SEC-PER-M3
# None
# no prefix:  http://qudt.org/vocab/unit/BQ-SEC-PER-M3
# http://qudt.org/vocab/unit/RAD-PER-HR
# None
# no prefix:  http://qudt.org/vocab/unit/RAD-PER-HR
# http://qudt.org/vocab/unit/RAD-PER-MIN
# None
# no prefix:  http://qudt.org/vocab/unit/RAD-PER-MIN
# http://qudt.org/vocab/unit/RAD-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/RAD-PER-SEC
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/PER-M3
# None
# no prefix:  http://qudt.org/vocab/unit/PER-M3
# http://qudt.org/vocab/unit/M2
# None
# no prefix:  http://qudt.org/vocab/unit/M2
# http://qudt.org/vocab/unit/ARE
# None
# no prefix:  http://qudt.org/vocab/unit/ARE
# http://qudt.org/vocab/unit/CentiM2
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM2
# http://qudt.org/vocab/unit/DecaARE
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaARE
# http://qudt.org/vocab/unit/DeciM2
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM2
# http://qudt.org/vocab/unit/HA
# None
# no prefix:  http://qudt.org/vocab/unit/HA
# http://qudt.org/vocab/unit/MicroM2
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM2
# http://qudt.org/vocab/unit/MilliM2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM2
# http://qudt.org/vocab/unit/NanoM2
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM2
# http://qudt.org/vocab/unit/M2-PER-KiloW
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/M2-PER-KiloW
# http://qudt.org/vocab/unit/M2-PER-W
# None
# no prefix:  http://qudt.org/vocab/unit/M2-PER-W
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/PER-K
# None
# no prefix:  http://qudt.org/vocab/unit/PER-K
# http://qudt.org/vocab/unit/PER-H
# None
# no prefix:  http://qudt.org/vocab/unit/PER-H
# http://qudt.org/vocab/unit/DEG_C-PER-HR
# None
# no prefix:  http://qudt.org/vocab/unit/DEG_C-PER-HR
# http://qudt.org/vocab/unit/DEG_C-PER-MIN
# None
# no prefix:  http://qudt.org/vocab/unit/DEG_C-PER-MIN
# http://qudt.org/vocab/unit/DEG_C-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/DEG_C-PER-SEC
# http://qudt.org/vocab/unit/DEG_C-PER-YR
# None
# no prefix:  http://qudt.org/vocab/unit/DEG_C-PER-YR
# http://qudt.org/vocab/unit/K-PER-HR
# None
# no prefix:  http://qudt.org/vocab/unit/K-PER-HR
# http://qudt.org/vocab/unit/K-PER-MIN
# None
# no prefix:  http://qudt.org/vocab/unit/K-PER-MIN
# http://qudt.org/vocab/unit/K-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/K-PER-SEC
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/J-PER-CentiM2-DAY
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/J-PER-CentiM2-DAY
# http://qudt.org/vocab/unit/MicroW-PER-M2
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroW-PER-M2
# http://qudt.org/vocab/unit/MilliW-PER-M2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliW-PER-M2
# http://qudt.org/vocab/unit/PicoW-PER-M2
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoW-PER-M2
# http://qudt.org/vocab/unit/W-PER-CentiM2
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/W-PER-CentiM2
# http://qudt.org/vocab/unit/W-PER-M2
# None
# no prefix:  http://qudt.org/vocab/unit/W-PER-M2
# http://qudt.org/vocab/unit/CentiN-M
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiN-M
# http://qudt.org/vocab/unit/DeciN-M
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciN-M
# http://qudt.org/vocab/unit/KiloN-M
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloN-M
# http://qudt.org/vocab/unit/MegaN-M
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaN-M
# http://qudt.org/vocab/unit/MicroN-M
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroN-M
# http://qudt.org/vocab/unit/MilliN-M
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliN-M
# http://qudt.org/vocab/unit/N-CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/N-CentiM
# http://qudt.org/vocab/unit/N-M
# None
# no prefix:  http://qudt.org/vocab/unit/N-M
# http://qudt.org/vocab/unit/M2-PER-MOL
# None
# no prefix:  http://qudt.org/vocab/unit/M2-PER-MOL
# http://qudt.org/vocab/unit/K-PER-T
# None
# no prefix:  http://qudt.org/vocab/unit/K-PER-T
# http://qudt.org/vocab/unit/SEC
# None
# no prefix:  http://qudt.org/vocab/unit/SEC
# http://qudt.org/vocab/unit/DAY
# None
# no prefix:  http://qudt.org/vocab/unit/DAY
# http://qudt.org/vocab/unit/AttoSEC
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoSEC
# http://qudt.org/vocab/unit/DeciSEC
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciSEC
# http://qudt.org/vocab/unit/FemtoSEC
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoSEC
# http://qudt.org/vocab/unit/H-PER-KiloOHM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/H-PER-KiloOHM
# http://qudt.org/vocab/unit/H-PER-OHM
# None
# no prefix:  http://qudt.org/vocab/unit/H-PER-OHM
# http://qudt.org/vocab/unit/HR
# None
# no prefix:  http://qudt.org/vocab/unit/HR
# http://qudt.org/vocab/unit/KiloSEC
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloSEC
# http://qudt.org/vocab/unit/MIN
# None
# no prefix:  http://qudt.org/vocab/unit/MIN
# http://qudt.org/vocab/unit/MO
# None
# no prefix:  http://qudt.org/vocab/unit/MO
# http://qudt.org/vocab/unit/MegaYR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaYR
# http://qudt.org/vocab/unit/MicroH-PER-KiloOHM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroH-PER-KiloOHM
# http://qudt.org/vocab/unit/MicroH-PER-OHM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroH-PER-OHM
# http://qudt.org/vocab/unit/MicroSEC
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroSEC
# http://qudt.org/vocab/unit/MilliH-PER-KiloOHM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliH-PER-KiloOHM
# http://qudt.org/vocab/unit/MilliH-PER-OHM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliH-PER-OHM
# http://qudt.org/vocab/unit/MilliSEC
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliSEC
# http://qudt.org/vocab/unit/NanoSEC
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoSEC
# http://qudt.org/vocab/unit/PicoSEC
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoSEC
# http://qudt.org/vocab/unit/WK
# None
# no prefix:  http://qudt.org/vocab/unit/WK
# http://qudt.org/vocab/unit/YR
# None
# no prefix:  http://qudt.org/vocab/unit/YR
# http://qudt.org/vocab/unit/YR_TROPICAL
# None
# no prefix:  http://qudt.org/vocab/unit/YR_TROPICAL
# http://qudt.org/vocab/unit/J
# None
# no prefix:  http://qudt.org/vocab/unit/J
# http://qudt.org/vocab/unit/MegaEV
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaEV
# http://qudt.org/vocab/unit/EV
# None
# no prefix:  http://qudt.org/vocab/unit/EV
# http://qudt.org/vocab/unit/GigaEV
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaEV
# http://qudt.org/vocab/unit/AttoJ
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoJ
# http://qudt.org/vocab/unit/ExaJ
# exa
# prefix:  exa found in  http://qudt.org/vocab/unit/ExaJ
# http://qudt.org/vocab/unit/FemtoJ
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoJ
# http://qudt.org/vocab/unit/GigaJ
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaJ
# http://qudt.org/vocab/unit/GigaW-HR
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaW-HR
# http://qudt.org/vocab/unit/KiloEV
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloEV
# http://qudt.org/vocab/unit/KiloJ
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloJ
# http://qudt.org/vocab/unit/KiloV-A-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloV-A-HR
# http://qudt.org/vocab/unit/KiloW-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloW-HR
# http://qudt.org/vocab/unit/MegaJ
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaJ
# http://qudt.org/vocab/unit/MegaV-A-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaV-A-HR
# http://qudt.org/vocab/unit/MegaW-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaW-HR
# http://qudt.org/vocab/unit/MilliJ
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliJ
# http://qudt.org/vocab/unit/PetaJ
# peta
# prefix:  peta found in  http://qudt.org/vocab/unit/PetaJ
# http://qudt.org/vocab/unit/TeraJ
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraJ
# http://qudt.org/vocab/unit/TeraW-HR
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraW-HR
# http://qudt.org/vocab/unit/V-A-HR
# None
# no prefix:  http://qudt.org/vocab/unit/V-A-HR
# http://qudt.org/vocab/unit/W-HR
# None
# no prefix:  http://qudt.org/vocab/unit/W-HR
# http://qudt.org/vocab/unit/W-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/W-SEC
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/DAY
# None
# no prefix:  http://qudt.org/vocab/unit/DAY
# http://qudt.org/vocab/unit/M2-PER-KiloGM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/M2-PER-KiloGM
# http://qudt.org/vocab/unit/M2-PER-GM
# None
# no prefix:  http://qudt.org/vocab/unit/M2-PER-GM
# http://qudt.org/vocab/unit/J
# None
# no prefix:  http://qudt.org/vocab/unit/J
# http://qudt.org/vocab/unit/MegaEV
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaEV
# http://qudt.org/vocab/unit/EV
# None
# no prefix:  http://qudt.org/vocab/unit/EV
# http://qudt.org/vocab/unit/GigaEV
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaEV
# http://qudt.org/vocab/unit/AttoJ
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoJ
# http://qudt.org/vocab/unit/ExaJ
# exa
# prefix:  exa found in  http://qudt.org/vocab/unit/ExaJ
# http://qudt.org/vocab/unit/FemtoJ
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoJ
# http://qudt.org/vocab/unit/GigaJ
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaJ
# http://qudt.org/vocab/unit/GigaW-HR
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaW-HR
# http://qudt.org/vocab/unit/KiloEV
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloEV
# http://qudt.org/vocab/unit/KiloJ
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloJ
# http://qudt.org/vocab/unit/KiloV-A-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloV-A-HR
# http://qudt.org/vocab/unit/KiloW-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloW-HR
# http://qudt.org/vocab/unit/MegaJ
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaJ
# http://qudt.org/vocab/unit/MegaV-A-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaV-A-HR
# http://qudt.org/vocab/unit/MegaW-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaW-HR
# http://qudt.org/vocab/unit/MilliJ
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliJ
# http://qudt.org/vocab/unit/PetaJ
# peta
# prefix:  peta found in  http://qudt.org/vocab/unit/PetaJ
# http://qudt.org/vocab/unit/TeraJ
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraJ
# http://qudt.org/vocab/unit/TeraW-HR
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraW-HR
# http://qudt.org/vocab/unit/V-A-HR
# None
# no prefix:  http://qudt.org/vocab/unit/V-A-HR
# http://qudt.org/vocab/unit/W-HR
# None
# no prefix:  http://qudt.org/vocab/unit/W-HR
# http://qudt.org/vocab/unit/W-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/W-SEC
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/HZ
# None
# no prefix:  http://qudt.org/vocab/unit/HZ
# http://qudt.org/vocab/unit/GigaHZ
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaHZ
# http://qudt.org/vocab/unit/KiloHZ
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloHZ
# http://qudt.org/vocab/unit/MegaHZ
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaHZ
# http://qudt.org/vocab/unit/PER-DAY
# None
# no prefix:  http://qudt.org/vocab/unit/PER-DAY
# http://qudt.org/vocab/unit/PER-HR
# None
# no prefix:  http://qudt.org/vocab/unit/PER-HR
# http://qudt.org/vocab/unit/PER-MIN
# None
# no prefix:  http://qudt.org/vocab/unit/PER-MIN
# http://qudt.org/vocab/unit/PER-MO
# None
# no prefix:  http://qudt.org/vocab/unit/PER-MO
# http://qudt.org/vocab/unit/PER-MilliSEC
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/PER-MilliSEC
# http://qudt.org/vocab/unit/PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/PER-SEC
# http://qudt.org/vocab/unit/PER-WK
# None
# no prefix:  http://qudt.org/vocab/unit/PER-WK
# http://qudt.org/vocab/unit/PER-YR
# None
# no prefix:  http://qudt.org/vocab/unit/PER-YR
# http://qudt.org/vocab/unit/TeraHZ
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraHZ
# http://qudt.org/vocab/unit/RAD-PER-M
# None
# no prefix:  http://qudt.org/vocab/unit/RAD-PER-M
# http://qudt.org/vocab/unit/W-PER-SR
# None
# no prefix:  http://qudt.org/vocab/unit/W-PER-SR
# http://qudt.org/vocab/unit/H-PER-M
# None
# no prefix:  http://qudt.org/vocab/unit/H-PER-M
# http://qudt.org/vocab/unit/MicroH-PER-M
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroH-PER-M
# http://qudt.org/vocab/unit/NanoH-PER-M
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoH-PER-M
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/FRACTION
# None
# no prefix:  http://qudt.org/vocab/unit/FRACTION
# http://qudt.org/vocab/unit/PERCENT
# None
# no prefix:  http://qudt.org/vocab/unit/PERCENT
# http://qudt.org/vocab/unit/PPB
# None
# no prefix:  http://qudt.org/vocab/unit/PPB
# http://qudt.org/vocab/unit/PPM
# None
# no prefix:  http://qudt.org/vocab/unit/PPM
# http://qudt.org/vocab/unit/PPQ
# None
# no prefix:  http://qudt.org/vocab/unit/PPQ
# http://qudt.org/vocab/unit/PPT
# None
# no prefix:  http://qudt.org/vocab/unit/PPT
# http://qudt.org/vocab/unit/PPTH
# None
# no prefix:  http://qudt.org/vocab/unit/PPTH
# http://qudt.org/vocab/unit/T
# None
# no prefix:  http://qudt.org/vocab/unit/T
# http://qudt.org/vocab/unit/MegaEV-FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/MegaEV-FemtoM
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/FRACTION
# None
# no prefix:  http://qudt.org/vocab/unit/FRACTION
# http://qudt.org/vocab/unit/PERCENT
# None
# no prefix:  http://qudt.org/vocab/unit/PERCENT
# http://qudt.org/vocab/unit/PPB
# None
# no prefix:  http://qudt.org/vocab/unit/PPB
# http://qudt.org/vocab/unit/PPM
# None
# no prefix:  http://qudt.org/vocab/unit/PPM
# http://qudt.org/vocab/unit/PPQ
# None
# no prefix:  http://qudt.org/vocab/unit/PPQ
# http://qudt.org/vocab/unit/PPT
# None
# no prefix:  http://qudt.org/vocab/unit/PPT
# http://qudt.org/vocab/unit/PPTH
# None
# no prefix:  http://qudt.org/vocab/unit/PPTH
# http://qudt.org/vocab/unit/M2
# None
# no prefix:  http://qudt.org/vocab/unit/M2
# http://qudt.org/vocab/unit/CentiM2
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM2
# http://qudt.org/vocab/unit/DeciM2
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM2
# http://qudt.org/vocab/unit/MicroM2
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM2
# http://qudt.org/vocab/unit/MilliM2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM2
# http://qudt.org/vocab/unit/NanoM2
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM2
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/OHM
# None
# no prefix:  http://qudt.org/vocab/unit/OHM
# http://qudt.org/vocab/unit/GigaOHM
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaOHM
# http://qudt.org/vocab/unit/KiloOHM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloOHM
# http://qudt.org/vocab/unit/MegaOHM
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaOHM
# http://qudt.org/vocab/unit/MicroOHM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroOHM
# http://qudt.org/vocab/unit/MilliOHM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliOHM
# http://qudt.org/vocab/unit/TeraOHM
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraOHM
# http://qudt.org/vocab/unit/FemtoGM-PER-KiloGM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoGM-PER-KiloGM
# http://qudt.org/vocab/unit/GM-PER-GM
# None
# no prefix:  http://qudt.org/vocab/unit/GM-PER-GM
# http://qudt.org/vocab/unit/GM-PER-KiloGM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/GM-PER-KiloGM
# http://qudt.org/vocab/unit/KiloGM-PER-KiloGM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloGM-PER-KiloGM
# http://qudt.org/vocab/unit/MicroGM-PER-GM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroGM-PER-GM
# http://qudt.org/vocab/unit/MicroGM-PER-KiloGM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroGM-PER-KiloGM
# http://qudt.org/vocab/unit/MilliGM-PER-GM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliGM-PER-GM
# http://qudt.org/vocab/unit/MilliGM-PER-KiloGM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliGM-PER-KiloGM
# http://qudt.org/vocab/unit/NanoGM-PER-KiloGM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoGM-PER-KiloGM
# http://qudt.org/vocab/unit/PicoGM-PER-GM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoGM-PER-GM
# http://qudt.org/vocab/unit/PicoGM-PER-KiloGM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoGM-PER-KiloGM
# http://qudt.org/vocab/unit/J
# None
# no prefix:  http://qudt.org/vocab/unit/J
# http://qudt.org/vocab/unit/CentiMOL-PER-L
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiMOL-PER-L
# http://qudt.org/vocab/unit/FemtoMOL-PER-L
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoMOL-PER-L
# http://qudt.org/vocab/unit/KiloMOL-PER-M3
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloMOL-PER-M3
# http://qudt.org/vocab/unit/MOL-PER-DeciM3
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/MOL-PER-DeciM3
# http://qudt.org/vocab/unit/MOL-PER-L
# None
# no prefix:  http://qudt.org/vocab/unit/MOL-PER-L
# http://qudt.org/vocab/unit/MOL-PER-M3
# None
# no prefix:  http://qudt.org/vocab/unit/MOL-PER-M3
# http://qudt.org/vocab/unit/MicroMOL-PER-L
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroMOL-PER-L
# http://qudt.org/vocab/unit/MilliMOL-PER-L
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliMOL-PER-L
# http://qudt.org/vocab/unit/MilliMOL-PER-M3
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliMOL-PER-M3
# http://qudt.org/vocab/unit/NanoMOL-PER-L
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoMOL-PER-L
# http://qudt.org/vocab/unit/PicoMOL-PER-L
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoMOL-PER-L
# http://qudt.org/vocab/unit/PicoMOL-PER-M3
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoMOL-PER-M3
# http://qudt.org/vocab/unit/N-M2-PER-A
# None
# no prefix:  http://qudt.org/vocab/unit/N-M2-PER-A
# http://qudt.org/vocab/unit/WB-M
# None
# no prefix:  http://qudt.org/vocab/unit/WB-M
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/V
# None
# no prefix:  http://qudt.org/vocab/unit/V
# http://qudt.org/vocab/unit/KiloV
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloV
# http://qudt.org/vocab/unit/MegaV
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaV
# http://qudt.org/vocab/unit/MicroV
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroV
# http://qudt.org/vocab/unit/MilliV
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliV
# http://qudt.org/vocab/unit/DEG
# None
# no prefix:  http://qudt.org/vocab/unit/DEG
# http://qudt.org/vocab/unit/GON
# None
# no prefix:  http://qudt.org/vocab/unit/GON
# http://qudt.org/vocab/unit/MIN_Angle
# None
# no prefix:  http://qudt.org/vocab/unit/MIN_Angle
# http://qudt.org/vocab/unit/MicroRAD
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroRAD
# http://qudt.org/vocab/unit/MilliRAD
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliRAD
# http://qudt.org/vocab/unit/RAD
# None
# no prefix:  http://qudt.org/vocab/unit/RAD
# http://qudt.org/vocab/unit/C-PER-CentiM2
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/C-PER-CentiM2
# http://qudt.org/vocab/unit/C-PER-M2
# None
# no prefix:  http://qudt.org/vocab/unit/C-PER-M2
# http://qudt.org/vocab/unit/C-PER-MilliM2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/C-PER-MilliM2
# http://qudt.org/vocab/unit/KiloC-PER-M2
# kilo
# ...
# None
# no prefix:  http://qudt.org/vocab/unit/M2-HZ4
# http://qudt.org/vocab/unit/M2-PER-HZ
# None
# no prefix:  http://qudt.org/vocab/unit/M2-PER-HZ
# http://qudt.org/vocab/unit/M2-PER-HZ2
# None
# no prefix:  http://qudt.org/vocab/unit/M2-PER-HZ2
# http://qudt.org/vocab/unit/M2-SEC-PER-RAD
# None
# no prefix:  http://qudt.org/vocab/unit/M2-SEC-PER-RAD
# http://qudt.org/vocab/unit/M4-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/M4-PER-SEC
# http://qudt.org/vocab/unit/MOL-PER-GM-HR
# None
# no prefix:  http://qudt.org/vocab/unit/MOL-PER-GM-HR
# http://qudt.org/vocab/unit/MOL-PER-M2
# None
# no prefix:  http://qudt.org/vocab/unit/MOL-PER-M2
# http://qudt.org/vocab/unit/MOL-PER-M2-SEC-M-SR
# None
# no prefix:  http://qudt.org/vocab/unit/MOL-PER-M2-SEC-M-SR
# http://qudt.org/vocab/unit/MOL-PER-M2-SEC-SR
# None
# no prefix:  http://qudt.org/vocab/unit/MOL-PER-M2-SEC-SR
# http://qudt.org/vocab/unit/MOL-PER-MOL
# None
# no prefix:  http://qudt.org/vocab/unit/MOL-PER-MOL
# http://qudt.org/vocab/unit/MicroGM-PER-L-HR
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroGM-PER-L-HR
# http://qudt.org/vocab/unit/MicroGM-PER-M3-HR
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroGM-PER-M3-HR
# http://qudt.org/vocab/unit/MicroM-PER-MilliL
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM-PER-MilliL
# http://qudt.org/vocab/unit/MicroMOL-PER-GM-HR
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroMOL-PER-GM-HR
# http://qudt.org/vocab/unit/MicroMOL-PER-GM-SEC
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroMOL-PER-GM-SEC
# http://qudt.org/vocab/unit/MicroMOL-PER-M2
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroMOL-PER-M2
# http://qudt.org/vocab/unit/MicroMOL-PER-MOL
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroMOL-PER-MOL
# http://qudt.org/vocab/unit/MicroMOL-PER-MicroMOL-DAY
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroMOL-PER-MicroMOL-DAY
# http://qudt.org/vocab/unit/MilliBQ-PER-M2-DAY
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliBQ-PER-M2-DAY
# http://qudt.org/vocab/unit/MilliGM-PER-M3-DAY
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliGM-PER-M3-DAY
# http://qudt.org/vocab/unit/MilliGM-PER-M3-HR
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliGM-PER-M3-HR
# http://qudt.org/vocab/unit/MilliGM-PER-M3-SEC
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliGM-PER-M3-SEC
# http://qudt.org/vocab/unit/MilliL-PER-M2-DAY
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliL-PER-M2-DAY
# http://qudt.org/vocab/unit/MilliMOL-PER-M2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliMOL-PER-M2
# http://qudt.org/vocab/unit/MilliMOL-PER-MOL
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliMOL-PER-MOL
# http://qudt.org/vocab/unit/MilliW-PER-CentiM2-MicroM-SR
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MilliW-PER-CentiM2-MicroM-SR
# http://qudt.org/vocab/unit/MilliW-PER-M2-NanoM-SR
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/MilliW-PER-M2-NanoM-SR
# http://qudt.org/vocab/unit/NanoMOL-PER-GM-SEC
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoMOL-PER-GM-SEC
# http://qudt.org/vocab/unit/NanoMOL-PER-MicroGM-HR
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoMOL-PER-MicroGM-HR
# http://qudt.org/vocab/unit/NanoMOL-PER-MicroMOL
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoMOL-PER-MicroMOL
# http://qudt.org/vocab/unit/NanoMOL-PER-MicroMOL-DAY
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoMOL-PER-MicroMOL-DAY
# http://qudt.org/vocab/unit/PA-M
# None
# no prefix:  http://qudt.org/vocab/unit/PA-M
# http://qudt.org/vocab/unit/PA-M-PER-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/PA-M-PER-SEC
# http://qudt.org/vocab/unit/PA-M-PER-SEC2
# None
# no prefix:  http://qudt.org/vocab/unit/PA-M-PER-SEC2
# http://qudt.org/vocab/unit/PA2-PER-SEC2
# None
# no prefix:  http://qudt.org/vocab/unit/PA2-PER-SEC2
# http://qudt.org/vocab/unit/PER-M-NanoM-SR
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/PER-M-NanoM-SR
# http://qudt.org/vocab/unit/PER-M-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/PER-M-SEC
# http://qudt.org/vocab/unit/PER-M-SR
# None
# no prefix:  http://qudt.org/vocab/unit/PER-M-SR
# http://qudt.org/vocab/unit/PER-MicroMOL-L
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/PER-MicroMOL-L
# http://qudt.org/vocab/unit/PER-PA-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/PER-PA-SEC
# http://qudt.org/vocab/unit/PER-SR
# None
# no prefix:  http://qudt.org/vocab/unit/PER-SR
# http://qudt.org/vocab/unit/PPTR_VOL
# None
# no prefix:  http://qudt.org/vocab/unit/PPTR_VOL
# http://qudt.org/vocab/unit/PicoA-PER-MicroMOL-L
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoA-PER-MicroMOL-L
# http://qudt.org/vocab/unit/PicoMOL-PER-M-W-SEC
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoMOL-PER-M-W-SEC
# http://qudt.org/vocab/unit/PicoW-PER-CentiM2-L
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoW-PER-CentiM2-L
# http://qudt.org/vocab/unit/SEC-PER-M
# None
# no prefix:  http://qudt.org/vocab/unit/SEC-PER-M
# http://qudt.org/vocab/unit/W-M-PER-M2-SR
# None
# no prefix:  http://qudt.org/vocab/unit/W-M-PER-M2-SR
# http://qudt.org/vocab/unit/W-PER-M2-M
# None
# no prefix:  http://qudt.org/vocab/unit/W-PER-M2-M
# http://qudt.org/vocab/unit/W-PER-M2-M-SR
# None
# no prefix:  http://qudt.org/vocab/unit/W-PER-M2-M-SR
# http://qudt.org/vocab/unit/W-PER-M2-NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/W-PER-M2-NanoM
# http://qudt.org/vocab/unit/W-PER-M2-NanoM-SR
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/W-PER-M2-NanoM-SR
# http://qudt.org/vocab/unit/J
# None
# no prefix:  http://qudt.org/vocab/unit/J
# http://qudt.org/vocab/unit/MegaEV
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaEV
# http://qudt.org/vocab/unit/EV
# None
# no prefix:  http://qudt.org/vocab/unit/EV
# http://qudt.org/vocab/unit/GigaEV
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaEV
# http://qudt.org/vocab/unit/AttoJ
# atto
# prefix:  atto found in  http://qudt.org/vocab/unit/AttoJ
# http://qudt.org/vocab/unit/ExaJ
# exa
# prefix:  exa found in  http://qudt.org/vocab/unit/ExaJ
# http://qudt.org/vocab/unit/FemtoJ
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoJ
# http://qudt.org/vocab/unit/GigaJ
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaJ
# http://qudt.org/vocab/unit/GigaW-HR
# giga
# prefix:  giga found in  http://qudt.org/vocab/unit/GigaW-HR
# http://qudt.org/vocab/unit/KiloEV
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloEV
# http://qudt.org/vocab/unit/KiloJ
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloJ
# http://qudt.org/vocab/unit/KiloV-A-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloV-A-HR
# http://qudt.org/vocab/unit/KiloW-HR
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloW-HR
# http://qudt.org/vocab/unit/MegaJ
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaJ
# http://qudt.org/vocab/unit/MegaV-A-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaV-A-HR
# http://qudt.org/vocab/unit/MegaW-HR
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaW-HR
# http://qudt.org/vocab/unit/MilliJ
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliJ
# http://qudt.org/vocab/unit/PetaJ
# peta
# prefix:  peta found in  http://qudt.org/vocab/unit/PetaJ
# http://qudt.org/vocab/unit/TeraJ
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraJ
# http://qudt.org/vocab/unit/TeraW-HR
# tera
# prefix:  tera found in  http://qudt.org/vocab/unit/TeraW-HR
# http://qudt.org/vocab/unit/V-A-HR
# None
# no prefix:  http://qudt.org/vocab/unit/V-A-HR
# http://qudt.org/vocab/unit/W-HR
# None
# no prefix:  http://qudt.org/vocab/unit/W-HR
# http://qudt.org/vocab/unit/W-SEC
# None
# no prefix:  http://qudt.org/vocab/unit/W-SEC
# http://qudt.org/vocab/unit/S-M2-PER-MOL
# None
# no prefix:  http://qudt.org/vocab/unit/S-M2-PER-MOL
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/A-PER-RAD
# None
# no prefix:  http://qudt.org/vocab/unit/A-PER-RAD
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/M
# None
# no prefix:  http://qudt.org/vocab/unit/M
# http://qudt.org/vocab/unit/AU
# None
# no prefix:  http://qudt.org/vocab/unit/AU
# http://qudt.org/vocab/unit/CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM
# http://qudt.org/vocab/unit/DecaM
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaM
# http://qudt.org/vocab/unit/DeciM
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM
# http://qudt.org/vocab/unit/FemtoM
# femto
# prefix:  femto found in  http://qudt.org/vocab/unit/FemtoM
# http://qudt.org/vocab/unit/HectoM
# hecto
# prefix:  hecto found in  http://qudt.org/vocab/unit/HectoM
# http://qudt.org/vocab/unit/KiloM
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloM
# http://qudt.org/vocab/unit/MicroM
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM
# http://qudt.org/vocab/unit/MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM
# http://qudt.org/vocab/unit/NanoM
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM
# http://qudt.org/vocab/unit/PicoM
# pico
# prefix:  pico found in  http://qudt.org/vocab/unit/PicoM
# http://qudt.org/vocab/unit/N-M-PER-M2
# None
# no prefix:  http://qudt.org/vocab/unit/N-M-PER-M2
# http://qudt.org/vocab/unit/KiloN-PER-M
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloN-PER-M
# http://qudt.org/vocab/unit/MilliN-PER-M
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliN-PER-M
# http://qudt.org/vocab/unit/N-PER-CentiM
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/N-PER-CentiM
# http://qudt.org/vocab/unit/N-PER-M
# None
# no prefix:  http://qudt.org/vocab/unit/N-PER-M
# http://qudt.org/vocab/unit/N-PER-MilliM
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/N-PER-MilliM
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/FRACTION
# None
# no prefix:  http://qudt.org/vocab/unit/FRACTION
# http://qudt.org/vocab/unit/PERCENT
# None
# no prefix:  http://qudt.org/vocab/unit/PERCENT
# http://qudt.org/vocab/unit/PPB
# None
# no prefix:  http://qudt.org/vocab/unit/PPB
# http://qudt.org/vocab/unit/PPM
# None
# no prefix:  http://qudt.org/vocab/unit/PPM
# http://qudt.org/vocab/unit/PPQ
# None
# no prefix:  http://qudt.org/vocab/unit/PPQ
# http://qudt.org/vocab/unit/PPT
# None
# no prefix:  http://qudt.org/vocab/unit/PPT
# http://qudt.org/vocab/unit/PPTH
# None
# no prefix:  http://qudt.org/vocab/unit/PPTH
# http://qudt.org/vocab/unit/FRACTION
# None
# no prefix:  http://qudt.org/vocab/unit/FRACTION
# http://qudt.org/vocab/unit/PERCENT
# None
# no prefix:  http://qudt.org/vocab/unit/PERCENT
# http://qudt.org/vocab/unit/LM-PER-W
# None
# no prefix:  http://qudt.org/vocab/unit/LM-PER-W
# http://qudt.org/vocab/unit/M2
# None
# no prefix:  http://qudt.org/vocab/unit/M2
# http://qudt.org/vocab/unit/ARE
# None
# no prefix:  http://qudt.org/vocab/unit/ARE
# http://qudt.org/vocab/unit/CentiM2
# centi
# prefix:  centi found in  http://qudt.org/vocab/unit/CentiM2
# http://qudt.org/vocab/unit/DecaARE
# deca
# prefix:  deca found in  http://qudt.org/vocab/unit/DecaARE
# http://qudt.org/vocab/unit/DeciM2
# deci
# prefix:  deci found in  http://qudt.org/vocab/unit/DeciM2
# http://qudt.org/vocab/unit/HA
# None
# no prefix:  http://qudt.org/vocab/unit/HA
# http://qudt.org/vocab/unit/MicroM2
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroM2
# http://qudt.org/vocab/unit/MilliM2
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliM2
# http://qudt.org/vocab/unit/NanoM2
# nano
# prefix:  nano found in  http://qudt.org/vocab/unit/NanoM2
# http://qudt.org/vocab/unit/DEG
# None
# no prefix:  http://qudt.org/vocab/unit/DEG
# http://qudt.org/vocab/unit/GON
# None
# no prefix:  http://qudt.org/vocab/unit/GON
# http://qudt.org/vocab/unit/MIN_Angle
# None
# no prefix:  http://qudt.org/vocab/unit/MIN_Angle
# http://qudt.org/vocab/unit/MicroRAD
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroRAD
# http://qudt.org/vocab/unit/MilliRAD
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliRAD
# http://qudt.org/vocab/unit/RAD
# None
# no prefix:  http://qudt.org/vocab/unit/RAD
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/FRACTION
# None
# no prefix:  http://qudt.org/vocab/unit/FRACTION
# http://qudt.org/vocab/unit/PERCENT
# None
# no prefix:  http://qudt.org/vocab/unit/PERCENT
# http://qudt.org/vocab/unit/PPB
# None
# no prefix:  http://qudt.org/vocab/unit/PPB
# http://qudt.org/vocab/unit/PPM
# None
# no prefix:  http://qudt.org/vocab/unit/PPM
# http://qudt.org/vocab/unit/PPQ
# None
# no prefix:  http://qudt.org/vocab/unit/PPQ
# http://qudt.org/vocab/unit/PPT
# None
# no prefix:  http://qudt.org/vocab/unit/PPT
# http://qudt.org/vocab/unit/PPTH
# None
# no prefix:  http://qudt.org/vocab/unit/PPTH
# http://qudt.org/vocab/unit/N
# None
# no prefix:  http://qudt.org/vocab/unit/N
# http://qudt.org/vocab/unit/KiloN
# kilo
# prefix:  kilo found in  http://qudt.org/vocab/unit/KiloN
# http://qudt.org/vocab/unit/MegaN
# mega
# prefix:  mega found in  http://qudt.org/vocab/unit/MegaN
# http://qudt.org/vocab/unit/MicroN
# micro
# prefix:  micro found in  http://qudt.org/vocab/unit/MicroN
# http://qudt.org/vocab/unit/MilliN
# milli
# prefix:  milli found in  http://qudt.org/vocab/unit/MilliN
# http://qudt.org/vocab/unit/NUM
# None
# no prefix:  http://qudt.org/vocab/unit/NUM
# http://qudt.org/vocab/unit/FRACTION
# None
# no prefix:  http://qudt.org/vocab/unit/FRACTION
# http://qudt.org/vocab/unit/PERCENT
# None
# no prefix:  http://qudt.org/vocab/unit/PERCENT
# http://qudt.org/vocab/unit/PPB
# None
# no prefix:  http://qudt.org/vocab/unit/PPB
# http://qudt.org/vocab/unit/PPM
# None
# no prefix:  http://qudt.org/vocab/unit/PPM
# http://qudt.org/vocab/unit/PPQ
# None
# no prefix:  http://qudt.org/vocab/unit/PPQ
# http://qudt.org/vocab/unit/PPT
# None
# no prefix:  http://qudt.org/vocab/unit/PPT
# http://qudt.org/vocab/unit/PPTH
# None
# no prefix:  http://qudt.org/vocab/unit/PPTH
# 579
# 371

# %%
# Functions to extract the path of a given URL
def get_path(url):
    return url.split("/")[-1]


# def get_path_list(url_list):
#     return [get_path(url) for url in url_list]

# def get_iri_without_path(iri):
#     return iri.split("/")[:-1]


def get_main_string(unit_str, prefix_name_list):
    for prefix in prefix_name_list:
        capitalized_prefix = prefix.capitalize()
        if capitalized_prefix in unit_str:
            return unit_str.replace(capitalized_prefix, "")
    return unit_str


def merge_prefixed_and_non_prefixed_units(
    all_non_prefixed_units, all_prefixed_units, prefix_name_list
):
    unit_dict = {}
    for non_prefixed_unit in all_non_prefixed_units:
        prefixed_units = []
        # Match the non prefixed unit with all the prefixed units
        for prefixed_unit in all_prefixed_units:
            if get_path(non_prefixed_unit) == get_main_string(
                get_path(prefixed_unit), prefix_name_list
            ):
                prefixed_units.append(prefixed_unit)
        unit_dict[non_prefixed_unit] = {"prefixed_units": prefixed_units}

    return unit_dict


unit_dict = merge_prefixed_and_non_prefixed_units(
    all_non_prefixed_units, all_prefixed_units, prefix_name_list
)
pprint(unit_dict)
# Out:
# {'http://qudt.org/vocab/unit/A': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloA',
#                                                      'http://qudt.org/vocab/unit/MilliA',
#                                                      'http://qudt.org/vocab/unit/MegaA',
#                                                      'http://qudt.org/vocab/unit/MicroA',
#                                                      'http://qudt.org/vocab/unit/PicoA']},
#  'http://qudt.org/vocab/unit/A-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliA-HR',
#                                                         'http://qudt.org/vocab/unit/KiloA-HR']},
#  'http://qudt.org/vocab/unit/A-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-M2-PER-J-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-DEG_C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliA-PER-MilliM',
#                                                            'http://qudt.org/vocab/unit/KiloA-PER-M',
#                                                            'http://qudt.org/vocab/unit/A-PER-CentiM',
#                                                            'http://qudt.org/vocab/unit/A-PER-MilliM']},
#  'http://qudt.org/vocab/unit/A-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaA-PER-M2',
#                                                             'http://qudt.org/vocab/unit/KiloA-PER-M2',
#                                                             'http://qudt.org/vocab/unit/A-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/A-PER-MilliM2']},
#  'http://qudt.org/vocab/unit/A-PER-M2-K2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/A-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/ARE': {'prefixed_units': ['http://qudt.org/vocab/unit/DecaARE']},
#  'http://qudt.org/vocab/unit/AU': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/B': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciB']},
#  'http://qudt.org/vocab/unit/BIT': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/BQ': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaBQ',
#                                                       'http://qudt.org/vocab/unit/MicroBQ',
#                                                       'http://qudt.org/vocab/unit/GigaBQ',
#                                                       'http://qudt.org/vocab/unit/KiloBQ']},
#  'http://qudt.org/vocab/unit/BQ-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroBQ-PER-L',
#                                                             'http://qudt.org/vocab/unit/NanoBQ-PER-L',
#                                                             'http://qudt.org/vocab/unit/MilliBQ-PER-L']},
#  'http://qudt.org/vocab/unit/BQ-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/BQ-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/BQ-SEC-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/BYTE': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaBYTE',
#                                                         'http://qudt.org/vocab/unit/PetaBYTE',
#                                                         'http://qudt.org/vocab/unit/TeraBYTE',
#                                                         'http://qudt.org/vocab/unit/MegaBYTE',
#                                                         'http://qudt.org/vocab/unit/ExaBYTE',
#                                                         'http://qudt.org/vocab/unit/KiloBYTE']},
#  'http://qudt.org/vocab/unit/C': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaC',
#                                                      'http://qudt.org/vocab/unit/DeciC',
#                                                      'http://qudt.org/vocab/unit/FemtoC',
#                                                      'http://qudt.org/vocab/unit/ZeptoC',
#                                                      'http://qudt.org/vocab/unit/DecaC',
#                                                      'http://qudt.org/vocab/unit/ZettaC',
#                                                      'http://qudt.org/vocab/unit/PicoC',
#                                                      'http://qudt.org/vocab/unit/CentiC',
#                                                      'http://qudt.org/vocab/unit/GigaC',
#                                                      'http://qudt.org/vocab/unit/ExaC',
#                                                      'http://qudt.org/vocab/unit/PetaC',
#                                                      'http://qudt.org/vocab/unit/NanoC',
#                                                      'http://qudt.org/vocab/unit/TeraC',
#                                                      'http://qudt.org/vocab/unit/AttoC',
#                                                      'http://qudt.org/vocab/unit/HectoC',
#                                                      'http://qudt.org/vocab/unit/KiloC',
#                                                      'http://qudt.org/vocab/unit/MilliC',
#                                                      'http://qudt.org/vocab/unit/MicroC',
#                                                      'http://qudt.org/vocab/unit/YottaC',
#                                                      'http://qudt.org/vocab/unit/YoctoC']},
#  'http://qudt.org/vocab/unit/C-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-M2-PER-V': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/C-PER-MilliM2',
#                                                             'http://qudt.org/vocab/unit/MicroC-PER-M2',
#                                                             'http://qudt.org/vocab/unit/MegaC-PER-M2',
#                                                             'http://qudt.org/vocab/unit/KiloC-PER-M2',
#                                                             'http://qudt.org/vocab/unit/C-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/MilliC-PER-M2']},
#  'http://qudt.org/vocab/unit/C-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/C-PER-CentiM3',
#                                                             'http://qudt.org/vocab/unit/MilliC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/GigaC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/KiloC-PER-M3',
#                                                             'http://qudt.org/vocab/unit/C-PER-MilliM3',
#                                                             'http://qudt.org/vocab/unit/MicroC-PER-M3']},
#  'http://qudt.org/vocab/unit/C-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C2-M2-PER-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C3-M-PER-J2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/C4-M4-PER-J3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CD-PER-LM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CD-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/CFU': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliDEG_C']},
#  'http://qudt.org/vocab/unit/DEG_C-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-PER-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C-WK': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_C2-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/DEG_F-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/EV': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloEV',
#                                                       'http://qudt.org/vocab/unit/MegaEV',
#                                                       'http://qudt.org/vocab/unit/GigaEV']},
#  'http://qudt.org/vocab/unit/EV-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/EV-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/EV-PER-T': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/EV-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/ElementaryCharge': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/FARAD': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroFARAD',
#                                                          'http://qudt.org/vocab/unit/PicoFARAD',
#                                                          'http://qudt.org/vocab/unit/AttoFARAD',
#                                                          'http://qudt.org/vocab/unit/NanoFARAD',
#                                                          'http://qudt.org/vocab/unit/MilliFARAD']},
#  'http://qudt.org/vocab/unit/FARAD-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/FARAD-PER-KiloM',
#                                                                'http://qudt.org/vocab/unit/NanoFARAD-PER-M',
#                                                                'http://qudt.org/vocab/unit/MicroFARAD-PER-M',
#                                                                'http://qudt.org/vocab/unit/PicoFARAD-PER-M']},
#  'http://qudt.org/vocab/unit/FRACTION': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/GM': {'prefixed_units': ['http://qudt.org/vocab/unit/PicoGM',
#                                                       'http://qudt.org/vocab/unit/DeciGM',
#                                                       'http://qudt.org/vocab/unit/CentiGM',
#                                                       'http://qudt.org/vocab/unit/MicroGM',
#                                                       'http://qudt.org/vocab/unit/NanoGM',
#                                                       'http://qudt.org/vocab/unit/KiloGM',
#                                                       'http://qudt.org/vocab/unit/MilliGM',
#                                                       'http://qudt.org/vocab/unit/DecaGM',
#                                                       'http://qudt.org/vocab/unit/MegaGM',
#                                                       'http://qudt.org/vocab/unit/HectoGM']},
#  'http://qudt.org/vocab/unit/GM-PER-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-DAY',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-DAY',
#                                                               'http://qudt.org/vocab/unit/NanoGM-PER-DAY']},
#  'http://qudt.org/vocab/unit/GM-PER-DEG_C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/GM-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroGM-PER-GM',
#                                                              'http://qudt.org/vocab/unit/MilliGM-PER-GM',
#                                                              'http://qudt.org/vocab/unit/GM-PER-KiloGM',
#                                                              'http://qudt.org/vocab/unit/PicoGM-PER-GM',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-KiloGM']},
#  'http://qudt.org/vocab/unit/GM-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloGM-PER-HR',
#                                                              'http://qudt.org/vocab/unit/MilliGM-PER-HR']},
#  'http://qudt.org/vocab/unit/GM-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/GM-PER-DeciL',
#                                                             'http://qudt.org/vocab/unit/KiloGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/PicoGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/GM-PER-MilliL',
#                                                             'http://qudt.org/vocab/unit/FemtoGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/MilliGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/NanoGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/MicroGM-PER-L',
#                                                             'http://qudt.org/vocab/unit/MilliGM-PER-MilliL']},
#  'http://qudt.org/vocab/unit/GM-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-M',
#                                                             'http://qudt.org/vocab/unit/GM-PER-MilliM',
#                                                             'http://qudt.org/vocab/unit/KiloGM-PER-M',
#                                                             'http://qudt.org/vocab/unit/GM-PER-KiloM']},
#  'http://qudt.org/vocab/unit/GM-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloGM-PER-M2',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-KiloM2',
#                                                              'http://qudt.org/vocab/unit/MilliGM-PER-M2',
#                                                              'http://qudt.org/vocab/unit/GM-PER-CentiM2']},
#  'http://qudt.org/vocab/unit/GM-PER-M2-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-M2-DAY',
#                                                                  'http://qudt.org/vocab/unit/MicroGM-PER-M2-DAY']},
#  'http://qudt.org/vocab/unit/GM-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/GM-PER-DeciM3',
#                                                              'http://qudt.org/vocab/unit/MicroGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/NanoGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/GM-PER-CentiM3',
#                                                              'http://qudt.org/vocab/unit/KiloGM-PER-M3',
#                                                              'http://qudt.org/vocab/unit/MegaGM-PER-M3']},
#  'http://qudt.org/vocab/unit/GM-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-MIN',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-MIN']},
#  'http://qudt.org/vocab/unit/GM-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloGM-PER-MOL',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-KiloMOL']},
#  'http://qudt.org/vocab/unit/GM-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGM-PER-SEC',
#                                                               'http://qudt.org/vocab/unit/KiloGM-PER-SEC']},
#  'http://qudt.org/vocab/unit/GON': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/GRAIN-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/GRAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliGRAY',
#                                                         'http://qudt.org/vocab/unit/MicroGRAY']},
#  'http://qudt.org/vocab/unit/GRAY-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/H': {'prefixed_units': ['http://qudt.org/vocab/unit/NanoH',
#                                                      'http://qudt.org/vocab/unit/PicoH',
#                                                      'http://qudt.org/vocab/unit/MilliH',
#                                                      'http://qudt.org/vocab/unit/MicroH']},
#  'http://qudt.org/vocab/unit/H-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/NanoH-PER-M',
#                                                            'http://qudt.org/vocab/unit/MicroH-PER-M']},
#  'http://qudt.org/vocab/unit/H-PER-OHM': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroH-PER-OHM',
#                                                              'http://qudt.org/vocab/unit/H-PER-KiloOHM',
#                                                              'http://qudt.org/vocab/unit/MilliH-PER-OHM']},
#  'http://qudt.org/vocab/unit/HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/HR-PER-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/HZ': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaHZ',
#                                                       'http://qudt.org/vocab/unit/KiloHZ',
#                                                       'http://qudt.org/vocab/unit/MegaHZ',
#                                                       'http://qudt.org/vocab/unit/TeraHZ']},
#  'http://qudt.org/vocab/unit/HZ-M': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaHZ-M',
#                                                         'http://qudt.org/vocab/unit/KiloHZ-M',
#                                                         'http://qudt.org/vocab/unit/MegaHZ-M']},
#  'http://qudt.org/vocab/unit/HZ-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaHZ-PER-K']},
#  'http://qudt.org/vocab/unit/HZ-PER-T': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaHZ-PER-T']},
#  'http://qudt.org/vocab/unit/HZ-PER-V': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J': {'prefixed_units': ['http://qudt.org/vocab/unit/TeraJ',
#                                                      'http://qudt.org/vocab/unit/FemtoJ',
#                                                      'http://qudt.org/vocab/unit/AttoJ',
#                                                      'http://qudt.org/vocab/unit/GigaJ',
#                                                      'http://qudt.org/vocab/unit/MilliJ',
#                                                      'http://qudt.org/vocab/unit/ExaJ',
#                                                      'http://qudt.org/vocab/unit/KiloJ',
#                                                      'http://qudt.org/vocab/unit/PetaJ',
#                                                      'http://qudt.org/vocab/unit/MegaJ']},
#  'http://qudt.org/vocab/unit/J-M-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloJ-PER-KiloGM',
#                                                             'http://qudt.org/vocab/unit/MilliJ-PER-GM',
#                                                             'http://qudt.org/vocab/unit/J-PER-KiloGM']},
#  'http://qudt.org/vocab/unit/J-PER-GM-DEG_C': {'prefixed_units': ['http://qudt.org/vocab/unit/J-PER-KiloGM-DEG_C']},
#  'http://qudt.org/vocab/unit/J-PER-GM-K': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloJ-PER-KiloGM-K',
#                                                               'http://qudt.org/vocab/unit/J-PER-KiloGM-K']},
#  'http://qudt.org/vocab/unit/J-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaJ-PER-HR',
#                                                             'http://qudt.org/vocab/unit/MegaJ-PER-HR']},
#  'http://qudt.org/vocab/unit/J-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaJ-PER-K',
#                                                            'http://qudt.org/vocab/unit/KiloJ-PER-K']},
#  'http://qudt.org/vocab/unit/J-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaJ-PER-M2',
#                                                             'http://qudt.org/vocab/unit/J-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/MilliJ-PER-M2',
#                                                             'http://qudt.org/vocab/unit/MegaJ-PER-M2']},
#  'http://qudt.org/vocab/unit/J-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaJ-PER-M3']},
#  'http://qudt.org/vocab/unit/J-PER-M3-K': {'prefixed_units': ['http://qudt.org/vocab/unit/J-PER-CentiM3-K']},
#  'http://qudt.org/vocab/unit/J-PER-M4': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloJ-PER-MOL']},
#  'http://qudt.org/vocab/unit/J-PER-MOL-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaJ-PER-SEC']},
#  'http://qudt.org/vocab/unit/J-PER-T': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-PER-T2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/J-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/AttoJ-SEC']},
#  'http://qudt.org/vocab/unit/J-SEC-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-M-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-M-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PA-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-T': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/K2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/KAT': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/KAT-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/PicoKAT-PER-L',
#                                                              'http://qudt.org/vocab/unit/NanoKAT-PER-L',
#                                                              'http://qudt.org/vocab/unit/MicroKAT-PER-L',
#                                                              'http://qudt.org/vocab/unit/KAT-PER-MicroL',
#                                                              'http://qudt.org/vocab/unit/MilliKAT-PER-L']},
#  'http://qudt.org/vocab/unit/L': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiL',
#                                                      'http://qudt.org/vocab/unit/PicoL',
#                                                      'http://qudt.org/vocab/unit/KiloL',
#                                                      'http://qudt.org/vocab/unit/HectoL',
#                                                      'http://qudt.org/vocab/unit/DecaL',
#                                                      'http://qudt.org/vocab/unit/DeciL',
#                                                      'http://qudt.org/vocab/unit/MilliL',
#                                                      'http://qudt.org/vocab/unit/MegaL',
#                                                      'http://qudt.org/vocab/unit/FemtoL',
#                                                      'http://qudt.org/vocab/unit/NanoL',
#                                                      'http://qudt.org/vocab/unit/MicroL']},
#  'http://qudt.org/vocab/unit/L-PER-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-DAY']},
#  'http://qudt.org/vocab/unit/L-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-HR',
#                                                             'http://qudt.org/vocab/unit/KiloL-PER-HR']},
#  'http://qudt.org/vocab/unit/L-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-K']},
#  'http://qudt.org/vocab/unit/L-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroL-PER-L',
#                                                            'http://qudt.org/vocab/unit/MilliL-PER-L']},
#  'http://qudt.org/vocab/unit/L-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-MIN']},
#  'http://qudt.org/vocab/unit/L-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/L-PER-MicroMOL']},
#  'http://qudt.org/vocab/unit/L-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliL-PER-SEC']},
#  'http://qudt.org/vocab/unit/L-PER-SEC-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LM-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LM-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LUX': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/LUX-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliM',
#                                                      'http://qudt.org/vocab/unit/MicroM',
#                                                      'http://qudt.org/vocab/unit/HectoM',
#                                                      'http://qudt.org/vocab/unit/NanoM',
#                                                      'http://qudt.org/vocab/unit/FemtoM',
#                                                      'http://qudt.org/vocab/unit/DecaM',
#                                                      'http://qudt.org/vocab/unit/CentiM',
#                                                      'http://qudt.org/vocab/unit/KiloM',
#                                                      'http://qudt.org/vocab/unit/DeciM',
#                                                      'http://qudt.org/vocab/unit/PicoM']},
#  'http://qudt.org/vocab/unit/M-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M-K-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M-PER-FARAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM-PER-HR',
#                                                             'http://qudt.org/vocab/unit/MilliM-PER-HR',
#                                                             'http://qudt.org/vocab/unit/KiloM-PER-HR']},
#  'http://qudt.org/vocab/unit/M-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM-PER-K',
#                                                            'http://qudt.org/vocab/unit/MicroM-PER-K',
#                                                            'http://qudt.org/vocab/unit/MilliM-PER-K']},
#  'http://qudt.org/vocab/unit/M-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliM-PER-MIN',
#                                                              'http://qudt.org/vocab/unit/MicroM-PER-MIN']},
#  'http://qudt.org/vocab/unit/M-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroM-PER-SEC',
#                                                              'http://qudt.org/vocab/unit/KiloM-PER-SEC',
#                                                              'http://qudt.org/vocab/unit/MilliM-PER-SEC',
#                                                              'http://qudt.org/vocab/unit/CentiM-PER-SEC']},
#  'http://qudt.org/vocab/unit/M-PER-SEC2': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM-PER-SEC2']},
#  'http://qudt.org/vocab/unit/M-PER-YR': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliM-PER-YR',
#                                                             'http://qudt.org/vocab/unit/CentiM-PER-YR']},
#  'http://qudt.org/vocab/unit/M2': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciM2',
#                                                       'http://qudt.org/vocab/unit/NanoM2',
#                                                       'http://qudt.org/vocab/unit/MicroM2',
#                                                       'http://qudt.org/vocab/unit/MilliM2',
#                                                       'http://qudt.org/vocab/unit/CentiM2']},
#  'http://qudt.org/vocab/unit/M2-HZ': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-HZ2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-HZ3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-HZ4': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-K-PER-W': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/M2-PER-KiloGM']},
#  'http://qudt.org/vocab/unit/M2-PER-HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-HZ': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-HZ2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-N': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliM2-PER-SEC',
#                                                               'http://qudt.org/vocab/unit/CentiM2-PER-SEC']},
#  'http://qudt.org/vocab/unit/M2-PER-SEC2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloM2-PER-SEC2']},
#  'http://qudt.org/vocab/unit/M2-PER-SEC2-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-SR-J': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-PER-V-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM2-PER-V-SEC']},
#  'http://qudt.org/vocab/unit/M2-PER-W': {'prefixed_units': ['http://qudt.org/vocab/unit/M2-PER-KiloW']},
#  'http://qudt.org/vocab/unit/M2-SEC-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M2-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroM3',
#                                                       'http://qudt.org/vocab/unit/DeciM3',
#                                                       'http://qudt.org/vocab/unit/CentiM3',
#                                                       'http://qudt.org/vocab/unit/MilliM3',
#                                                       'http://qudt.org/vocab/unit/DecaM3']},
#  'http://qudt.org/vocab/unit/M3-PER-C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3-PER-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-DAY',
#                                                               'http://qudt.org/vocab/unit/DeciM3-PER-DAY']},
#  'http://qudt.org/vocab/unit/M3-PER-HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-HR',
#                                                              'http://qudt.org/vocab/unit/DeciM3-PER-HR']},
#  'http://qudt.org/vocab/unit/M3-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-K']},
#  'http://qudt.org/vocab/unit/M3-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M3-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-CentiM3',
#                                                              'http://qudt.org/vocab/unit/DeciM3-PER-M3',
#                                                              'http://qudt.org/vocab/unit/MicroM3-PER-M3',
#                                                              'http://qudt.org/vocab/unit/CentiM3-PER-M3',
#                                                              'http://qudt.org/vocab/unit/MilliM3-PER-M3']},
#  'http://qudt.org/vocab/unit/M3-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciM3-PER-MIN',
#                                                               'http://qudt.org/vocab/unit/CentiM3-PER-MIN']},
#  'http://qudt.org/vocab/unit/M3-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-MOL',
#                                                               'http://qudt.org/vocab/unit/DeciM3-PER-MOL']},
#  'http://qudt.org/vocab/unit/M3-PER-MOL-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM3-PER-MOL-SEC']},
#  'http://qudt.org/vocab/unit/M3-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciM3-PER-SEC',
#                                                               'http://qudt.org/vocab/unit/CentiM3-PER-SEC']},
#  'http://qudt.org/vocab/unit/M3-PER-SEC2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloM3-PER-SEC2']},
#  'http://qudt.org/vocab/unit/M3-PER-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M4': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliM4',
#                                                       'http://qudt.org/vocab/unit/CentiM4']},
#  'http://qudt.org/vocab/unit/M4-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M5': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/M6': {'prefixed_units': ['http://qudt.org/vocab/unit/CentiM6']},
#  'http://qudt.org/vocab/unit/MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MIN_Angle': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MO': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliMOL',
#                                                        'http://qudt.org/vocab/unit/MicroMOL',
#                                                        'http://qudt.org/vocab/unit/KiloMOL',
#                                                        'http://qudt.org/vocab/unit/FemtoMOL']},
#  'http://qudt.org/vocab/unit/MOL-DEG_C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-GM-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-GM-HR']},
#  'http://qudt.org/vocab/unit/MOL-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloMOL-PER-HR']},
#  'http://qudt.org/vocab/unit/MOL-PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/NanoMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/MilliMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/CentiMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/FemtoMOL-PER-L',
#                                                              'http://qudt.org/vocab/unit/PicoMOL-PER-L']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-M2',
#                                                               'http://qudt.org/vocab/unit/MilliMOL-PER-M2']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-DAY': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-M2-DAY',
#                                                                   'http://qudt.org/vocab/unit/PicoMOL-PER-M2-DAY',
#                                                                   'http://qudt.org/vocab/unit/NanoMOL-PER-M2-DAY',
#                                                                   'http://qudt.org/vocab/unit/MilliMOL-PER-M2-DAY']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliMOL-PER-M2-SEC',
#                                                                   'http://qudt.org/vocab/unit/MicroMOL-PER-M2-SEC']},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC-M-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-M2-SEC-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/MOL-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloMOL-PER-M3',
#                                                               'http://qudt.org/vocab/unit/MilliMOL-PER-M3',
#                                                               'http://qudt.org/vocab/unit/MOL-PER-DeciM3',
#                                                               'http://qudt.org/vocab/unit/PicoMOL-PER-M3']},
#  'http://qudt.org/vocab/unit/MOL-PER-M3-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/PicoMOL-PER-M3-SEC']},
#  'http://qudt.org/vocab/unit/MOL-PER-MIN': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloMOL-PER-MIN']},
#  'http://qudt.org/vocab/unit/MOL-PER-MOL': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliMOL-PER-MOL',
#                                                                'http://qudt.org/vocab/unit/MicroMOL-PER-MOL']},
#  'http://qudt.org/vocab/unit/MOL-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroMOL-PER-SEC',
#                                                                'http://qudt.org/vocab/unit/KiloMOL-PER-SEC']},
#  'http://qudt.org/vocab/unit/N': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroN',
#                                                      'http://qudt.org/vocab/unit/MegaN',
#                                                      'http://qudt.org/vocab/unit/MilliN',
#                                                      'http://qudt.org/vocab/unit/KiloN']},
#  'http://qudt.org/vocab/unit/N-M': {'prefixed_units': ['http://qudt.org/vocab/unit/DeciN-M',
#                                                        'http://qudt.org/vocab/unit/MegaN-M',
#                                                        'http://qudt.org/vocab/unit/CentiN-M',
#                                                        'http://qudt.org/vocab/unit/KiloN-M',
#                                                        'http://qudt.org/vocab/unit/MicroN-M',
#                                                        'http://qudt.org/vocab/unit/MilliN-M',
#                                                        'http://qudt.org/vocab/unit/N-CentiM']},
#  'http://qudt.org/vocab/unit/N-M-PER-A': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-PER-DEG-M': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-M-PER-DEG-M']},
#  'http://qudt.org/vocab/unit/N-M-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-M-PER-M']},
#  'http://qudt.org/vocab/unit/N-M-PER-M-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M-SEC-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-M2']},
#  'http://qudt.org/vocab/unit/N-M2-PER-A': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-PER-A': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-PER-C': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/N-PER-CentiM',
#                                                            'http://qudt.org/vocab/unit/MilliN-PER-M',
#                                                            'http://qudt.org/vocab/unit/N-PER-MilliM',
#                                                            'http://qudt.org/vocab/unit/KiloN-PER-M']},
#  'http://qudt.org/vocab/unit/N-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/N-PER-MilliM2',
#                                                             'http://qudt.org/vocab/unit/N-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/KiloN-PER-M2']},
#  'http://qudt.org/vocab/unit/N-PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloN-PER-M3']},
#  'http://qudt.org/vocab/unit/N-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/N-SEC-PER-RAD': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/NP': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/NUM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/OHM': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroOHM',
#                                                        'http://qudt.org/vocab/unit/GigaOHM',
#                                                        'http://qudt.org/vocab/unit/KiloOHM',
#                                                        'http://qudt.org/vocab/unit/TeraOHM',
#                                                        'http://qudt.org/vocab/unit/MilliOHM',
#                                                        'http://qudt.org/vocab/unit/MegaOHM']},
#  'http://qudt.org/vocab/unit/OHM-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/OHM-M2-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaPA',
#                                                       'http://qudt.org/vocab/unit/DecaPA',
#                                                       'http://qudt.org/vocab/unit/HectoPA',
#                                                       'http://qudt.org/vocab/unit/MicroPA',
#                                                       'http://qudt.org/vocab/unit/KiloPA',
#                                                       'http://qudt.org/vocab/unit/MilliPA',
#                                                       'http://qudt.org/vocab/unit/GigaPA']},
#  'http://qudt.org/vocab/unit/PA-L-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/HectoPA-L-PER-SEC',
#                                                                 'http://qudt.org/vocab/unit/MegaPA-L-PER-SEC']},
#  'http://qudt.org/vocab/unit/PA-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-M-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-M-PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-M3-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaPA-M3-PER-SEC',
#                                                                  'http://qudt.org/vocab/unit/HectoPA-M3-PER-SEC']},
#  'http://qudt.org/vocab/unit/PA-PER-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/HectoPA-PER-HR']},
#  'http://qudt.org/vocab/unit/PA-PER-K': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloPA-PER-K',
#                                                             'http://qudt.org/vocab/unit/MegaPA-PER-K',
#                                                             'http://qudt.org/vocab/unit/HectoPA-PER-K']},
#  'http://qudt.org/vocab/unit/PA-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliPA-SEC']},
#  'http://qudt.org/vocab/unit/PA-SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA-SEC-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA2-PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PA2-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-EV2': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-GigaEV2']},
#  'http://qudt.org/vocab/unit/PER-GM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-H': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-J-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-J2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-L': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-MilliL']},
#  'http://qudt.org/vocab/unit/PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-MilliM',
#                                                          'http://qudt.org/vocab/unit/PER-PicoM',
#                                                          'http://qudt.org/vocab/unit/PER-NanoM',
#                                                          'http://qudt.org/vocab/unit/PER-CentiM',
#                                                          'http://qudt.org/vocab/unit/PER-MicroM',
#                                                          'http://qudt.org/vocab/unit/PER-KiloM']},
#  'http://qudt.org/vocab/unit/PER-M-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M2-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-M3': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-MilliM3',
#                                                           'http://qudt.org/vocab/unit/PER-CentiM3']},
#  'http://qudt.org/vocab/unit/PER-M3-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-MO': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-PA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-PA-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/PER-MilliSEC']},
#  'http://qudt.org/vocab/unit/PER-SEC-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC-M2-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-T-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-T-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-WB': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-WK': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PER-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PERCENT': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PH': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PPB': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PPM': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PPQ': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PPT': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PPTH': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/PPTR_VOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/R': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliR',
#                                                      'http://qudt.org/vocab/unit/KiloR']},
#  'http://qudt.org/vocab/unit/RAD': {'prefixed_units': ['http://qudt.org/vocab/unit/MicroRAD',
#                                                        'http://qudt.org/vocab/unit/MilliRAD']},
#  'http://qudt.org/vocab/unit/RAD-M2-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/RAD-PER-SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/S': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliS',
#                                                      'http://qudt.org/vocab/unit/KiloS',
#                                                      'http://qudt.org/vocab/unit/MicroS']},
#  'http://qudt.org/vocab/unit/S-M2-PER-MOL': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/S-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaS-PER-M',
#                                                            'http://qudt.org/vocab/unit/PicoS-PER-M',
#                                                            'http://qudt.org/vocab/unit/MicroS-PER-M',
#                                                            'http://qudt.org/vocab/unit/DeciS-PER-M',
#                                                            'http://qudt.org/vocab/unit/S-PER-CentiM',
#                                                            'http://qudt.org/vocab/unit/KiloS-PER-M',
#                                                            'http://qudt.org/vocab/unit/MilliS-PER-M',
#                                                            'http://qudt.org/vocab/unit/NanoS-PER-M']},
#  'http://qudt.org/vocab/unit/SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/AttoSEC',
#                                                        'http://qudt.org/vocab/unit/KiloSEC',
#                                                        'http://qudt.org/vocab/unit/MilliSEC',
#                                                        'http://qudt.org/vocab/unit/FemtoSEC',
#                                                        'http://qudt.org/vocab/unit/DeciSEC',
#                                                        'http://qudt.org/vocab/unit/MicroSEC',
#                                                        'http://qudt.org/vocab/unit/NanoSEC',
#                                                        'http://qudt.org/vocab/unit/PicoSEC']},
#  'http://qudt.org/vocab/unit/SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/SEC-PER-RAD-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/SEC2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/SV': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliSV',
#                                                       'http://qudt.org/vocab/unit/MicroSV']},
#  'http://qudt.org/vocab/unit/T': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliT',
#                                                      'http://qudt.org/vocab/unit/NanoT',
#                                                      'http://qudt.org/vocab/unit/MicroT']},
#  'http://qudt.org/vocab/unit/T-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/T-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-HA-YR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TONNE-PER-YR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloTONNE-PER-YR']},
#  'http://qudt.org/vocab/unit/TON_Metric': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloTON_Metric',
#                                                               'http://qudt.org/vocab/unit/DeciTON_Metric']},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-DAY': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-HA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-HR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-MIN': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/TON_Metric-PER-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliV',
#                                                      'http://qudt.org/vocab/unit/MicroV',
#                                                      'http://qudt.org/vocab/unit/KiloV',
#                                                      'http://qudt.org/vocab/unit/MegaV']},
#  'http://qudt.org/vocab/unit/V-A': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloV-A',
#                                                        'http://qudt.org/vocab/unit/MegaV-A']},
#  'http://qudt.org/vocab/unit/V-A-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloV-A-HR',
#                                                           'http://qudt.org/vocab/unit/MegaV-A-HR']},
#  'http://qudt.org/vocab/unit/V-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaV-PER-M',
#                                                            'http://qudt.org/vocab/unit/MicroV-PER-M',
#                                                            'http://qudt.org/vocab/unit/MilliV-PER-M',
#                                                            'http://qudt.org/vocab/unit/V-PER-CentiM',
#                                                            'http://qudt.org/vocab/unit/KiloV-PER-M',
#                                                            'http://qudt.org/vocab/unit/V-PER-MilliM']},
#  'http://qudt.org/vocab/unit/V-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V-PER-SEC': {'prefixed_units': ['http://qudt.org/vocab/unit/V-PER-MicroSEC']},
#  'http://qudt.org/vocab/unit/V-SEC-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/V2-PER-K2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W': {'prefixed_units': ['http://qudt.org/vocab/unit/NanoW',
#                                                      'http://qudt.org/vocab/unit/MegaW',
#                                                      'http://qudt.org/vocab/unit/TeraW',
#                                                      'http://qudt.org/vocab/unit/MilliW',
#                                                      'http://qudt.org/vocab/unit/GigaW',
#                                                      'http://qudt.org/vocab/unit/KiloW',
#                                                      'http://qudt.org/vocab/unit/MicroW',
#                                                      'http://qudt.org/vocab/unit/PicoW']},
#  'http://qudt.org/vocab/unit/W-HR': {'prefixed_units': ['http://qudt.org/vocab/unit/GigaW-HR',
#                                                         'http://qudt.org/vocab/unit/MegaW-HR',
#                                                         'http://qudt.org/vocab/unit/KiloW-HR',
#                                                         'http://qudt.org/vocab/unit/TeraW-HR']},
#  'http://qudt.org/vocab/unit/W-HR-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/KiloW-HR-PER-M2']},
#  'http://qudt.org/vocab/unit/W-HR-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-M-PER-M2-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-M2-PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-GM': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliW-PER-MilliGM',
#                                                             'http://qudt.org/vocab/unit/W-PER-KiloGM']},
#  'http://qudt.org/vocab/unit/W-PER-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M2': {'prefixed_units': ['http://qudt.org/vocab/unit/W-PER-CentiM2',
#                                                             'http://qudt.org/vocab/unit/MicroW-PER-M2',
#                                                             'http://qudt.org/vocab/unit/PicoW-PER-M2',
#                                                             'http://qudt.org/vocab/unit/MilliW-PER-M2']},
#  'http://qudt.org/vocab/unit/W-PER-M2-K': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M2-K4': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M2-M': {'prefixed_units': ['http://qudt.org/vocab/unit/W-PER-M2-NanoM']},
#  'http://qudt.org/vocab/unit/W-PER-M2-M-SR': {'prefixed_units': ['http://qudt.org/vocab/unit/W-PER-M2-NanoM-SR']},
#  'http://qudt.org/vocab/unit/W-PER-M2-PA': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M2-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-M3': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-PER-SR': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-SEC': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/W-SEC-PER-M2': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/WB': {'prefixed_units': ['http://qudt.org/vocab/unit/MilliWB']},
#  'http://qudt.org/vocab/unit/WB-M': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/WB-PER-M': {'prefixed_units': ['http://qudt.org/vocab/unit/WB-PER-MilliM',
#                                                             'http://qudt.org/vocab/unit/KiloWB-PER-M']},
#  'http://qudt.org/vocab/unit/WK': {'prefixed_units': []},
#  'http://qudt.org/vocab/unit/YR': {'prefixed_units': ['http://qudt.org/vocab/unit/MegaYR']},
#  'http://qudt.org/vocab/unit/YR_TROPICAL': {'prefixed_units': []}}

# %% [markdown]
# ## Fetch OSL Schema for Unit of Measure

# %%
from osw.core import OSW
import osw
from osw.auth import CredentialManager
from osw.wtsite import WtSite
from osw.express import OswExpress
import osw.model.entity as model


required_schemas = [
    "Category:OSW99e0f46a40ca4129a420b4bb89c4cc45",  # Unit prefix
    "Category:OSWd2520fa016844e01af0097a85bb25b25",  # Unit of Measure
]


def update_local_osw(osw_obj):
    print("fetch schemas")
    osw_obj.fetch_schema(
        OSW.FetchSchemaParam(
            schema_title=required_schemas,
            mode="replace",
        )
    )


if __name__ == "__main__":
    # Authentication
    osw_obj = OswExpress(
        domain="wiki-dev.open-semantic-lab.org",  # cred_filepath=pwd_file_path
    )
    update_local_osw(osw_obj)
# Out:
# c:\Users\raeder\AppData\Local\pypoetry\Cache\virtualenvs\quantities-units-W4YBs7Av-py3.12\Lib\site-packages\osw\utils\strings.py:58: FutureWarning: Possible nested set at position 16
#   self.pattern = re.compile(self.pattern)
# c:\Users\raeder\AppData\Local\pypoetry\Cache\virtualenvs\quantities-units-W4YBs7Av-py3.12\Lib\site-packages\osw\express.py:323: UserWarning: An exception occurred while loading the module dependencies:
# 'module 'osw.model.entity' has no attribute 'File''You will be now have to connect to an OSW instance to fetch the dependencies from!
#   warn(
# Fetch Category:OSW3e3f5dd4f71842fbb8f270e511af8031
# Fetch Category:OSWff333fd349af4f65a69100405a9e60c7
# Fetch Category:OSW2ac4493f8635481eaf1db961b63c8325
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW11a53cdfbdc24524bf8ac435cbf65d9d
# Fetch Category:OSW05b244d0a669436e96fe4e1631d5a171
# Fetch Category:OSWff333fd349af4f65a69100405a9e60c7
# Fetch Category:OSW2ac4493f8635481eaf1db961b63c8325
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# ReadAccess
# AccessRestrictions
# Label
# Description
# WikiPage
# Meta
# Entity
# ObjectStatement
# DataStatement
# QuantityStatement
# Item
# Data
# File
# LocalFile
# c:\Users\raeder\AppData\Local\pypoetry\Cache\virtualenvs\quantities-units-W4YBs7Av-py3.12\Lib\site-packages\osw\express.py:335: UserWarning: Dependencies specified in the module 'osw.express' have been fetched from OSW:
# {'LocalFile': 'Category:OSW3e3f5dd4f71842fbb8f270e511af8031', 'WikiFile': 'Category:OSW11a53cdfbdc24524bf8ac435cbf65d9d'}
# Its recommended to restart the kernel, to apply all changes seamlessly.
#   warn(
# fetch schemas
# Fetch Category:OSW99e0f46a40ca4129a420b4bb89c4cc45
# Fetch Category:OSWd02741381aaa4709ae0753a0edc341ce
# Fetch Category:OSWcbb09a36336740c6a2cd62db9bf647ec
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSWd2520fa016844e01af0097a85bb25b25
# Fetch Category:Item
# Fetch Category:Entity
# Fetch JsonSchema:Label
# Fetch JsonSchema:Label
# Fetch JsonSchema:Description
# Fetch JsonSchema:Statement
# Fetch JsonSchema:Label
# Fetch JsonSchema:Meta
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# Fetch Category:OSW6ef70c808fb54abbbacb059c285713d4
# Fetch Category:OSW93ccae36243542ceac6c951450a81d47
# ReadAccess
# AccessRestrictions
# Label
# Description
# WikiPage
# Meta
# Characteristic
# OntologyRelated
# Entity
# ObjectStatement
# DataStatement
# QuantityStatement
# Item
# IntangibleItem
# Enumeration

# %% [markdown]
# ## Instanciate Example Unit of Measure

# %%
title = "Item:OSWc73852e7049f42e7b5282866f3839f5e"  # Meter
meter_u = osw_obj.load_entity(title)

pprint(meter_u)
# Out:
# BaseUnitOfMeasure(type=['Category:OSW7199b9568d96476cacfe30060c64f371'], uuid=UUID('c73852e7-049f-42e7-b528-2866f3839f5e'), exact_ontology_match=['https://qudt.org/vocab/unit/M', 'https://si-digital-framework.org/SI/units/metre', ' http://dbpedia.org/resource/Metre ', 'http://www.ontology-of-units-of-measure.org/resource/om-2/metre', 'urn:samm:org.eclipse.esmf.samm:unit:2.1.0#m'], close_ontology_match=None, rdf_type=None, iri=None, name='Meter', label=[Label(text='Meter', lang='en')], short_name=None, query_label=None, description=[], image=None, ordering_categories=None, keywords=None, based_on=None, statements=None, attachments=None, meta=Meta(wiki_page=WikiPage(title='OSWc73852e7049f42e7b5282866f3839f5e', namespace='Item'), change_id=None), entry_access=None, main_symbol='m', prefix_units=[PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='f454ccd2-582d-4727-9a2e-05e2b6f83c5a', exact_ontology_match=['https://qudt.org/vocab/unit/KiloM', ' http://dbpedia.org/resource/Kilometre ', 'urn:samm:org.eclipse.esmf.samm:unit:2.1.0#km'], close_ontology_match=None, osw_id='Item:OSWc73852e7049f42e7b5282866f3839f5e#OSWf454ccd2582d47279a2e05e2b6f83c5a', prefix='Item:OSW9aae9552adf34f139f6766876a8d7c59', prefix_symbol='k', main_symbol='km'), PrefixUnit(type=['Category:OSW6ef70c808fb54abbbacb059c285713d4'], uuid='eb12f149-b594-4ded-bf96-018b953a8195', exact_ontology_match=['https://qudt.org/vocab/unit/MilliM', ' http://dbpedia.org/resource/Millimetre ', 'urn:samm:org.eclipse.esmf.samm:unit:2.1.0#mm'], close_ontology_match=None, osw_id='Item:OSWc73852e7049f42e7b5282866f3839f5e#OSWeb12f149b5944dedbf96018b953a8195', prefix='Item:OSWa404be342a6b4b47ae1fd6f95cb7ab81', prefix_symbol='m', main_symbol='mm')])

# %% [markdown]
# ## Fetch Units from Ontology and complete properties of unit dictionary

# %%
from utils import sparql_wrapper
from pprint import pprint

sparql_qudt_unit_params = sparql_wrapper.Sparql(
    endpoint="https://www.qudt.org/fuseki/qudt/sparql",
    src_filepath="../ontology/qudt/sparql/units.sparql",
    tgt_filepath="../ontology/qudt/data/units.json",
    debug=False,
)
qudt_units_param_res = sparql_qudt_unit_params.execQuery()
sparql_qudt_unit_params.writeJsonFile(data=qudt_units_param_res)
print(len(qudt_units_param_res))
# pprint(qudt_units_param_res)
# Out:
# Reading SPARQL Query from c:\Users\raeder\Desktop\dev\Gitlab\osw\apps\python-lvl2\quantities-units\src\quantities-units\utils\../ontology/qudt/sparql/units.sparql
# Writing JSON data to c:\Users\raeder\Desktop\dev\Gitlab\osw\apps\python-lvl2\quantities-units\src\quantities-units\utils\../ontology/qudt/data/units.json
# 2
# ['http://qudt.org/vocab/unit/MilliPA-SEC', 'http://qudt.org/vocab/unit/KiloBYTE', 'http://qudt.org/vocab/unit/J-M2-PER-KiloGM', 'http://qudt.org/vocab/unit/DecaPA', 'http://qudt.org/vocab/unit/CentiL', 'http://qudt.org/vocab/unit/DecaM3', 'http://qudt.org/vocab/unit/NanoH-PER-M', 'http://qudt.org/vocab/unit/MicroKAT-PER-L', 'http://qudt.org/vocab/unit/MilliGM-PER-M3-DAY', 'http://qudt.org/vocab/unit/MicroN', 'http://qudt.org/vocab/unit/KiloGM-PER-M3', 'http://qudt.org/vocab/unit/J-PER-GM-DEG_C', 'http://qudt.org/vocab/unit/HR', 'http://qudt.org/vocab/unit/WB-PER-MilliM', 'http://qudt.org/vocab/unit/KiloM-PER-HR', 'http://qudt.org/vocab/unit/NanoMOL-PER-L-DAY', 'http://qudt.org/vocab/unit/MicroMOL-PER-M2', 'http://qudt.org/vocab/unit/NanoW', 'http://qudt.org/vocab/unit/T-M', 'http://qudt.org/vocab/unit/M-PER-HR', 'http://qudt.org/vocab/unit/KiloGM-PER-HR', 'http://qudt.org/vocab/unit/KiloGM-M2', 'http://qudt.org/vocab/unit/MicroM3-PER-M3', 'http://qudt.org/vocab/unit/MilliS-PER-M', 'http://qudt.org/vocab/unit/HectoPA-PER-HR', 'http://qudt.org/vocab/unit/CentiM6', 'http://qudt.org/vocab/unit/M-K', 'http://qudt.org/vocab/unit/M2-PER-W', 'http://qudt.org/vocab/unit/DeciC', 'http://qudt.org/vocab/unit/CentiM3-PER-GM', 'http://qudt.org/vocab/unit/NanoMOL-PER-M2-DAY', 'http://qudt.org/vocab/unit/M2-PER-KiloW', 'http://qudt.org/vocab/unit/KiloGM-PER-HA', 'http://qudt.org/vocab/unit/C-PER-CentiM2', 'http://qudt.org/vocab/unit/CentiM2', 'http://qudt.org/vocab/unit/KiloGM-PER-M', 'http://qudt.org/vocab/unit/MOL', 'http://qudt.org/vocab/unit/MilliBQ-PER-GM', 'http://qudt.org/vocab/unit/TON_Metric', 'http://qudt.org/vocab/unit/C-PER-MilliM3', 'http://qudt.org/vocab/unit/M-PER-K', 'http://qudt.org/vocab/unit/MegaJ-PER-M2', 'http://qudt.org/vocab/unit/KiloW-HR-PER-M2', 'http://qudt.org/vocab/unit/PicoMOL-PER-KiloGM', 'http://qudt.org/vocab/unit/MicroGM-PER-M3-HR', 'http://qudt.org/vocab/unit/J-SEC-PER-MOL', 'http://qudt.org/vocab/unit/CentiGM', 'http://qudt.org/vocab/unit/PER-SEC-M2-SR', 'http://qudt.org/vocab/unit/MicroH-PER-M', 'http://qudt.org/vocab/unit/PA-PER-MIN', 'http://qudt.org/vocab/unit/SEC2', 'http://qudt.org/vocab/unit/LUX-HR', 'http://qudt.org/vocab/unit/ERG-PER-CentiM2', 'http://qudt.org/vocab/unit/PER-NanoM', 'http://qudt.org/vocab/unit/HZ-PER-K', 'http://qudt.org/vocab/unit/PER-GigaEV2', 'http://qudt.org/vocab/unit/MilliW-PER-M2-NanoM', 'http://qudt.org/vocab/unit/KiloGM-PER-FT2', 'http://qudt.org/vocab/unit/MicroV-PER-M', 'http://qudt.org/vocab/unit/PicoGM', 'http://qudt.org/vocab/unit/DEG_C', 'http://qudt.org/vocab/unit/PA', 'http://qudt.org/vocab/unit/BQ-PER-M2', 'http://qudt.org/vocab/unit/BQ-PER-M3', 'http://qudt.org/vocab/unit/N-M-PER-M-RAD', 'http://qudt.org/vocab/unit/PER-CentiM', 'http://qudt.org/vocab/unit/DEG_C-PER-M', 'http://qudt.org/vocab/unit/MilliMOL-PER-GM', 'http://qudt.org/vocab/unit/PicoGM-PER-GM', 'http://qudt.org/vocab/unit/M2-PER-GM', 'http://qudt.org/vocab/unit/KiloBQ', 'http://qudt.org/vocab/unit/KiloHZ', 'http://qudt.org/vocab/unit/KiloGM-PER-L', 'http://qudt.org/vocab/unit/N-M-PER-KiloGM', 'http://qudt.org/vocab/unit/DeciM', 'http://qudt.org/vocab/unit/DEG', 'http://qudt.org/vocab/unit/ZeptoC', 'http://qudt.org/vocab/unit/K2', 'http://qudt.org/vocab/unit/NanoKAT-PER-L', 'http://qudt.org/vocab/unit/N-PER-KiloGM', 'http://qudt.org/vocab/unit/MilliM-PER-K', 'http://qudt.org/vocab/unit/TONNE-PER-DAY', 'http://qudt.org/vocab/unit/TON_Metric-PER-M3', 'http://qudt.org/vocab/unit/A-PER-DEG_C', 'http://qudt.org/vocab/unit/EV-PER-K', 'http://qudt.org/vocab/unit/MegaJ-PER-M3', 'http://qudt.org/vocab/unit/M2-K', 'http://qudt.org/vocab/unit/NanoMOL-PER-MicroGM-HR', 'http://qudt.org/vocab/unit/RAD-PER-M', 'http://qudt.org/vocab/unit/MicroGRAY', 'http://qudt.org/vocab/unit/KiloC-PER-M3', 'http://qudt.org/vocab/unit/MilliC-PER-M3', 'http://qudt.org/vocab/unit/PER-SEC', 'http://qudt.org/vocab/unit/W-PER-GM', 'http://qudt.org/vocab/unit/PicoPA-PER-KiloM', 'http://qudt.org/vocab/unit/TONNE-PER-MIN', 'http://qudt.org/ ...

# %%
# from jsonpath_ng import jsonpath, parse

# # use json path to extract all another info of same level in results.bindings where the identifier is results.bindings[*].applicableUnit.value and the value is "http://qudt.org/vocab/unit#Meter"
# jsonpath_expr = parse(
#     "$.results.bindings[?(@.applicableUnit.value == 'http://qudt.org/vocab/unit#Meter')]"
# )
# meter_unit_info = [match.value for match in jsonpath_expr.find(qudt_units_param_res)]

from jsonpath_ng.ext import parse

# Use json path to extract all another info of same level in results.bindings where the identifier is results.bindings[*].applicableUnit.value and the value is "http://qudt.org/vocab/unit#Meter"
jsonpath_expr = parse(
    '$.results.bindings[?(@.applicableUnit.value = "http://qudt.org/vocab/unit/MilliPA-SEC")]'
)
# meter_unit_info = [match.value for match in jsonpath_expr.find(qudt_units_param_res)]
# pprint(meter_unit_info)

pprint(jsonpath_expr.find(qudt_units_param_res)[0].value)


def match_json_path_key(qudt_units_param_res, identifier="", key=""):
    jsonpath_expr = parse(
        f'$.results.bindings[?(@.applicableUnit.value = "{identifier}")].{key}.value'
    )
    return jsonpath_expr.find(qudt_units_param_res)[0].value


# test
pprint(
    match_json_path_key(
        qudt_units_param_res,
        identifier="http://qudt.org/vocab/unit/KiloBYTE",
        key="ucumCodes",
    )
)
# Out:
# {'applicableSystems': {'type': 'literal',
#                        'value': 'http://qudt.org/vocab/sou/SI, '
#                                 'http://qudt.org/vocab/sou/CGS, '
#                                 'http://qudt.org/vocab/sou/CGS-EMU, '
#                                 'http://qudt.org/vocab/sou/CGS-GAUSS'},
#  'applicableUnit': {'type': 'uri',
#                     'value': 'http://qudt.org/vocab/unit/MilliPA-SEC'},
#  'dimensionVector': {'type': 'uri',
#                      'value': 'http://qudt.org/vocab/dimensionvector/A0E0L-1I0M1H0T-1D0'},
#  'qlabels': {'type': 'literal', 'value': 'Millipascal Second@en'},
#  'symbol': {'type': 'literal', 'value': 'mPa·s'},
#  'ucumCodes': {'type': 'literal', 'value': 'mPa.s'}}
# 'kBy'

# %% [markdown]
# ## Map Attributes from Ontology Data to OSL Schema

# %%
import uuid

units = [
    model.QuantityUnit(
        uuid=uuid.uuid5(
            namespace=uuid.NAMESPACE_URL, name=non_prefixed_unit_iri
        ),
        exact_ontology_match=[non_prefixed_unit_iri],
        name="Meter",
        label=[model.Label(text="Meter", lang="en")],
    )
    for non_prefixed_unit_iri, unit_property_dict in unit_dict.items()
]
